# %% [markdown]
# # Football Stats

# %% [markdown]
# ### To run this Notebook you need to have this JSON files "playerrank, players, teams, events_England, events_European_Championship, events_France, events_Germany, events_Italy, events_Spain, events_World_Cup

# %% [markdown]
# ## Data Extraction and Players Stats

# %% [markdown]
# # Euro , World Cup

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")



## Extaracting info about players form json files

## Minutes played for each player
prank=pd.read_json('playerank.json')
mi=pd.DataFrame(prank.groupby('playerId')['minutesPlayed'].sum()).reset_index()

## Names and personal info for players 
names = pd.read_json('players.json')
names = pd.concat([names['role'].apply(pd.Series), names.drop('role', axis = 1)], axis =1)
names = names.drop('birthArea', axis = 1)
names = pd.concat([names['passportArea'].apply(pd.Series), names.drop('passportArea', axis = 1)], axis =1)
names = names.drop(['name','alpha2code','code2','name'],axis=1)

## info about Clubs 
teams=pd.read_json('teams.json')
teams = pd.concat([teams['area'].apply(pd.Series), teams.drop('area', axis = 1)], axis =1)



### Europeaan Championship
eurodf=pd.read_json('events_European_Championship.json')
## Extracting the coordinates and put them in to multiple columns 
eurodf= pd.concat([eurodf['positions'].apply(pd.Series), eurodf.drop('positions', axis = 1)], axis =1)
eurodf=eurodf.rename(columns={0:'from',1:'to'})
eurodf= pd.concat([eurodf['from'].apply(pd.Series), eurodf.drop('from', axis = 1)], axis =1)
eurodf=eurodf.rename(columns={'x':'From X','y':'From y'})
eurodf= pd.concat([eurodf['to'].apply(pd.Series), eurodf.drop('to', axis = 1)], axis =1)
eurodf=eurodf.rename(columns={'x':'To X','y':'To y'})
eurodf=eurodf.rename(columns={0:'f'})
eurodf=eurodf.drop(['f'],axis=1)

    
## Extracting the Tags and put them in two multiple columns 
eurodf=eurodf.rename(columns={'id':'id_0'})

eurodf= pd.concat([eurodf['tags'].apply(pd.Series), eurodf.drop('tags', axis = 1)], axis =1)
eurodf=eurodf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
eurodf= pd.concat([eurodf['zero'].apply(pd.Series), eurodf.drop('zero', axis = 1)], axis =1)
eurodf=eurodf.rename(columns={'id':'id_1'})
eurodf= pd.concat([eurodf['one'].apply(pd.Series), eurodf.drop('one', axis = 1)], axis =1)
    

eurodf=eurodf.rename(columns={'id':'id_2',0:'a'})
eurodf=eurodf.dropna(axis=1,how='all')
eurodf= pd.concat([eurodf['two'].apply(pd.Series), eurodf.drop('two', axis = 1)], axis =1)


eurodf=eurodf.rename(columns={'id':'id_3',0:'a'})
eurodf=eurodf.dropna(axis=1,how='all')
eurodf= pd.concat([eurodf['three'].apply(pd.Series), eurodf.drop('three', axis = 1)], axis =1)


eurodf=eurodf.rename(columns={'id':'id_4',0:'a'})
eurodf=eurodf.dropna(axis=1,how='all')
eurodf= pd.concat([eurodf['four'].apply(pd.Series), eurodf.drop('four', axis = 1)], axis =1)

    
eurodf=eurodf.rename(columns={'id':'id_5',0:'a'})
eurodf=eurodf.dropna(axis=1,how='all')

def concat_cols(row):
    row = row.fillna('')
    return ''.join([str(row[col]) for col in ['id_1', 'id_2', 'id_3', 'id_4', 'id_5']])
    
    
    
## Removing all tags except only tags related to Accuracy 
eurodfaccuracy=eurodf.copy()
eurodfaccuracy['id_1'] = np.where(eurodfaccuracy['id_1'] <= 1800, np.NaN, eurodfaccuracy['id_1'])
eurodfaccuracy['id_1'] = np.where(eurodfaccuracy['id_1'] >= 1803, np.NaN, eurodfaccuracy['id_1'])

eurodfaccuracy['id_2'] = np.where(eurodfaccuracy['id_2'] <= 1800, np.NaN, eurodfaccuracy['id_2'])
eurodfaccuracy['id_2'] = np.where(eurodfaccuracy['id_2'] >= 1803, np.NaN, eurodfaccuracy['id_2'])

eurodfaccuracy['id_3'] = np.where(eurodfaccuracy['id_3'] <= 1800, np.NaN, eurodfaccuracy['id_3'])
eurodfaccuracy['id_3'] = np.where(eurodfaccuracy['id_3'] >= 1803, np.NaN, eurodfaccuracy['id_3'])

eurodfaccuracy['id_4'] = np.where(eurodfaccuracy['id_4'] <= 1800, np.NaN, eurodfaccuracy['id_4'])
eurodfaccuracy['id_4'] = np.where(eurodfaccuracy['id_4'] >= 1803, np.NaN, eurodfaccuracy['id_4'])
    
# apply function to DataFrame and create new column
eurodfaccuracy['Accuracy'] = eurodfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodfaccuracy['Accuracy'] = eurodfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
eurodfaccuracy['Accuracy'] = eurodfaccuracy['Accuracy'].astype(int)

# remove original columns
eurodfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
eurodfinterception=eurodf.copy()
eurodfinterception['id_1'] = np.where(eurodfinterception['id_1'] <= 1400, np.NaN, eurodfinterception['id_1'])
eurodfinterception['id_1'] = np.where(eurodfinterception['id_1'] >= 1402, np.NaN, eurodfinterception['id_1'])

eurodfinterception['id_2'] = np.where(eurodfinterception['id_2'] <= 1400, np.NaN, eurodfinterception['id_2'])
eurodfinterception['id_2'] = np.where(eurodfinterception['id_2'] >= 1402, np.NaN, eurodfinterception['id_2'])

eurodfinterception['id_3'] = np.where(eurodfinterception['id_3'] <= 1400, np.NaN, eurodfinterception['id_3'])
eurodfinterception['id_3'] = np.where(eurodfinterception['id_3'] >= 1402, np.NaN, eurodfinterception['id_3'])

eurodfinterception['id_4'] = np.where(eurodfinterception['id_4'] <= 1400, np.NaN, eurodfinterception['id_4'])
eurodfinterception['id_4'] = np.where(eurodfinterception['id_4'] >= 1402, np.NaN, eurodfinterception['id_4'])

eurodfinterception['id_5'] = np.where(eurodfinterception['id_5'] <= 1400, np.NaN, eurodfinterception['id_5'])
eurodfinterception['id_5'] = np.where(eurodfinterception['id_5'] >= 1402, np.NaN, eurodfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
eurodfinterception['interception'] = eurodfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodfinterception['interception'] = eurodfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
eurodfinterception['interception'] = eurodfinterception['interception'].astype(int)

# remove original columns
eurodfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
eurodfassist = eurodf.copy()
eurodfassist['id_1'] = np.where(eurodfassist['id_1'] <= 300, np.NaN, eurodfassist['id_1'])
eurodfassist['id_1'] = np.where(eurodfassist['id_1'] >= 303, np.NaN, eurodfassist['id_1'])

eurodfassist['id_2'] = np.where(eurodfassist['id_2'] <= 300, np.NaN, eurodfassist['id_2'])
eurodfassist['id_2'] = np.where(eurodfassist['id_2'] >= 303, np.NaN, eurodfassist['id_2'])

eurodfassist['id_3'] = np.where(eurodfassist['id_3'] <= 300, np.NaN, eurodfassist['id_3'])
eurodfassist['id_3'] = np.where(eurodfassist['id_3'] >= 303, np.NaN, eurodfassist['id_3'])

eurodfassist['id_4'] = np.where(eurodfassist['id_4'] <= 300, np.NaN, eurodfassist['id_4'])
eurodfassist['id_4'] = np.where(eurodfassist['id_4'] >= 303, np.NaN, eurodfassist['id_4'])

eurodfassist['id_5'] = np.where(eurodfassist['id_5'] <= 300, np.NaN, eurodfassist['id_5'])
eurodfassist['id_5'] = np.where(eurodfassist['id_5'] >= 303, np.NaN, eurodfassist['id_5'])
    
# apply function to DataFrame and create new column
eurodfassist['assist'] = eurodfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodfassist['assist'] = eurodfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
eurodfassist['assist'] = eurodfassist['assist'].astype(int)

# remove original columns
eurodfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
eurodfthrough = eurodf.copy()
eurodfthrough['id_1'] = np.where(eurodfthrough['id_1'] <= 900, np.NaN, eurodfthrough['id_1'])
eurodfthrough['id_1'] = np.where(eurodfthrough['id_1'] >= 902, np.NaN, eurodfthrough['id_1'])

eurodfthrough['id_2'] = np.where(eurodfthrough['id_2'] <= 900, np.NaN, eurodfthrough['id_2'])
eurodfthrough['id_2'] = np.where(eurodfthrough['id_2'] >= 902, np.NaN, eurodfthrough['id_2'])

eurodfthrough['id_3'] = np.where(eurodfthrough['id_3'] <= 900, np.NaN, eurodfthrough['id_3'])
eurodfthrough['id_3'] = np.where(eurodfthrough['id_3'] >= 902, np.NaN, eurodfthrough['id_3'])

eurodfthrough['id_4'] = np.where(eurodfthrough['id_4'] <= 900, np.NaN, eurodfthrough['id_4'])
eurodfthrough['id_4'] = np.where(eurodfthrough['id_4'] >= 902, np.NaN, eurodfthrough['id_4'])

eurodfthrough['id_5'] = np.where(eurodfthrough['id_5'] <= 900, np.NaN, eurodfthrough['id_5'])
eurodfthrough['id_5'] = np.where(eurodfthrough['id_5'] >= 902, np.NaN, eurodfthrough['id_5'])

# apply function to DataFrame and create new column
eurodfthrough['through'] = eurodfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodfthrough['through'] = eurodfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
eurodfthrough['through'] = eurodfthrough['through'].astype(int)

# remove original columns
eurodfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
eurodfdribble= eurodf.copy()
eurodfdribble['id_1'] = np.where(eurodfdribble['id_1'] <= 502, np.NaN, eurodfdribble['id_1'])
eurodfdribble['id_1'] = np.where(eurodfdribble['id_1'] >= 505, np.NaN, eurodfdribble['id_1'])

eurodfdribble['id_2'] = np.where(eurodfdribble['id_2'] <= 502, np.NaN, eurodfdribble['id_2'])
eurodfdribble['id_2'] = np.where(eurodfdribble['id_2'] >= 505, np.NaN, eurodfdribble['id_2'])

eurodfdribble['id_3'] = np.where(eurodfdribble['id_3'] <= 502, np.NaN, eurodfdribble['id_3'])
eurodfdribble['id_3'] = np.where(eurodfdribble['id_3'] >= 505, np.NaN, eurodfdribble['id_3'])

eurodfdribble['id_4'] = np.where(eurodfdribble['id_4'] <= 502, np.NaN, eurodfdribble['id_4'])
eurodfdribble['id_4'] = np.where(eurodfdribble['id_4'] >= 505, np.NaN, eurodfdribble['id_4'])

eurodfdribble['id_5'] = np.where(eurodfdribble['id_5'] <= 502, np.NaN, eurodfdribble['id_5'])
eurodfdribble['id_5'] = np.where(eurodfdribble['id_5'] >= 505, np.NaN, eurodfdribble['id_5'])
    
    
# apply function to DataFrame and create new column
eurodfdribble['dribble'] = eurodfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodfdribble['dribble'] = eurodfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
eurodfdribble['dribble'] = eurodfdribble['dribble'].astype(int)

# remove original columns
eurodfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
eurodftackle=eurodf.copy()
eurodftackle['id_1'] = np.where(eurodftackle['id_1'] <= 1600, np.NaN, eurodftackle['id_1'])
eurodftackle['id_1'] = np.where(eurodftackle['id_1'] >= 1602, np.NaN, eurodftackle['id_1'])

eurodftackle['id_2'] = np.where(eurodftackle['id_2'] <= 1600, np.NaN, eurodftackle['id_2'])
eurodftackle['id_2'] = np.where(eurodftackle['id_2'] >= 1602, np.NaN, eurodftackle['id_2'])

eurodftackle['id_3'] = np.where(eurodftackle['id_3'] <= 1600, np.NaN, eurodftackle['id_3'])
eurodftackle['id_3'] = np.where(eurodftackle['id_3'] >= 1602, np.NaN, eurodftackle['id_3'])

eurodftackle['id_4'] = np.where(eurodftackle['id_4'] <= 1600, np.NaN, eurodftackle['id_4'])
eurodftackle['id_4'] = np.where(eurodftackle['id_4'] >= 1602, np.NaN, eurodftackle['id_4'])

eurodftackle['id_5'] = np.where(eurodftackle['id_5'] <= 1600, np.NaN, eurodftackle['id_5'])
eurodftackle['id_5'] = np.where(eurodftackle['id_5'] >= 1602, np.NaN, eurodftackle['id_5'])
    
    
# apply function to DataFrame and create new column
eurodftackle['tackle'] = eurodftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodftackle['tackle'] = eurodftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
eurodftackle['tackle'] = eurodftackle['tackle'].astype(int)

# remove original columns
eurodftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
    
eurodfgoalPos=eurodf.copy()
eurodfgoalPos['id_1'] = np.where(eurodfgoalPos['id_1'] <= 1200, np.NaN, eurodfgoalPos['id_1'])
eurodfgoalPos['id_1'] = np.where(eurodfgoalPos['id_1'] >= 1210, np.NaN, eurodfgoalPos['id_1'])

eurodfgoalPos['id_2'] = np.where(eurodfgoalPos['id_2'] <= 1200, np.NaN, eurodfgoalPos['id_2'])
eurodfgoalPos['id_2'] = np.where(eurodfgoalPos['id_2'] >= 1210, np.NaN, eurodfgoalPos['id_2'])

eurodfgoalPos['id_3'] = np.where(eurodfgoalPos['id_3'] <= 1200, np.NaN, eurodfgoalPos['id_3'])
eurodfgoalPos['id_3'] = np.where(eurodfgoalPos['id_3'] >= 1210, np.NaN, eurodfgoalPos['id_3'])

eurodfgoalPos['id_4'] = np.where(eurodfgoalPos['id_4'] <= 1200, np.NaN, eurodfgoalPos['id_4'])
eurodfgoalPos['id_4'] = np.where(eurodfgoalPos['id_4'] >= 1210, np.NaN, eurodfgoalPos['id_4'])

eurodfgoalPos['id_5'] = np.where(eurodfgoalPos['id_5'] <= 1200, np.NaN, eurodfgoalPos['id_5'])
eurodfgoalPos['id_5'] = np.where(eurodfgoalPos['id_5'] >= 1210, np.NaN, eurodfgoalPos['id_5'])
    
    
# apply function to DataFrame and create new column
eurodfgoalPos['goalPos'] = eurodfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
eurodfgoalPos['goalPos'] = eurodfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
eurodfgoalPos['goalPos'] = eurodfgoalPos['goalPos'].astype(int)

# remove original columns
eurodfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


eurodf = eurodf.join([eurodfaccuracy['Accuracy'], eurodfinterception['interception'], eurodfassist['assist'], eurodfthrough['through'], eurodfdribble['dribble'],
                   eurodftackle['tackle'], eurodfgoalPos['goalPos']])


eurodf=eurodf.rename(columns={5:'non'})
eurodf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)
eurodf['To x - From x']=eurodf['To X']-eurodf['From X']
eurodf['To y - From y']=eurodf['To y']-eurodf['From y']
eurodf['Angle']=np.degrees(np.arctan2(eurodf['To y - From y'],eurodf['To x - From x']))
eurodf['Position'] = ['Left' if x < 0 else 'Right' for x in eurodf['Angle']]
eurodf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in eurodf['Angle']]
eurodf['distance']= (((eurodf['To X']-eurodf['From X'])**2)+((eurodf['To y']-eurodf['From y'])**2))**0.5














### World Cup
worlddf=pd.read_json('events_World_Cup.json')
## Extracting the coordinates and put them in to multiple columns 
worlddf= pd.concat([worlddf['positions'].apply(pd.Series), worlddf.drop('positions', axis = 1)], axis =1)
worlddf=worlddf.rename(columns={0:'from',1:'to'})
worlddf= pd.concat([worlddf['from'].apply(pd.Series), worlddf.drop('from', axis = 1)], axis =1)
worlddf=worlddf.rename(columns={'x':'From X','y':'From y'})
worlddf= pd.concat([worlddf['to'].apply(pd.Series), worlddf.drop('to', axis = 1)], axis =1)
worlddf=worlddf.rename(columns={'x':'To X','y':'To y'})
worlddf=worlddf.rename(columns={0:'f'})
worlddf=worlddf.drop(['f'],axis=1)

    
## Extracting the Tags and put them in two multiple columns 
worlddf=worlddf.rename(columns={'id':'id_0'})

worlddf= pd.concat([worlddf['tags'].apply(pd.Series), worlddf.drop('tags', axis = 1)], axis =1)
worlddf=worlddf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
worlddf= pd.concat([worlddf['zero'].apply(pd.Series), worlddf.drop('zero', axis = 1)], axis =1)
worlddf=worlddf.rename(columns={'id':'id_1'})
worlddf= pd.concat([worlddf['one'].apply(pd.Series), worlddf.drop('one', axis = 1)], axis =1)
    

worlddf=worlddf.rename(columns={'id':'id_2',0:'a'})
worlddf=worlddf.dropna(axis=1,how='all')
worlddf= pd.concat([worlddf['two'].apply(pd.Series), worlddf.drop('two', axis = 1)], axis =1)


worlddf=worlddf.rename(columns={'id':'id_3',0:'a'})
worlddf=worlddf.dropna(axis=1,how='all')
worlddf= pd.concat([worlddf['three'].apply(pd.Series), worlddf.drop('three', axis = 1)], axis =1)


worlddf=worlddf.rename(columns={'id':'id_4',0:'a'})
worlddf=worlddf.dropna(axis=1,how='all')
worlddf= pd.concat([worlddf['four'].apply(pd.Series), worlddf.drop('four', axis = 1)], axis =1)

    
worlddf=worlddf.rename(columns={'id':'id_5',0:'a'})
worlddf=worlddf.dropna(axis=1,how='all')

    
    
## Removing all tags except only tags related to Accuracy 
worlddfaccuracy=worlddf.copy()
worlddfaccuracy['id_1'] = np.where(worlddfaccuracy['id_1'] <= 1800, np.NaN, worlddfaccuracy['id_1'])
worlddfaccuracy['id_1'] = np.where(worlddfaccuracy['id_1'] >= 1803, np.NaN, worlddfaccuracy['id_1'])

worlddfaccuracy['id_2'] = np.where(worlddfaccuracy['id_2'] <= 1800, np.NaN, worlddfaccuracy['id_2'])
worlddfaccuracy['id_2'] = np.where(worlddfaccuracy['id_2'] >= 1803, np.NaN, worlddfaccuracy['id_2'])

worlddfaccuracy['id_3'] = np.where(worlddfaccuracy['id_3'] <= 1800, np.NaN, worlddfaccuracy['id_3'])
worlddfaccuracy['id_3'] = np.where(worlddfaccuracy['id_3'] >= 1803, np.NaN, worlddfaccuracy['id_3'])

worlddfaccuracy['id_4'] = np.where(worlddfaccuracy['id_4'] <= 1800, np.NaN, worlddfaccuracy['id_4'])
worlddfaccuracy['id_4'] = np.where(worlddfaccuracy['id_4'] >= 1803, np.NaN, worlddfaccuracy['id_4'])
    
# apply function to DataFrame and create new column
worlddfaccuracy['Accuracy'] = worlddfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddfaccuracy['Accuracy'] = worlddfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
worlddfaccuracy['Accuracy'] = worlddfaccuracy['Accuracy'].astype(int)

# remove original columns
worlddfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
worlddfinterception=worlddf.copy()
worlddfinterception['id_1'] = np.where(worlddfinterception['id_1'] <= 1400, np.NaN, worlddfinterception['id_1'])
worlddfinterception['id_1'] = np.where(worlddfinterception['id_1'] >= 1402, np.NaN, worlddfinterception['id_1'])

worlddfinterception['id_2'] = np.where(worlddfinterception['id_2'] <= 1400, np.NaN, worlddfinterception['id_2'])
worlddfinterception['id_2'] = np.where(worlddfinterception['id_2'] >= 1402, np.NaN, worlddfinterception['id_2'])

worlddfinterception['id_3'] = np.where(worlddfinterception['id_3'] <= 1400, np.NaN, worlddfinterception['id_3'])
worlddfinterception['id_3'] = np.where(worlddfinterception['id_3'] >= 1402, np.NaN, worlddfinterception['id_3'])

worlddfinterception['id_4'] = np.where(worlddfinterception['id_4'] <= 1400, np.NaN, worlddfinterception['id_4'])
worlddfinterception['id_4'] = np.where(worlddfinterception['id_4'] >= 1402, np.NaN, worlddfinterception['id_4'])

worlddfinterception['id_5'] = np.where(worlddfinterception['id_5'] <= 1400, np.NaN, worlddfinterception['id_5'])
worlddfinterception['id_5'] = np.where(worlddfinterception['id_5'] >= 1402, np.NaN, worlddfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
worlddfinterception['interception'] = worlddfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddfinterception['interception'] = worlddfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
worlddfinterception['interception'] = worlddfinterception['interception'].astype(int)

# remove original columns
worlddfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
worlddfassist = worlddf.copy()
worlddfassist['id_1'] = np.where(worlddfassist['id_1'] <= 300, np.NaN, worlddfassist['id_1'])
worlddfassist['id_1'] = np.where(worlddfassist['id_1'] >= 303, np.NaN, worlddfassist['id_1'])

worlddfassist['id_2'] = np.where(worlddfassist['id_2'] <= 300, np.NaN, worlddfassist['id_2'])
worlddfassist['id_2'] = np.where(worlddfassist['id_2'] >= 303, np.NaN, worlddfassist['id_2'])

worlddfassist['id_3'] = np.where(worlddfassist['id_3'] <= 300, np.NaN, worlddfassist['id_3'])
worlddfassist['id_3'] = np.where(worlddfassist['id_3'] >= 303, np.NaN, worlddfassist['id_3'])

worlddfassist['id_4'] = np.where(worlddfassist['id_4'] <= 300, np.NaN, worlddfassist['id_4'])
worlddfassist['id_4'] = np.where(worlddfassist['id_4'] >= 303, np.NaN, worlddfassist['id_4'])

worlddfassist['id_5'] = np.where(worlddfassist['id_5'] <= 300, np.NaN, worlddfassist['id_5'])
worlddfassist['id_5'] = np.where(worlddfassist['id_5'] >= 303, np.NaN, worlddfassist['id_5'])
    
# apply function to DataFrame and create new column
worlddfassist['assist'] = worlddfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddfassist['assist'] = worlddfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
worlddfassist['assist'] = worlddfassist['assist'].astype(int)

# remove original columns
worlddfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
worlddfthrough = worlddf.copy()
worlddfthrough['id_1'] = np.where(worlddfthrough['id_1'] <= 900, np.NaN, worlddfthrough['id_1'])
worlddfthrough['id_1'] = np.where(worlddfthrough['id_1'] >= 902, np.NaN, worlddfthrough['id_1'])

worlddfthrough['id_2'] = np.where(worlddfthrough['id_2'] <= 900, np.NaN, worlddfthrough['id_2'])
worlddfthrough['id_2'] = np.where(worlddfthrough['id_2'] >= 902, np.NaN, worlddfthrough['id_2'])

worlddfthrough['id_3'] = np.where(worlddfthrough['id_3'] <= 900, np.NaN, worlddfthrough['id_3'])
worlddfthrough['id_3'] = np.where(worlddfthrough['id_3'] >= 902, np.NaN, worlddfthrough['id_3'])

worlddfthrough['id_4'] = np.where(worlddfthrough['id_4'] <= 900, np.NaN, worlddfthrough['id_4'])
worlddfthrough['id_4'] = np.where(worlddfthrough['id_4'] >= 902, np.NaN, worlddfthrough['id_4'])

worlddfthrough['id_5'] = np.where(worlddfthrough['id_5'] <= 900, np.NaN, worlddfthrough['id_5'])
worlddfthrough['id_5'] = np.where(worlddfthrough['id_5'] >= 902, np.NaN, worlddfthrough['id_5'])

# apply function to DataFrame and create new column
worlddfthrough['through'] = worlddfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddfthrough['through'] = worlddfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
worlddfthrough['through'] = worlddfthrough['through'].astype(int)

# remove original columns
worlddfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
worlddfdribble= worlddf.copy()
worlddfdribble['id_1'] = np.where(worlddfdribble['id_1'] <= 502, np.NaN, worlddfdribble['id_1'])
worlddfdribble['id_1'] = np.where(worlddfdribble['id_1'] >= 505, np.NaN, worlddfdribble['id_1'])

worlddfdribble['id_2'] = np.where(worlddfdribble['id_2'] <= 502, np.NaN, worlddfdribble['id_2'])
worlddfdribble['id_2'] = np.where(worlddfdribble['id_2'] >= 505, np.NaN, worlddfdribble['id_2'])

worlddfdribble['id_3'] = np.where(worlddfdribble['id_3'] <= 502, np.NaN, worlddfdribble['id_3'])
worlddfdribble['id_3'] = np.where(worlddfdribble['id_3'] >= 505, np.NaN, worlddfdribble['id_3'])

worlddfdribble['id_4'] = np.where(worlddfdribble['id_4'] <= 502, np.NaN, worlddfdribble['id_4'])
worlddfdribble['id_4'] = np.where(worlddfdribble['id_4'] >= 505, np.NaN, worlddfdribble['id_4'])

worlddfdribble['id_5'] = np.where(worlddfdribble['id_5'] <= 502, np.NaN, worlddfdribble['id_5'])
worlddfdribble['id_5'] = np.where(worlddfdribble['id_5'] >= 505, np.NaN, worlddfdribble['id_5'])
    
    
# apply function to DataFrame and create new column
worlddfdribble['dribble'] = worlddfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddfdribble['dribble'] = worlddfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
worlddfdribble['dribble'] = worlddfdribble['dribble'].astype(int)

# remove original columns
worlddfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
worlddftackle=worlddf.copy()
worlddftackle['id_1'] = np.where(worlddftackle['id_1'] <= 1600, np.NaN, worlddftackle['id_1'])
worlddftackle['id_1'] = np.where(worlddftackle['id_1'] >= 1602, np.NaN, worlddftackle['id_1'])

worlddftackle['id_2'] = np.where(worlddftackle['id_2'] <= 1600, np.NaN, worlddftackle['id_2'])
worlddftackle['id_2'] = np.where(worlddftackle['id_2'] >= 1602, np.NaN, worlddftackle['id_2'])

worlddftackle['id_3'] = np.where(worlddftackle['id_3'] <= 1600, np.NaN, worlddftackle['id_3'])
worlddftackle['id_3'] = np.where(worlddftackle['id_3'] >= 1602, np.NaN, worlddftackle['id_3'])

worlddftackle['id_4'] = np.where(worlddftackle['id_4'] <= 1600, np.NaN, worlddftackle['id_4'])
worlddftackle['id_4'] = np.where(worlddftackle['id_4'] >= 1602, np.NaN, worlddftackle['id_4'])

worlddftackle['id_5'] = np.where(worlddftackle['id_5'] <= 1600, np.NaN, worlddftackle['id_5'])
worlddftackle['id_5'] = np.where(worlddftackle['id_5'] >= 1602, np.NaN, worlddftackle['id_5'])
    
    
# apply function to DataFrame and create new column
worlddftackle['tackle'] = worlddftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddftackle['tackle'] = worlddftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
worlddftackle['tackle'] = worlddftackle['tackle'].astype(int)

# remove original columns
worlddftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
    
worlddfgoalPos=worlddf.copy()
worlddfgoalPos['id_1'] = np.where(worlddfgoalPos['id_1'] <= 1200, np.NaN, worlddfgoalPos['id_1'])
worlddfgoalPos['id_1'] = np.where(worlddfgoalPos['id_1'] >= 1210, np.NaN, worlddfgoalPos['id_1'])

worlddfgoalPos['id_2'] = np.where(worlddfgoalPos['id_2'] <= 1200, np.NaN, worlddfgoalPos['id_2'])
worlddfgoalPos['id_2'] = np.where(worlddfgoalPos['id_2'] >= 1210, np.NaN, worlddfgoalPos['id_2'])

worlddfgoalPos['id_3'] = np.where(worlddfgoalPos['id_3'] <= 1200, np.NaN, worlddfgoalPos['id_3'])
worlddfgoalPos['id_3'] = np.where(worlddfgoalPos['id_3'] >= 1210, np.NaN, worlddfgoalPos['id_3'])

worlddfgoalPos['id_4'] = np.where(worlddfgoalPos['id_4'] <= 1200, np.NaN, worlddfgoalPos['id_4'])
worlddfgoalPos['id_4'] = np.where(worlddfgoalPos['id_4'] >= 1210, np.NaN, worlddfgoalPos['id_4'])

worlddfgoalPos['id_5'] = np.where(worlddfgoalPos['id_5'] <= 1200, np.NaN, worlddfgoalPos['id_5'])
worlddfgoalPos['id_5'] = np.where(worlddfgoalPos['id_5'] >= 1210, np.NaN, worlddfgoalPos['id_5'])
    
    
# apply function to DataFrame and create new column
worlddfgoalPos['goalPos'] = worlddfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
worlddfgoalPos['goalPos'] = worlddfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
worlddfgoalPos['goalPos'] = worlddfgoalPos['goalPos'].astype(int)

# remove original columns
worlddfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


worlddf = worlddf.join([worlddfaccuracy['Accuracy'], worlddfinterception['interception'], worlddfassist['assist'], worlddfthrough['through'], worlddfdribble['dribble'],
                   worlddftackle['tackle'], worlddfgoalPos['goalPos']])


worlddf=worlddf.rename(columns={5:'non'})
worlddf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)
worlddf['To x - From x']=worlddf['To X']-worlddf['From X']
worlddf['To y - From y']=worlddf['To y']-worlddf['From y']
worlddf['Angle']=np.degrees(np.arctan2(worlddf['To y - From y'],worlddf['To x - From x']))
worlddf['Position'] = ['Left' if x < 0 else 'Right' for x in worlddf['Angle']]
worlddf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in worlddf['Angle']]
worlddf['distance']= (((worlddf['To X']-worlddf['From X'])**2)+((worlddf['To y']-worlddf['From y'])**2))**0.5

# %% [markdown]
# # Germany Players Stats

# %%
germanydf = pd.read_json('events_Germany.json')
# Extracting the coordinates and put them into multiple columns
# Split the "positions" column into two separate columns "from" and "to"
germanydf = pd.concat([germanydf['positions'].apply(pd.Series), germanydf.drop('positions', axis = 1)], axis =1)
# Rename the columns to more descriptive names
germanydf = germanydf.rename(columns={0:'from',1:'to'})
# Split the "from" column into two separate columns "From X" and "From y"
germanydf = pd.concat([germanydf['from'].apply(pd.Series), germanydf.drop('from', axis = 1)], axis =1)
germanydf = germanydf.rename(columns={'x':'From X','y':'From y'})
# Split the "to" column into two separate columns "To X" and "To y"
germanydf = pd.concat([germanydf['to'].apply(pd.Series), germanydf.drop('to', axis = 1)], axis =1)
germanydf = germanydf.rename(columns={'x':'To X','y':'To y'})
# Drop the "f" column
germanydf = germanydf.rename(columns={0:'f'})
germanydf = germanydf.drop(['f'], axis=1)

# Extracting the tags and put them into multiple columns
germanydf=germanydf.rename(columns={'id':'id_0'})

germanydf= pd.concat([germanydf['tags'].apply(pd.Series), germanydf.drop('tags', axis = 1)], axis =1)
germanydf=germanydf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
germanydf= pd.concat([germanydf['zero'].apply(pd.Series), germanydf.drop('zero', axis = 1)], axis =1)
germanydf=germanydf.rename(columns={'id':'id_1'})
germanydf= pd.concat([germanydf['one'].apply(pd.Series), germanydf.drop('one', axis = 1)], axis =1)


germanydf=germanydf.rename(columns={'id':'id_2',0:'a'})
germanydf=germanydf.dropna(axis=1,how='all')
germanydf= pd.concat([germanydf['two'].apply(pd.Series), germanydf.drop('two', axis = 1)], axis =1)


germanydf=germanydf.rename(columns={'id':'id_3',0:'a'})
germanydf=germanydf.dropna(axis=1,how='all')
germanydf= pd.concat([germanydf['three'].apply(pd.Series), germanydf.drop('three', axis = 1)], axis =1)


germanydf=germanydf.rename(columns={'id':'id_4',0:'a'})
germanydf=germanydf.dropna(axis=1,how='all')
germanydf= pd.concat([germanydf['four'].apply(pd.Series), germanydf.drop('four', axis = 1)], axis =1)

    
germanydf=germanydf.rename(columns={'id':'id_5',0:'a'})
germanydf=germanydf.dropna(axis=1,how='all')


## Removing all tags except only tags related to Accuracy 
# Create a copy of germanydf dataframe 
# Set values less than or equal to 1800 and greater than or equal to 1803 to NaN in all columns
germanydfaccuracy = germanydf.copy()
germanydfaccuracy['id_1'] = np.where(germanydfaccuracy['id_1'] <= 1800, np.NaN, germanydfaccuracy['id_1'])
germanydfaccuracy['id_1'] = np.where(germanydfaccuracy['id_1'] >= 1803, np.NaN, germanydfaccuracy['id_1'])

germanydfaccuracy['id_2'] = np.where(germanydfaccuracy['id_2'] <= 1800, np.NaN, germanydfaccuracy['id_2'])
germanydfaccuracy['id_2'] = np.where(germanydfaccuracy['id_2'] >= 1803, np.NaN, germanydfaccuracy['id_2'])

germanydfaccuracy['id_3'] = np.where(germanydfaccuracy['id_3'] <= 1800, np.NaN, germanydfaccuracy['id_3'])
germanydfaccuracy['id_3'] = np.where(germanydfaccuracy['id_3'] >= 1803, np.NaN, germanydfaccuracy['id_3'])

germanydfaccuracy['id_4'] = np.where(germanydfaccuracy['id_4'] <= 1800, np.NaN, germanydfaccuracy['id_4'])
germanydfaccuracy['id_4'] = np.where(germanydfaccuracy['id_4'] >= 1803, np.NaN, germanydfaccuracy['id_4'])

# apply function to DataFrame and create new column
germanydfaccuracy['Accuracy'] = germanydfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfaccuracy['Accuracy'] = germanydfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
germanydfaccuracy['Accuracy'] = germanydfaccuracy['Accuracy'].astype(int)

# remove original columns
germanydfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)



# Create a copy of germanydf dataframe 
# Set values less than or equal to 1400 and greater than or equal to 1402 to NaN in all columns    
germanydfinterception = germanydf.copy()
germanydfinterception['id_1'] = np.where(germanydfinterception['id_1'] <= 1400, np.NaN, germanydfinterception['id_1'])
germanydfinterception['id_1'] = np.where(germanydfinterception['id_1'] >= 1402, np.NaN, germanydfinterception['id_1'])

germanydfinterception['id_2'] = np.where(germanydfinterception['id_2'] <= 1400, np.NaN, germanydfinterception['id_2'])
germanydfinterception['id_2'] = np.where(germanydfinterception['id_2'] >= 1402, np.NaN, germanydfinterception['id_2'])

germanydfinterception['id_3'] = np.where(germanydfinterception['id_3'] <= 1400, np.NaN, germanydfinterception['id_3'])
germanydfinterception['id_3'] = np.where(germanydfinterception['id_3'] >= 1402, np.NaN, germanydfinterception['id_3'])

germanydfinterception['id_4'] = np.where(germanydfinterception['id_4'] <= 1400, np.NaN, germanydfinterception['id_4'])
germanydfinterception['id_4'] = np.where(germanydfinterception['id_4'] >= 1402, np.NaN, germanydfinterception['id_4'])

germanydfinterception['id_5'] = np.where(germanydfinterception['id_5'] <= 1400, np.NaN, germanydfinterception['id_5'])
germanydfinterception['id_5'] = np.where(germanydfinterception['id_5'] >= 1402, np.NaN, germanydfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
germanydfinterception['interception'] = germanydfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfinterception['interception'] = germanydfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
germanydfinterception['interception'] = germanydfinterception['interception'].astype(int)

# remove original columns
germanydfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    

# Create a copy of germanydf dataframe 
# Set values less than or equal to 300 and greater than or equal to 303 to NaN in all columns    
germanydfassist = germanydf.copy()
germanydfassist['id_1'] = np.where(germanydfassist['id_1'] <= 300, np.NaN, germanydfassist['id_1'])
germanydfassist['id_1'] = np.where(germanydfassist['id_1'] >= 303, np.NaN, germanydfassist['id_1'])

germanydfassist['id_2'] = np.where(germanydfassist['id_2'] <= 300, np.NaN, germanydfassist['id_2'])
germanydfassist['id_2'] = np.where(germanydfassist['id_2'] >= 303, np.NaN, germanydfassist['id_2'])

germanydfassist['id_3'] = np.where(germanydfassist['id_3'] <= 300, np.NaN, germanydfassist['id_3'])
germanydfassist['id_3'] = np.where(germanydfassist['id_3'] >= 303, np.NaN, germanydfassist['id_3'])

germanydfassist['id_4'] = np.where(germanydfassist['id_4'] <= 300, np.NaN, germanydfassist['id_4'])
germanydfassist['id_4'] = np.where(germanydfassist['id_4'] >= 303, np.NaN, germanydfassist['id_4'])

germanydfassist['id_5'] = np.where(germanydfassist['id_5'] <= 300, np.NaN, germanydfassist['id_5'])
germanydfassist['id_5'] = np.where(germanydfassist['id_5'] >= 303, np.NaN, germanydfassist['id_5'])

# apply function to DataFrame and create new column
germanydfassist['assist'] = germanydfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfassist['assist'] = germanydfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
germanydfassist['assist'] = germanydfassist['assist'].astype(int)

# remove original columns
germanydfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of germanydf dataframe 
# Set values less than or equal to 900 and greater than or equal to 902 to NaN in all columns
germanydfthrough = germanydf.copy()
germanydfthrough['id_1'] = np.where(germanydfthrough['id_1'] <= 900, np.NaN, germanydfthrough['id_1'])
germanydfthrough['id_1'] = np.where(germanydfthrough['id_1'] >= 902, np.NaN, germanydfthrough['id_1'])

germanydfthrough['id_2'] = np.where(germanydfthrough['id_2'] <= 900, np.NaN, germanydfthrough['id_2'])
germanydfthrough['id_2'] = np.where(germanydfthrough['id_2'] >= 902, np.NaN, germanydfthrough['id_2'])

germanydfthrough['id_3'] = np.where(germanydfthrough['id_3'] <= 900, np.NaN, germanydfthrough['id_3'])
germanydfthrough['id_3'] = np.where(germanydfthrough['id_3'] >= 902, np.NaN, germanydfthrough['id_3'])

germanydfthrough['id_4'] = np.where(germanydfthrough['id_4'] <= 900, np.NaN, germanydfthrough['id_4'])
germanydfthrough['id_4'] = np.where(germanydfthrough['id_4'] >= 902, np.NaN, germanydfthrough['id_4'])

germanydfthrough['id_5'] = np.where(germanydfthrough['id_5'] <= 900, np.NaN, germanydfthrough['id_5'])
germanydfthrough['id_5'] = np.where(germanydfthrough['id_5'] >= 902, np.NaN, germanydfthrough['id_5'])

# apply function to DataFrame and create new column
germanydfthrough['through'] = germanydfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfthrough['through'] = germanydfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
germanydfthrough['through'] = germanydfthrough['through'].astype(int)

# remove original columns
germanydfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of germanydf dataframe 
# Set values less than or equal to 502 and greater than or equal to 505 to NaN in all columns    
germanydfdribble= germanydf.copy()
germanydfdribble['id_1'] = np.where(germanydfdribble['id_1'] <= 502, np.NaN, germanydfdribble['id_1'])
germanydfdribble['id_1'] = np.where(germanydfdribble['id_1'] >= 505, np.NaN, germanydfdribble['id_1'])

germanydfdribble['id_2'] = np.where(germanydfdribble['id_2'] <= 502, np.NaN, germanydfdribble['id_2'])
germanydfdribble['id_2'] = np.where(germanydfdribble['id_2'] >= 505, np.NaN, germanydfdribble['id_2'])

germanydfdribble['id_3'] = np.where(germanydfdribble['id_3'] <= 502, np.NaN, germanydfdribble['id_3'])
germanydfdribble['id_3'] = np.where(germanydfdribble['id_3'] >= 505, np.NaN, germanydfdribble['id_3'])

germanydfdribble['id_4'] = np.where(germanydfdribble['id_4'] <= 502, np.NaN, germanydfdribble['id_4'])
germanydfdribble['id_4'] = np.where(germanydfdribble['id_4'] >= 505, np.NaN, germanydfdribble['id_4'])

germanydfdribble['id_5'] = np.where(germanydfdribble['id_5'] <= 502, np.NaN, germanydfdribble['id_5'])
germanydfdribble['id_5'] = np.where(germanydfdribble['id_5'] >= 505, np.NaN, germanydfdribble['id_5'])

# apply function to DataFrame and create new column
germanydfdribble['dribble'] = germanydfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfdribble['dribble'] = germanydfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
germanydfdribble['dribble'] = germanydfdribble['dribble'].astype(int)

# remove original columns
germanydfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of Germany dataframe
# Set values less than or equal to 1600 and greater than or equal to 1602 to NaN in all columns
germanydftackle = germanydf.copy()
germanydftackle['id_1'] = np.where(germanydftackle['id_1'] <= 1600, np.NaN, germanydftackle['id_1'])
germanydftackle['id_1'] = np.where(germanydftackle['id_1'] >= 1602, np.NaN, germanydftackle['id_1'])

germanydftackle['id_2'] = np.where(germanydftackle['id_2'] <= 1600, np.NaN, germanydftackle['id_2'])
germanydftackle['id_2'] = np.where(germanydftackle['id_2'] >= 1602, np.NaN, germanydftackle['id_2'])

germanydftackle['id_3'] = np.where(germanydftackle['id_3'] <= 1600, np.NaN, germanydftackle['id_3'])
germanydftackle['id_3'] = np.where(germanydftackle['id_3'] >= 1602, np.NaN, germanydftackle['id_3'])

germanydftackle['id_4'] = np.where(germanydftackle['id_4'] <= 1600, np.NaN, germanydftackle['id_4'])
germanydftackle['id_4'] = np.where(germanydftackle['id_4'] >= 1602, np.NaN, germanydftackle['id_4'])

germanydftackle['id_5'] = np.where(germanydftackle['id_5'] <= 1600, np.NaN, germanydftackle['id_5'])
germanydftackle['id_5'] = np.where(germanydftackle['id_5'] >= 1602, np.NaN, germanydftackle['id_5'])

# apply function to DataFrame and create new column
germanydftackle['tackle'] = germanydftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydftackle['tackle'] = germanydftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
germanydftackle['tackle'] = germanydftackle['tackle'].astype(int)

# remove original columns
germanydftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of Germany dataframe 
germanydfgoalPos=germanydf.copy()

# Set values less than or equal to 1200 and greater than or equal to 1210 to NaN in all columns    
germanydfgoalPos['id_1'] = np.where(germanydfgoalPos['id_1'] <= 1200, np.NaN, germanydfgoalPos['id_1'])
germanydfgoalPos['id_1'] = np.where(germanydfgoalPos['id_1'] >= 1210, np.NaN, germanydfgoalPos['id_1'])

germanydfgoalPos['id_2'] = np.where(germanydfgoalPos['id_2'] <= 1200, np.NaN, germanydfgoalPos['id_2'])
germanydfgoalPos['id_2'] = np.where(germanydfgoalPos['id_2'] >= 1210, np.NaN, germanydfgoalPos['id_2'])

germanydfgoalPos['id_3'] = np.where(germanydfgoalPos['id_3'] <= 1200, np.NaN, germanydfgoalPos['id_3'])
germanydfgoalPos['id_3'] = np.where(germanydfgoalPos['id_3'] >= 1210, np.NaN, germanydfgoalPos['id_3'])

germanydfgoalPos['id_4'] = np.where(germanydfgoalPos['id_4'] <= 1200, np.NaN, germanydfgoalPos['id_4'])
germanydfgoalPos['id_4'] = np.where(germanydfgoalPos['id_4'] >= 1210, np.NaN, germanydfgoalPos['id_4'])

germanydfgoalPos['id_5'] = np.where(germanydfgoalPos['id_5'] <= 1200, np.NaN, germanydfgoalPos['id_5'])
germanydfgoalPos['id_5'] = np.where(germanydfgoalPos['id_5'] >= 1210, np.NaN, germanydfgoalPos['id_5'])

# apply function to DataFrame and create new column
germanydfgoalPos['goalPos'] = germanydfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfgoalPos['goalPos'] = germanydfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
germanydfgoalPos['goalPos'] = germanydfgoalPos['goalPos'].astype(int)

# remove original columns
germanydfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)




germanydfcounterAttack=germanydf.copy()
germanydfcounterAttack['id_1'] = np.where(germanydfcounterAttack['id_1'] <= 1900, np.NaN, germanydfcounterAttack['id_1'])
germanydfcounterAttack['id_1'] = np.where(germanydfcounterAttack['id_1'] >= 1902, np.NaN, germanydfcounterAttack['id_1'])

germanydfcounterAttack['id_2'] = np.where(germanydfcounterAttack['id_2'] <= 1900, np.NaN, germanydfcounterAttack['id_2'])
germanydfcounterAttack['id_2'] = np.where(germanydfcounterAttack['id_2'] >= 1902, np.NaN, germanydfcounterAttack['id_2'])

germanydfcounterAttack['id_3'] = np.where(germanydfcounterAttack['id_3'] <= 1900, np.NaN, germanydfcounterAttack['id_3'])
germanydfcounterAttack['id_3'] = np.where(germanydfcounterAttack['id_3'] >= 1902, np.NaN, germanydfcounterAttack['id_3'])

germanydfcounterAttack['id_4'] = np.where(germanydfcounterAttack['id_4'] <= 1900, np.NaN, germanydfcounterAttack['id_4'])
germanydfcounterAttack['id_4'] = np.where(germanydfcounterAttack['id_4'] >= 1902, np.NaN, germanydfcounterAttack['id_4'])

germanydfcounterAttack['id_5'] = np.where(germanydfcounterAttack['id_5'] <= 1900, np.NaN, germanydfcounterAttack['id_5'])
germanydfcounterAttack['id_5'] = np.where(germanydfcounterAttack['id_5'] >= 1902, np.NaN, germanydfcounterAttack['id_5'])
    
    
# apply function to DataFrame and create new column
germanydfcounterAttack['CounteAttack'] = germanydfcounterAttack.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
germanydfcounterAttack['CounteAttack'] = germanydfcounterAttack['CounteAttack'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
germanydfcounterAttack['CounteAttack'] = germanydfcounterAttack['CounteAttack'].astype(int)

# remove original columns
germanydfcounterAttack.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)




# Joining various dataframes on the germanydf dataframe
germanydf = germanydf.join([germanydfaccuracy['Accuracy'], germanydfinterception['interception'], germanydfassist['assist'], germanydfthrough['through'], germanydfdribble['dribble'], germanydftackle['tackle'], germanydfgoalPos['goalPos'], germanydfcounterAttack['CounteAttack']])


# Renaming column 5 to 'non' and dropping unwanted columns
germanydf = germanydf.rename(columns={5:'non'})
germanydf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)

# Adding columns for x and y distances, angle and pass positions
germanydf['To x - From x']=germanydf['To X']-germanydf['From X']
germanydf['To y - From y']=germanydf['To y']-germanydf['From y']
germanydf['Angle']=np.degrees(np.arctan2(germanydf['To y - From y'],germanydf['To x - From x']))
germanydf['Position'] = ['Left' if x < 0 else 'Right' for x in germanydf['Angle']]
germanydf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in germanydf['Angle']]
germanydf['distance']= (((germanydf['To X']-germanydf['From X'])**2)+((germanydf['To y']-germanydf['From y'])**2))**0.5

# Getting unique player IDs and selecting them from eurodf and worlddf dataframes
germanydfids=germanydf['playerId'].unique()
germanyeurodf=eurodf.loc[eurodf['playerId'].isin(germanydfids)]
germanyworlddf=worlddf.loc[worlddf['playerId'].isin(germanydfids)]

# Concatenating all dataframes into one
allgermanydf=pd.concat([germanydf, germanyeurodf, germanyworlddf], ignore_index=True)
allgermanydf['CounteAttack'].fillna(0, inplace=True)
# Replacing 'Accuracy' values with strings
allgermanydf['Accuracy'].replace(1801, "Accurate", inplace=True)
allgermanydf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)




# Creating an empty list 'data'
germanydata=[]
for i in germanydfids :
    
    h=allgermanydf[allgermanydf['playerId']==i]
    #Pass
    x=h[h['eventName']=='Pass']
    #Back Right Pass
    s=x[x['pass Position']=='Back Right']
    ACC=s[s['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=s[s['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Through=s[s['through']!=0]
    AccThrough=Through[Through['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrough=Through[Through['Accuracy']=='Not Accurate'].value_counts().sum()
    
    KeyPass_Assist=s[s['assist']!=0]
    KeyPass_Assist1=KeyPass_Assist[KeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_RDis=s['distance'].mean()
    Sd_Br=s['distance'].std()
    av_brAng=s['Angle'].mean()
    
    
    #Forward Right Pass
    
    fr=x[x['pass Position']=='Forward Right']
    frACC=fr[fr['Accuracy']=='Accurate'].value_counts().sum()
    frNotAcc=fr[fr['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSimplepass=fr[fr['subEventName']=='Simple pass']
    frSimplepass1=frSimplepass[frSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    frSimplepass2=frSimplepass[frSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSmartPass=fr[fr['subEventName']=='Smart pass']
    frSmartPass1=frSmartPass[frSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    frSmartPass2=frSmartPass[frSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frCross=fr[fr['subEventName']=='Cross']
    frCross1=frCross[frCross['Accuracy']=='Accurate'].value_counts().sum()
    frCross2=frCross[frCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frHighpass=fr[fr['subEventName']=='High pass']
    frHighpass1=frHighpass[frHighpass['Accuracy']=='Accurate'].value_counts().sum()
    frHighpass2=frHighpass[frHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frHeadpass=fr[fr['subEventName']=='Head pass']
    frHeadpass1=frHeadpass[frHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    frHeadpass2=frHeadpass[frHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frThrough=fr[fr['through']!=0]
    frAccThrough=frThrough[frThrough['Accuracy']=='Accurate'].value_counts().sum()
    frNotAccThrough=frThrough[frThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frKeyPass_Assist=fr[fr['assist']!=0]
    frKeyPass_Assist1=frKeyPass_Assist[frKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    fraverage_RDis=fr['distance'].mean()
    Sd_fr=fr['distance'].std()
    av_frAng=fr['Angle'].mean()
    
    
    
    
    #Forward left Pass
    L=x[x['pass Position']=='Forward Left']
    LACC=L[L['Accuracy']=='Accurate'].value_counts().sum()
    LNotAcc=L[L['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSimplepass=L[L['subEventName']=='Simple pass']
    LSimplepass1=LSimplepass[LSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    LSimplepass2=LSimplepass[LSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSmartPass=L[L['subEventName']=='Smart pass']
    LSmartPass1=LSmartPass[LSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    LSmartPass2=LSmartPass[LSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LCross=L[L['subEventName']=='Cross']
    LCross1=LCross[LCross['Accuracy']=='Accurate'].value_counts().sum()
    LCross2=LCross[LCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LHighpass=L[L['subEventName']=='High pass']
    LHighpass1=LHighpass[LHighpass['Accuracy']=='Accurate'].value_counts().sum()
    LHighpass2=LHighpass[LHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LHeadpass=L[L['subEventName']=='Head pass']
    LHeadpass1=LHeadpass[LHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    LHeadpass2=LHeadpass[LHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LThrough=L[L['through']!=0]
    LAccThrough=LThrough[LThrough['Accuracy']=='Accurate'].value_counts().sum()
    LNotAccThrough=LThrough[LThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LKeyPass_Assist=L[L['assist']!=0]
    LKeyPass_Assist1=LKeyPass_Assist[LKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_LDis=L['distance'].mean()
    Sd_fl=L['distance'].std()
    av_flAng=L['Angle'].mean()
    
    #Back left Pass
    b=x[x['pass Position']=='Back Left']
    bLACC=b[b['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAcc=b[b['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSimplepass=b[b['subEventName']=='Simple pass']
    bLSimplepass1=bLSimplepass[bLSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    bLSimplepass2=bLSimplepass[bLSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSmartPass=b[b['subEventName']=='Smart pass']
    bLSmartPass1=bLSmartPass[bLSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    bLSmartPass2=bLSmartPass[bLSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLCross=b[b['subEventName']=='Cross']
    bLCross1=bLCross[bLCross['Accuracy']=='Accurate'].value_counts().sum()
    bLCross2=bLCross[bLCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLHighpass=b[b['subEventName']=='High pass']
    bLHighpass1=bLHighpass[bLHighpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHighpass2=bLHighpass[bLHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLHeadpass=b[b['subEventName']=='Head pass']
    bLHeadpass1=bLHeadpass[bLHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHeadpass2=bLHeadpass[bLHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLThrough=b[b['through']!=0]
    bLAccThrough=bLThrough[bLThrough['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAccThrough=bLThrough[bLThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLKeyPass_Assist=b[b['assist']!=0]
    bLKeyPass_Assist1=bLKeyPass_Assist[bLKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    baverage_LDis=b['distance'].mean()
    Sd_Bl=b['distance'].std()
    av_blAng=b['Angle'].mean()
    
    
    
    #info
    y= mi[mi['playerId']==i]
    Minutes=y['minutesPlayed'].sum()
    z=names[names['wyId']==i]
    c=z['firstName'].to_list()
    fname=' '.join(map(str, c))
    b=z['lastName'].to_list()
    lname=' '.join(map(str, b))
    e=z['code3'].to_list()
    position=' '.join(map(str, e))
    c=z['birthDate'].to_list()
    Birthdate=' '.join(map(str, c))
    
     
    #accuracy
    PassACC=((ACC/(ACC+NotAcc))/Minutes)*100
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/Minutes)*100
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/Minutes)*100
    CrossACC=((Cross1/(Cross1+Cross2))/Minutes)*100
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/Minutes)*100
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/Minutes)*100
    ThroughACC=((AccThrough/(AccThrough+NotAccThrough))/Minutes)*100
    KeyPass_AssistAcc=(KeyPass_Assist1/Minutes)*100
    
    
    
    frPassACC=((frACC/(frACC+frNotAcc))/Minutes)*100
    frSimplepassACC=((frSimplepass1/(frSimplepass1+frSimplepass2))/Minutes)*100
    frSmartPassACC=((frSmartPass1/(frSmartPass1+frSmartPass2))/Minutes)*100
    frCrossACC=((frCross1/(frCross1+frCross2))/Minutes)*100
    frHighpassACC=((frHighpass1/(frHighpass1+frHighpass2))/Minutes)*100
    frHeadpassACC=((frHeadpass1/(frHeadpass1+frHeadpass2))/Minutes)*100
    frThroughACC=((frAccThrough/(frAccThrough+frNotAccThrough))/Minutes)*100
    frKeyPass_AssistAcc=(frKeyPass_Assist1/Minutes)*100
    
    
    
    LPassACC=((LACC/(LACC+LNotAcc))/Minutes)*100
    LSimplepassACC=((LSimplepass1/(LSimplepass1+LSimplepass2))/Minutes)*100
    LSmartPassACC=((LSmartPass1/(LSmartPass1+LSmartPass2))/Minutes)*100
    LCrossACC=((LCross1/(LCross1+LCross2))/Minutes)*100
    LHighpassACC=((LHighpass1/(LHighpass1+LHighpass2))/Minutes)*100
    LHeadpassACC=((LHeadpass1/(LHeadpass1+LHeadpass2))/Minutes)*100
    LThroughACC=((LAccThrough/(LAccThrough+LNotAccThrough))/Minutes)*100
    LKeyPass_AssistAcc=(LKeyPass_Assist1/Minutes)*100
    
    
    bLPassACC=((bLACC/(bLACC+bLNotAcc))/Minutes)*100
    bLSimplepassACC=((bLSimplepass1/(bLSimplepass1+bLSimplepass2))/Minutes)*100
    bLSmartPassACC=((bLSmartPass1/(bLSmartPass1+bLSmartPass2))/Minutes)*100
    bLCrossACC=((bLCross1/(bLCross1+bLCross2))/Minutes)*100
    bLHighpassACC=((bLHighpass1/(bLHighpass1+bLHighpass2))/Minutes)*100
    bLHeadpassACC=((bLHeadpass1/(bLHeadpass1+bLHeadpass2))/Minutes)*100
    bLThroughACC=((bLAccThrough/(bLAccThrough+bLNotAccThrough))/Minutes)*100
    bLKeyPass_AssistAcc=(bLKeyPass_Assist1/Minutes)*100
    
    
    
    #duels
    d=h[h['eventName']=='Duel']
    
    AD=d[d['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Dribble=d[d['dribble']!=0]
    AccDribble=Dribble[Dribble['Accuracy']=='Accurate'].value_counts().sum()
    NotAccDribble=Dribble[Dribble['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Tackle=d[d['tackle']!=0]
    AccTackle=Tackle[Tackle['Accuracy']=='Accurate'].value_counts().sum()
    NotAccTackle=Tackle[Tackle['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Interceptions=d[d['interception']!=0]
    AccInterceptions=Interceptions[Interceptions['Accuracy']=='Accurate'].value_counts().sum()
    NotAccInterceptions=Interceptions[Interceptions['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=d[d['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=d[d['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=d[d['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    #duels Accuracy
    AD_ACC=(AccAD/(AccAD+NotAccAD))*100
    Dribble_Acc=(AccDribble/(AccDribble+NotAccDribble))*100
    Tackle_ACC=(AccTackle/(AccTackle+NotAccTackle))*100
    Interceptions_Acc=(AccInterceptions/(AccInterceptions+NotAccInterceptions))*100
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD))*100
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD))*100
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD))*100
    
    
    germanydata.append((fname,lname,position,Birthdate,i,
                 
                 ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2
                 ,AccThrough,NotAccThrough,KeyPass_Assist1,average_RDis,Sd_Br,av_brAng,
                 
                 
                 frACC,frNotAcc,frSimplepass1,frSimplepass2,frSmartPass1,frSmartPass2,
                 frCross1,frCross2,frHighpass1,frHighpass2,frHeadpass1,frHeadpass2
                 ,frAccThrough,frNotAccThrough,frKeyPass_Assist1,fraverage_RDis,Sd_fr,av_frAng,
                 
                 
                 bLACC,bLNotAcc,bLSimplepass1,bLSimplepass2,bLSmartPass1,bLSmartPass2,
                 bLCross1,bLCross2,bLHighpass1,bLHighpass2,bLHeadpass1,bLHeadpass2
                 ,bLAccThrough,bLNotAccThrough,bLKeyPass_Assist1,baverage_LDis,Sd_Bl,av_blAng,
                 
                 
                 LACC,LNotAcc,LSimplepass1,LSimplepass2,LSmartPass1,LSmartPass2,
                 LCross1,LCross2,LHighpass1,LHighpass2,Headpass1,LHeadpass2
                 ,LAccThrough,LNotAccThrough,LKeyPass_Assist1,average_LDis,Sd_fl,av_flAng,
                 
                 
                
                
                 Minutes,PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,ThroughACC,KeyPass_AssistAcc,
                 
                 frPassACC,frSimplepassACC,frSmartPassACC,frCrossACC,frHighpassACC,frHeadpassACC,frThroughACC,frKeyPass_AssistAcc,
                
                
                 bLPassACC,bLSimplepassACC,bLSmartPassACC,bLCrossACC,bLHighpassACC,bLHeadpassACC,bLThroughACC,bLKeyPass_AssistAcc,
                 
                 
                 LPassACC,LSimplepassACC,LSmartPassACC,LCrossACC,LHighpassACC,LHeadpassACC,LThroughACC,LKeyPass_AssistAcc,
                  
                  
                 AccAD,NotAccAD,AccDribble,NotAccDribble,AccTackle,NotAccTackle,
                 AccInterceptions,NotAccInterceptions,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                  
                  
                 AD_ACC,Dribble_Acc,Tackle_ACC,Interceptions_Acc,GLD_Acc,GDD_Acc,GAD_Acc))
        

        
germanyplayers=pd.DataFrame(germanydata,columns=('First Name','Last Name','position','Birth Date','Player ID',
                               
                               
                               'Accurate Back Right Passes','Not Accurate Back Right Passes','Accurate Simple Back Right Passes',
                               'Not Accurate Simple Back Right Passes','Accurate Smart Back Right Passes','Not Accurate Smart Back Right Passes',
                               'Accurate Back Right Cross','Not Accurate Back Right Cross','Accurate High Back Right Passes','Not Accurate High Back Right Passes',
                               'Accurate Head Back Right Passes','Not Accurate Head Back Right Passes',
                               'Acc Back Right Through','Not Acc Back Right Through','Back Right KeyPass+Assist','Back Right pass Average distance',
                               'Back Right pass Average distance SD','Back Right pass Average ANGLE',
                               
                               
                               'Accurate Forward Right Passes','Not Accurate Forward Right Passes','Accurate Simple Forward Right Passes',
                               'Not Accurate Simple Forward Right Passes','Accurate Smart Forward Right Passes','Not Accurate Smart Forward Right Passes',
                               'Accurate Forward Right Cross','Not Accurate Forward Right Cross','Accurate High Forward Right Passes','Not Accurate High Forward Right Passes',
                               'Accurate Head Forward Right Passes','Not Accurate Head Forward Right Passes',
                               'Acc Forward Right Through','Not Acc Forward Right Through','Forward Right KeyPass+Assist','Forward Right pass Average distance',
                               'Forward Right pass Average distance SD','Forward Right pass Average ANGLE',
                               
                               'Accurate Back Left Passes','Not Accurate Back Left Passes','Accurate Simple Back Left Passes',
                               'Not Accurate Simple Back Left Passes','Accurate Smart Back Left Passes','Not Accurate Smart Back Left Passes',
                               'Accurate Back Left Cross','Not Accurate Back Left Cross','Accurate High Back Left Passes','Not Accurate High Back Left Passes',
                               'Accurate Head Back Left Passes','Not Accurate Head Back Left Passes',
                               'Acc Back Left Through','Not Acc Back Left Through','Back Left KeyPass+Assist','Back Left pass Average distance',
                               'Back Left pass Average distance SD','Back Left pass Average ANGLE',
                               
                               'Accurate Forward Left Passes','Not Accurate Forward Left Passes','Accurate Simple Forward Left Passes',
                               'Not Accurate Simple Forward Left Passes','Accurate Smart Forward Left Passes','Not Accurate Smart Forward Left Passes',
                               'Accurate Forward Left Cross','Not Accurate Forward Left Cross','Accurate High Forward Left Passes','Not Accurate High Forward Left Passes',
                               'Accurate Head Forward Left Passes','Not Accurate Head Forward Left Passes',
                               'Acc Forward Left Through','Not Acc Forward Left Through','Forward Left KeyPass+Assist','Forward Left pass Average distance',
                               'Forward Left pass Average distance SD','Forward Left pass Average ANGLE',
                               
                               'Minutes Played','Back Right Pass ACC %','Back Right Simplepass ACC %','Back Right SmartPass ACC %',
                               'Back Right Cross ACC %','Back Right Highpass ACC %','Back Right Headpass ACC %','Back Right Through ACC %','Back Right Chances %',
                               
                               'Forward Right Pass ACC %','Forward Right Simplepass ACC %','Forward Right SmartPass ACC %',
                               'Forward Right Cross ACC %','Forward Right Highpass ACC %','Forward Right Headpass ACC %','Forward Right Through ACC %','Forward Right Chances %',
                               
                               'Back Left Pass ACC %','Back Left Simplepass ACC %','Back Left SmartPass ACC %',
                               'Back Left Cross ACC %','Back Left Highpass ACC %','Back Left Headpass ACC %','Back Left Through ACC %','Back Left Chances %',
                               
                               
                               'Forward Left Pass ACC %','Forward Left Simplepass ACC %','Forward Left SmartPass ACC %',
                               'Forward Left Cross ACC %','Forward Left Highpass ACC %','Forward Left Headpass ACC %','Forward Left Through ACC %','Forward Left Chances %',
                              
                              
                              
                              
                               'Accurate Air Duel','Not Accurate Air Duel','Acc Dribbles','Not Acc Dribbles',
                               'ACC Tackles','Not Acc Tackles','ACC Interceptions','Not Acc Interceptions',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel', 
                               'Air Duel ACC %','Dribble ACC %','SLiding Tackle ACC %','Interceptions ACC %'
                               ,'Ground loose ball duel ACC %','Ground Defending duel ACC %','Ground Attacking duel ACC %')).sort_values('Minutes Played',ascending=False).reset_index().drop('index',axis=1)        
## adding column with the country name 
germanyplayers['Country']='Germany'

# %% [markdown]
# # Italy Players Stats

# %%
italydf=pd.read_json('events_Italy.json')
# Extracting the coordinates and put them into multiple columns
# Split the "positions" column into two separate columns "from" and "to"
italydf = pd.concat([italydf['positions'].apply(pd.Series), italydf.drop('positions', axis = 1)], axis =1)
# Rename the columns to more descriptive names
italydf = italydf.rename(columns={0:'from',1:'to'})
# Split the "from" column into two separate columns "From X" and "From y"
italydf = pd.concat([italydf['from'].apply(pd.Series), italydf.drop('from', axis = 1)], axis =1)
italydf = italydf.rename(columns={'x':'From X','y':'From y'})
# Split the "to" column into two separate columns "To X" and "To y"
italydf = pd.concat([italydf['to'].apply(pd.Series), italydf.drop('to', axis = 1)], axis =1)
italydf = italydf.rename(columns={'x':'To X','y':'To y'})
# Drop the "f" column
italydf = italydf.rename(columns={0:'f'})
italydf = italydf.drop(['f'], axis=1)

# Extracting the tags and put them into multiple columns
italydf=italydf.rename(columns={'id':'id_0'})

italydf= pd.concat([italydf['tags'].apply(pd.Series), italydf.drop('tags', axis = 1)], axis =1)
italydf=italydf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
italydf= pd.concat([italydf['zero'].apply(pd.Series), italydf.drop('zero', axis = 1)], axis =1)
italydf=italydf.rename(columns={'id':'id_1'})
italydf= pd.concat([italydf['one'].apply(pd.Series), italydf.drop('one', axis = 1)], axis =1)


italydf=italydf.rename(columns={'id':'id_2',0:'a'})
italydf=italydf.dropna(axis=1,how='all')
italydf= pd.concat([italydf['two'].apply(pd.Series), italydf.drop('two', axis = 1)], axis =1)


italydf=italydf.rename(columns={'id':'id_3',0:'a'})
italydf=italydf.dropna(axis=1,how='all')
italydf= pd.concat([italydf['three'].apply(pd.Series), italydf.drop('three', axis = 1)], axis =1)


italydf=italydf.rename(columns={'id':'id_4',0:'a'})
italydf=italydf.dropna(axis=1,how='all')
italydf= pd.concat([italydf['four'].apply(pd.Series), italydf.drop('four', axis = 1)], axis =1)

    
italydf=italydf.rename(columns={'id':'id_5',0:'a'})
italydf=italydf.dropna(axis=1,how='all')

## Removing all tags except only tags related to Accuracy 
# Create a copy of italydf dataframe 
# Set values less than or equal to 1800 and greater than or equal to 1803 to NaN in all columns
italydfaccuracy = italydf.copy()
italydfaccuracy['id_1'] = np.where(italydfaccuracy['id_1'] <= 1800, np.NaN, italydfaccuracy['id_1'])
italydfaccuracy['id_1'] = np.where(italydfaccuracy['id_1'] >= 1803, np.NaN, italydfaccuracy['id_1'])

italydfaccuracy['id_2'] = np.where(italydfaccuracy['id_2'] <= 1800, np.NaN, italydfaccuracy['id_2'])
italydfaccuracy['id_2'] = np.where(italydfaccuracy['id_2'] >= 1803, np.NaN, italydfaccuracy['id_2'])

italydfaccuracy['id_3'] = np.where(italydfaccuracy['id_3'] <= 1800, np.NaN, italydfaccuracy['id_3'])
italydfaccuracy['id_3'] = np.where(italydfaccuracy['id_3'] >= 1803, np.NaN, italydfaccuracy['id_3'])

italydfaccuracy['id_4'] = np.where(italydfaccuracy['id_4'] <= 1800, np.NaN, italydfaccuracy['id_4'])
italydfaccuracy['id_4'] = np.where(italydfaccuracy['id_4'] >= 1803, np.NaN, italydfaccuracy['id_4'])

# apply function to DataFrame and create new column
italydfaccuracy['Accuracy'] = italydfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfaccuracy['Accuracy'] = italydfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
italydfaccuracy['Accuracy'] = italydfaccuracy['Accuracy'].astype(int)

# remove original columns
italydfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of italydf dataframe 
# Set values less than or equal to 1400 and greater than or equal to 1402 to NaN in all columns    
italydfinterception = italydf.copy()
italydfinterception['id_1'] = np.where(italydfinterception['id_1'] <= 1400, np.NaN, italydfinterception['id_1'])
italydfinterception['id_1'] = np.where(italydfinterception['id_1'] >= 1402, np.NaN, italydfinterception['id_1'])

italydfinterception['id_2'] = np.where(italydfinterception['id_2'] <= 1400, np.NaN, italydfinterception['id_2'])
italydfinterception['id_2'] = np.where(italydfinterception['id_2'] >= 1402, np.NaN, italydfinterception['id_2'])

italydfinterception['id_3'] = np.where(italydfinterception['id_3'] <= 1400, np.NaN, italydfinterception['id_3'])
italydfinterception['id_3'] = np.where(italydfinterception['id_3'] >= 1402, np.NaN, italydfinterception['id_3'])

italydfinterception['id_4'] = np.where(italydfinterception['id_4'] <= 1400, np.NaN, italydfinterception['id_4'])
italydfinterception['id_4'] = np.where(italydfinterception['id_4'] >= 1402, np.NaN, italydfinterception['id_4'])

italydfinterception['id_5'] = np.where(italydfinterception['id_5'] <= 1400, np.NaN, italydfinterception['id_5'])
italydfinterception['id_5'] = np.where(italydfinterception['id_5'] >= 1402, np.NaN, italydfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
italydfinterception['interception'] = italydfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfinterception['interception'] = italydfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
italydfinterception['interception'] = italydfinterception['interception'].astype(int)

# remove original columns
italydfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    

# Create a copy of italydf dataframe 
# Set values less than or equal to 300 and greater than or equal to 303 to NaN in all columns    
italydfassist = italydf.copy()
italydfassist['id_1'] = np.where(italydfassist['id_1'] <= 300, np.NaN, italydfassist['id_1'])
italydfassist['id_1'] = np.where(italydfassist['id_1'] >= 303, np.NaN, italydfassist['id_1'])

italydfassist['id_2'] = np.where(italydfassist['id_2'] <= 300, np.NaN, italydfassist['id_2'])
italydfassist['id_2'] = np.where(italydfassist['id_2'] >= 303, np.NaN, italydfassist['id_2'])

italydfassist['id_3'] = np.where(italydfassist['id_3'] <= 300, np.NaN, italydfassist['id_3'])
italydfassist['id_3'] = np.where(italydfassist['id_3'] >= 303, np.NaN, italydfassist['id_3'])

italydfassist['id_4'] = np.where(italydfassist['id_4'] <= 300, np.NaN, italydfassist['id_4'])
italydfassist['id_4'] = np.where(italydfassist['id_4'] >= 303, np.NaN, italydfassist['id_4'])

italydfassist['id_5'] = np.where(italydfassist['id_5'] <= 300, np.NaN, italydfassist['id_5'])
italydfassist['id_5'] = np.where(italydfassist['id_5'] >= 303, np.NaN, italydfassist['id_5'])

# apply function to DataFrame and create new column
italydfassist['assist'] = italydfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfassist['assist'] = italydfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
italydfassist['assist'] = italydfassist['assist'].astype(int)

# remove original columns
italydfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of italydf dataframe 
# Set values less than or equal to 900 and greater than or equal to 902 to NaN in all columns
italydfthrough = italydf.copy()
italydfthrough['id_1'] = np.where(italydfthrough['id_1'] <= 900, np.NaN, italydfthrough['id_1'])
italydfthrough['id_1'] = np.where(italydfthrough['id_1'] >= 902, np.NaN, italydfthrough['id_1'])

italydfthrough['id_2'] = np.where(italydfthrough['id_2'] <= 900, np.NaN, italydfthrough['id_2'])
italydfthrough['id_2'] = np.where(italydfthrough['id_2'] >= 902, np.NaN, italydfthrough['id_2'])

italydfthrough['id_3'] = np.where(italydfthrough['id_3'] <= 900, np.NaN, italydfthrough['id_3'])
italydfthrough['id_3'] = np.where(italydfthrough['id_3'] >= 902, np.NaN, italydfthrough['id_3'])

italydfthrough['id_4'] = np.where(italydfthrough['id_4'] <= 900, np.NaN, italydfthrough['id_4'])
italydfthrough['id_4'] = np.where(italydfthrough['id_4'] >= 902, np.NaN, italydfthrough['id_4'])

italydfthrough['id_5'] = np.where(italydfthrough['id_5'] <= 900, np.NaN, italydfthrough['id_5'])
italydfthrough['id_5'] = np.where(italydfthrough['id_5'] >= 902, np.NaN, italydfthrough['id_5'])

# apply function to DataFrame and create new column
italydfthrough['through'] = italydfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfthrough['through'] = italydfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
italydfthrough['through'] = italydfthrough['through'].astype(int)

# remove original columns
italydfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of italydf dataframe 
# Set values less than or equal to 502 and greater than or equal to 505 to NaN in all columns    
italydfdribble= italydf.copy()
italydfdribble['id_1'] = np.where(italydfdribble['id_1'] <= 502, np.NaN, italydfdribble['id_1'])
italydfdribble['id_1'] = np.where(italydfdribble['id_1'] >= 505, np.NaN, italydfdribble['id_1'])

italydfdribble['id_2'] = np.where(italydfdribble['id_2'] <= 502, np.NaN, italydfdribble['id_2'])
italydfdribble['id_2'] = np.where(italydfdribble['id_2'] >= 505, np.NaN, italydfdribble['id_2'])

italydfdribble['id_3'] = np.where(italydfdribble['id_3'] <= 502, np.NaN, italydfdribble['id_3'])
italydfdribble['id_3'] = np.where(italydfdribble['id_3'] >= 505, np.NaN, italydfdribble['id_3'])

italydfdribble['id_4'] = np.where(italydfdribble['id_4'] <= 502, np.NaN, italydfdribble['id_4'])
italydfdribble['id_4'] = np.where(italydfdribble['id_4'] >= 505, np.NaN, italydfdribble['id_4'])

italydfdribble['id_5'] = np.where(italydfdribble['id_5'] <= 502, np.NaN, italydfdribble['id_5'])
italydfdribble['id_5'] = np.where(italydfdribble['id_5'] >= 505, np.NaN, italydfdribble['id_5'])

# # apply function to DataFrame and create new column
italydfdribble['dribble'] = italydfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfdribble['dribble'] = italydfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
italydfdribble['dribble'] = italydfdribble['dribble'].astype(int)

# remove original columns
italydfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of Italy dataframe
# Set values less than or equal to 1600 and greater than or equal to 1602 to NaN in all columns
italydftackle = italydf.copy()
italydftackle['id_1'] = np.where(italydftackle['id_1'] <= 1600, np.NaN, italydftackle['id_1'])
italydftackle['id_1'] = np.where(italydftackle['id_1'] >= 1602, np.NaN, italydftackle['id_1'])

italydftackle['id_2'] = np.where(italydftackle['id_2'] <= 1600, np.NaN, italydftackle['id_2'])
italydftackle['id_2'] = np.where(italydftackle['id_2'] >= 1602, np.NaN, italydftackle['id_2'])

italydftackle['id_3'] = np.where(italydftackle['id_3'] <= 1600, np.NaN, italydftackle['id_3'])
italydftackle['id_3'] = np.where(italydftackle['id_3'] >= 1602, np.NaN, italydftackle['id_3'])

italydftackle['id_4'] = np.where(italydftackle['id_4'] <= 1600, np.NaN, italydftackle['id_4'])
italydftackle['id_4'] = np.where(italydftackle['id_4'] >= 1602, np.NaN, italydftackle['id_4'])

italydftackle['id_5'] = np.where(italydftackle['id_5'] <= 1600, np.NaN, italydftackle['id_5'])
italydftackle['id_5'] = np.where(italydftackle['id_5'] >= 1602, np.NaN, italydftackle['id_5'])

# apply function to DataFrame and create new column
italydftackle['tackle'] = italydftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydftackle['tackle'] = italydftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
italydftackle['tackle'] = italydftackle['tackle'].astype(int)

# remove original columns
italydftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of Italy dataframe 
# Set values less than or equal to 1200 and greater than or equal to 1210 to NaN in all columns    

italydfgoalPos=italydf.copy()
italydfgoalPos['id_1'] = np.where(italydfgoalPos['id_1'] <= 1200, np.NaN, italydfgoalPos['id_1'])
italydfgoalPos['id_1'] = np.where(italydfgoalPos['id_1'] >= 1210, np.NaN, italydfgoalPos['id_1'])

italydfgoalPos['id_2'] = np.where(italydfgoalPos['id_2'] <= 1200, np.NaN, italydfgoalPos['id_2'])
italydfgoalPos['id_2'] = np.where(italydfgoalPos['id_2'] >= 1210, np.NaN, italydfgoalPos['id_2'])

italydfgoalPos['id_3'] = np.where(italydfgoalPos['id_3'] <= 1200, np.NaN, italydfgoalPos['id_3'])
italydfgoalPos['id_3'] = np.where(italydfgoalPos['id_3'] >= 1210, np.NaN, italydfgoalPos['id_3'])

italydfgoalPos['id_4'] = np.where(italydfgoalPos['id_4'] <= 1200, np.NaN, italydfgoalPos['id_4'])
italydfgoalPos['id_4'] = np.where(italydfgoalPos['id_4'] >= 1210, np.NaN, italydfgoalPos['id_4'])

italydfgoalPos['id_5'] = np.where(italydfgoalPos['id_5'] <= 1200, np.NaN, italydfgoalPos['id_5'])
italydfgoalPos['id_5'] = np.where(italydfgoalPos['id_5'] >= 1210, np.NaN, italydfgoalPos['id_5'])

# apply function to DataFrame and create new column
italydfgoalPos['goalPos'] = italydfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfgoalPos['goalPos'] = italydfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
italydfgoalPos['goalPos'] = italydfgoalPos['goalPos'].astype(int)

# remove original columns
italydfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)





italydfcounterAttack=italydf.copy()
italydfcounterAttack['id_1'] = np.where(italydfcounterAttack['id_1'] <= 1900, np.NaN, italydfcounterAttack['id_1'])
italydfcounterAttack['id_1'] = np.where(italydfcounterAttack['id_1'] >= 1902, np.NaN, italydfcounterAttack['id_1'])

italydfcounterAttack['id_2'] = np.where(italydfcounterAttack['id_2'] <= 1900, np.NaN, italydfcounterAttack['id_2'])
italydfcounterAttack['id_2'] = np.where(italydfcounterAttack['id_2'] >= 1902, np.NaN, italydfcounterAttack['id_2'])

italydfcounterAttack['id_3'] = np.where(italydfcounterAttack['id_3'] <= 1900, np.NaN, italydfcounterAttack['id_3'])
italydfcounterAttack['id_3'] = np.where(italydfcounterAttack['id_3'] >= 1902, np.NaN, italydfcounterAttack['id_3'])

italydfcounterAttack['id_4'] = np.where(italydfcounterAttack['id_4'] <= 1900, np.NaN, italydfcounterAttack['id_4'])
italydfcounterAttack['id_4'] = np.where(italydfcounterAttack['id_4'] >= 1902, np.NaN, italydfcounterAttack['id_4'])

italydfcounterAttack['id_5'] = np.where(italydfcounterAttack['id_5'] <= 1900, np.NaN, italydfcounterAttack['id_5'])
italydfcounterAttack['id_5'] = np.where(italydfcounterAttack['id_5'] >= 1902, np.NaN, italydfcounterAttack['id_5'])
    
    
# apply function to DataFrame and create new column
italydfcounterAttack['CounteAttack'] = italydfcounterAttack.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
italydfcounterAttack['CounteAttack'] = italydfcounterAttack['CounteAttack'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
italydfcounterAttack['CounteAttack'] = italydfcounterAttack['CounteAttack'].astype(int)

# remove original columns
italydfcounterAttack.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)






# Joining various dataframes on the italydf dataframe
italydf = italydf.join([italydfaccuracy['Accuracy'], italydfinterception['interception'], italydfassist['assist'], italydfthrough['through'], italydfdribble['dribble'], italydftackle['tackle'], italydfgoalPos['goalPos'], italydfcounterAttack['CounteAttack']])

# Renaming column 5 to 'non' and dropping unwanted columns
italydf = italydf.rename(columns={5:'non'})
italydf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)

# Adding columns for x and y distances, angle and pass positions
italydf['To x - From x']=italydf['To X']-italydf['From X']
italydf['To y - From y']=italydf['To y']-italydf['From y']
italydf['Angle']=np.degrees(np.arctan2(italydf['To y - From y'],italydf['To x - From x']))
italydf['Position'] = ['Left' if x < 0 else 'Right' for x in italydf['Angle']]
italydf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in italydf['Angle']]
italydf['distance']= (((italydf['To X']-italydf['From X'])**2)+((italydf['To y']-italydf['From y'])**2))**0.5

# Getting unique player IDs and selecting them from eurodf and worlddf dataframes
italydfids=italydf['playerId'].unique()
italyeurodf=eurodf.loc[eurodf['playerId'].isin(italydfids)]
italyworlddf=worlddf.loc[worlddf['playerId'].isin(italydfids)]

# Concatenating all dataframes into one
allitalydf=pd.concat([italydf, italyeurodf, italyworlddf], ignore_index=True)
allitalydf['CounteAttack'].fillna(0, inplace=True)

# Replacing 'Accuracy' values with strings
allitalydf['Accuracy'].replace(1801, "Accurate", inplace=True)
allitalydf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)


# Creating an empty list 'data'
italydata=[]
for i in italydfids :
    
    h=allitalydf[allitalydf['playerId']==i]
    #Pass
    x=h[h['eventName']=='Pass']
    #Back Right Pass
    s=x[x['pass Position']=='Back Right']
    ACC=s[s['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=s[s['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Through=s[s['through']!=0]
    AccThrough=Through[Through['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrough=Through[Through['Accuracy']=='Not Accurate'].value_counts().sum()
    
    KeyPass_Assist=s[s['assist']!=0]
    KeyPass_Assist1=KeyPass_Assist[KeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_RDis=s['distance'].mean()
    Sd_Br=s['distance'].std()
    av_brAng=s['Angle'].mean()
    
    
    #Forward Right Pass
    
    fr=x[x['pass Position']=='Forward Right']
    frACC=fr[fr['Accuracy']=='Accurate'].value_counts().sum()
    frNotAcc=fr[fr['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSimplepass=fr[fr['subEventName']=='Simple pass']
    frSimplepass1=frSimplepass[frSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    frSimplepass2=frSimplepass[frSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSmartPass=fr[fr['subEventName']=='Smart pass']
    frSmartPass1=frSmartPass[frSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    frSmartPass2=frSmartPass[frSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frCross=fr[fr['subEventName']=='Cross']
    frCross1=frCross[frCross['Accuracy']=='Accurate'].value_counts().sum()
    frCross2=frCross[frCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frHighpass=fr[fr['subEventName']=='High pass']
    frHighpass1=frHighpass[frHighpass['Accuracy']=='Accurate'].value_counts().sum()
    frHighpass2=frHighpass[frHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frHeadpass=fr[fr['subEventName']=='Head pass']
    frHeadpass1=frHeadpass[frHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    frHeadpass2=frHeadpass[frHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frThrough=fr[fr['through']!=0]
    frAccThrough=frThrough[frThrough['Accuracy']=='Accurate'].value_counts().sum()
    frNotAccThrough=frThrough[frThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frKeyPass_Assist=fr[fr['assist']!=0]
    frKeyPass_Assist1=frKeyPass_Assist[frKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    fraverage_RDis=fr['distance'].mean()
    Sd_fr=fr['distance'].std()
    av_frAng=fr['Angle'].mean()
    
    
    
    
    #Forward left Pass
    L=x[x['pass Position']=='Forward Left']
    LACC=L[L['Accuracy']=='Accurate'].value_counts().sum()
    LNotAcc=L[L['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSimplepass=L[L['subEventName']=='Simple pass']
    LSimplepass1=LSimplepass[LSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    LSimplepass2=LSimplepass[LSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSmartPass=L[L['subEventName']=='Smart pass']
    LSmartPass1=LSmartPass[LSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    LSmartPass2=LSmartPass[LSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LCross=L[L['subEventName']=='Cross']
    LCross1=LCross[LCross['Accuracy']=='Accurate'].value_counts().sum()
    LCross2=LCross[LCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LHighpass=L[L['subEventName']=='High pass']
    LHighpass1=LHighpass[LHighpass['Accuracy']=='Accurate'].value_counts().sum()
    LHighpass2=LHighpass[LHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LHeadpass=L[L['subEventName']=='Head pass']
    LHeadpass1=LHeadpass[LHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    LHeadpass2=LHeadpass[LHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LThrough=L[L['through']!=0]
    LAccThrough=LThrough[LThrough['Accuracy']=='Accurate'].value_counts().sum()
    LNotAccThrough=LThrough[LThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LKeyPass_Assist=L[L['assist']!=0]
    LKeyPass_Assist1=LKeyPass_Assist[LKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_LDis=L['distance'].mean()
    Sd_fl=L['distance'].std()
    av_flAng=L['Angle'].mean()
    
    #Back left Pass
    b=x[x['pass Position']=='Back Left']
    bLACC=b[b['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAcc=b[b['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSimplepass=b[b['subEventName']=='Simple pass']
    bLSimplepass1=bLSimplepass[bLSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    bLSimplepass2=bLSimplepass[bLSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSmartPass=b[b['subEventName']=='Smart pass']
    bLSmartPass1=bLSmartPass[bLSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    bLSmartPass2=bLSmartPass[bLSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLCross=b[b['subEventName']=='Cross']
    bLCross1=bLCross[bLCross['Accuracy']=='Accurate'].value_counts().sum()
    bLCross2=bLCross[bLCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLHighpass=b[b['subEventName']=='High pass']
    bLHighpass1=bLHighpass[bLHighpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHighpass2=bLHighpass[bLHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLHeadpass=b[b['subEventName']=='Head pass']
    bLHeadpass1=bLHeadpass[bLHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHeadpass2=bLHeadpass[bLHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLThrough=b[b['through']!=0]
    bLAccThrough=bLThrough[bLThrough['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAccThrough=bLThrough[bLThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLKeyPass_Assist=b[b['assist']!=0]
    bLKeyPass_Assist1=bLKeyPass_Assist[bLKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    baverage_LDis=b['distance'].mean()
    Sd_Bl=b['distance'].std()
    av_blAng=b['Angle'].mean()
    
    
    
    #info
    y= mi[mi['playerId']==i]
    Minutes=y['minutesPlayed'].sum()
    z=names[names['wyId']==i]
    c=z['firstName'].to_list()
    fname=' '.join(map(str, c))
    b=z['lastName'].to_list()
    lname=' '.join(map(str, b))
    e=z['code3'].to_list()
    position=' '.join(map(str, e))
    c=z['birthDate'].to_list()
    Birthdate=' '.join(map(str, c))
    
     
    #accuracy
    PassACC=((ACC/(ACC+NotAcc))/Minutes)*100
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/Minutes)*100
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/Minutes)*100
    CrossACC=((Cross1/(Cross1+Cross2))/Minutes)*100
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/Minutes)*100
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/Minutes)*100
    ThroughACC=((AccThrough/(AccThrough+NotAccThrough))/Minutes)*100
    KeyPass_AssistAcc=(KeyPass_Assist1/Minutes)*100
    
    
    
    frPassACC=((frACC/(frACC+frNotAcc))/Minutes)*100
    frSimplepassACC=((frSimplepass1/(frSimplepass1+frSimplepass2))/Minutes)*100
    frSmartPassACC=((frSmartPass1/(frSmartPass1+frSmartPass2))/Minutes)*100
    frCrossACC=((frCross1/(frCross1+frCross2))/Minutes)*100
    frHighpassACC=((frHighpass1/(frHighpass1+frHighpass2))/Minutes)*100
    frHeadpassACC=((frHeadpass1/(frHeadpass1+frHeadpass2))/Minutes)*100
    frThroughACC=((frAccThrough/(frAccThrough+frNotAccThrough))/Minutes)*100
    frKeyPass_AssistAcc=(frKeyPass_Assist1/Minutes)*100
    
    
    
    LPassACC=((LACC/(LACC+LNotAcc))/Minutes)*100
    LSimplepassACC=((LSimplepass1/(LSimplepass1+LSimplepass2))/Minutes)*100
    LSmartPassACC=((LSmartPass1/(LSmartPass1+LSmartPass2))/Minutes)*100
    LCrossACC=((LCross1/(LCross1+LCross2))/Minutes)*100
    LHighpassACC=((LHighpass1/(LHighpass1+LHighpass2))/Minutes)*100
    LHeadpassACC=((LHeadpass1/(LHeadpass1+LHeadpass2))/Minutes)*100
    LThroughACC=((LAccThrough/(LAccThrough+LNotAccThrough))/Minutes)*100
    LKeyPass_AssistAcc=(LKeyPass_Assist1/Minutes)*100
    
    
    bLPassACC=((bLACC/(bLACC+bLNotAcc))/Minutes)*100
    bLSimplepassACC=((bLSimplepass1/(bLSimplepass1+bLSimplepass2))/Minutes)*100
    bLSmartPassACC=((bLSmartPass1/(bLSmartPass1+bLSmartPass2))/Minutes)*100
    bLCrossACC=((bLCross1/(bLCross1+bLCross2))/Minutes)*100
    bLHighpassACC=((bLHighpass1/(bLHighpass1+bLHighpass2))/Minutes)*100
    bLHeadpassACC=((bLHeadpass1/(bLHeadpass1+bLHeadpass2))/Minutes)*100
    bLThroughACC=((bLAccThrough/(bLAccThrough+bLNotAccThrough))/Minutes)*100
    bLKeyPass_AssistAcc=(bLKeyPass_Assist1/Minutes)*100
    
    
    
    #duels
    d=h[h['eventName']=='Duel']
    
    AD=d[d['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Dribble=d[d['dribble']!=0]
    AccDribble=Dribble[Dribble['Accuracy']=='Accurate'].value_counts().sum()
    NotAccDribble=Dribble[Dribble['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Tackle=d[d['tackle']!=0]
    AccTackle=Tackle[Tackle['Accuracy']=='Accurate'].value_counts().sum()
    NotAccTackle=Tackle[Tackle['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Interceptions=d[d['interception']!=0]
    AccInterceptions=Interceptions[Interceptions['Accuracy']=='Accurate'].value_counts().sum()
    NotAccInterceptions=Interceptions[Interceptions['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=d[d['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=d[d['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=d[d['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    #duels Accuracy
    AD_ACC=(AccAD/(AccAD+NotAccAD))*100
    Dribble_Acc=(AccDribble/(AccDribble+NotAccDribble))*100
    Tackle_ACC=(AccTackle/(AccTackle+NotAccTackle))*100
    Interceptions_Acc=(AccInterceptions/(AccInterceptions+NotAccInterceptions))*100
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD))*100
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD))*100
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD))*100
    
    
    italydata.append((fname,lname,position,Birthdate,i,
                 
                 ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2
                 ,AccThrough,NotAccThrough,KeyPass_Assist1,average_RDis,Sd_Br,av_brAng,
                 
                 
                 frACC,frNotAcc,frSimplepass1,frSimplepass2,frSmartPass1,frSmartPass2,
                 frCross1,frCross2,frHighpass1,frHighpass2,frHeadpass1,frHeadpass2
                 ,frAccThrough,frNotAccThrough,frKeyPass_Assist1,fraverage_RDis,Sd_fr,av_frAng,
                 
                 
                 bLACC,bLNotAcc,bLSimplepass1,bLSimplepass2,bLSmartPass1,bLSmartPass2,
                 bLCross1,bLCross2,bLHighpass1,bLHighpass2,bLHeadpass1,bLHeadpass2
                 ,bLAccThrough,bLNotAccThrough,bLKeyPass_Assist1,baverage_LDis,Sd_Bl,av_blAng,
                 
                 
                 LACC,LNotAcc,LSimplepass1,LSimplepass2,LSmartPass1,LSmartPass2,
                 LCross1,LCross2,LHighpass1,LHighpass2,Headpass1,LHeadpass2
                 ,LAccThrough,LNotAccThrough,LKeyPass_Assist1,average_LDis,Sd_fl,av_flAng,
                 
                 
                
                
                 Minutes,PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,ThroughACC,KeyPass_AssistAcc,
                 
                 frPassACC,frSimplepassACC,frSmartPassACC,frCrossACC,frHighpassACC,frHeadpassACC,frThroughACC,frKeyPass_AssistAcc,
                
                
                 bLPassACC,bLSimplepassACC,bLSmartPassACC,bLCrossACC,bLHighpassACC,bLHeadpassACC,bLThroughACC,bLKeyPass_AssistAcc,
                 
                 
                 LPassACC,LSimplepassACC,LSmartPassACC,LCrossACC,LHighpassACC,LHeadpassACC,LThroughACC,LKeyPass_AssistAcc,
                  
                  
                 AccAD,NotAccAD,AccDribble,NotAccDribble,AccTackle,NotAccTackle,
                 AccInterceptions,NotAccInterceptions,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                  
                  
                 AD_ACC,Dribble_Acc,Tackle_ACC,Interceptions_Acc,GLD_Acc,GDD_Acc,GAD_Acc))
        

        
italyplayers=pd.DataFrame(italydata,columns=('First Name','Last Name','position','Birth Date','Player ID',
                               
                               
                               'Accurate Back Right Passes','Not Accurate Back Right Passes','Accurate Simple Back Right Passes',
                               'Not Accurate Simple Back Right Passes','Accurate Smart Back Right Passes','Not Accurate Smart Back Right Passes',
                               'Accurate Back Right Cross','Not Accurate Back Right Cross','Accurate High Back Right Passes','Not Accurate High Back Right Passes',
                               'Accurate Head Back Right Passes','Not Accurate Head Back Right Passes',
                               'Acc Back Right Through','Not Acc Back Right Through','Back Right KeyPass+Assist','Back Right pass Average distance',
                               'Back Right pass Average distance SD','Back Right pass Average ANGLE',
                               
                               
                               'Accurate Forward Right Passes','Not Accurate Forward Right Passes','Accurate Simple Forward Right Passes',
                               'Not Accurate Simple Forward Right Passes','Accurate Smart Forward Right Passes','Not Accurate Smart Forward Right Passes',
                               'Accurate Forward Right Cross','Not Accurate Forward Right Cross','Accurate High Forward Right Passes','Not Accurate High Forward Right Passes',
                               'Accurate Head Forward Right Passes','Not Accurate Head Forward Right Passes',
                               'Acc Forward Right Through','Not Acc Forward Right Through','Forward Right KeyPass+Assist','Forward Right pass Average distance',
                               'Forward Right pass Average distance SD','Forward Right pass Average ANGLE',
                               
                               'Accurate Back Left Passes','Not Accurate Back Left Passes','Accurate Simple Back Left Passes',
                               'Not Accurate Simple Back Left Passes','Accurate Smart Back Left Passes','Not Accurate Smart Back Left Passes',
                               'Accurate Back Left Cross','Not Accurate Back Left Cross','Accurate High Back Left Passes','Not Accurate High Back Left Passes',
                               'Accurate Head Back Left Passes','Not Accurate Head Back Left Passes',
                               'Acc Back Left Through','Not Acc Back Left Through','Back Left KeyPass+Assist','Back Left pass Average distance',
                               'Back Left pass Average distance SD','Back Left pass Average ANGLE',
                               
                               'Accurate Forward Left Passes','Not Accurate Forward Left Passes','Accurate Simple Forward Left Passes',
                               'Not Accurate Simple Forward Left Passes','Accurate Smart Forward Left Passes','Not Accurate Smart Forward Left Passes',
                               'Accurate Forward Left Cross','Not Accurate Forward Left Cross','Accurate High Forward Left Passes','Not Accurate High Forward Left Passes',
                               'Accurate Head Forward Left Passes','Not Accurate Head Forward Left Passes',
                               'Acc Forward Left Through','Not Acc Forward Left Through','Forward Left KeyPass+Assist','Forward Left pass Average distance',
                               'Forward Left pass Average distance SD','Forward Left pass Average ANGLE',
                               
                               'Minutes Played','Back Right Pass ACC %','Back Right Simplepass ACC %','Back Right SmartPass ACC %',
                               'Back Right Cross ACC %','Back Right Highpass ACC %','Back Right Headpass ACC %','Back Right Through ACC %','Back Right Chances %',
                               
                               'Forward Right Pass ACC %','Forward Right Simplepass ACC %','Forward Right SmartPass ACC %',
                               'Forward Right Cross ACC %','Forward Right Highpass ACC %','Forward Right Headpass ACC %','Forward Right Through ACC %','Forward Right Chances %',
                               
                               'Back Left Pass ACC %','Back Left Simplepass ACC %','Back Left SmartPass ACC %',
                               'Back Left Cross ACC %','Back Left Highpass ACC %','Back Left Headpass ACC %','Back Left Through ACC %','Back Left Chances %',
                               
                               
                               'Forward Left Pass ACC %','Forward Left Simplepass ACC %','Forward Left SmartPass ACC %',
                               'Forward Left Cross ACC %','Forward Left Highpass ACC %','Forward Left Headpass ACC %','Forward Left Through ACC %','Forward Left Chances %',
                              
                              
                              
                              
                               'Accurate Air Duel','Not Accurate Air Duel','Acc Dribbles','Not Acc Dribbles',
                               'ACC Tackles','Not Acc Tackles','ACC Interceptions','Not Acc Interceptions',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel', 
                               'Air Duel ACC %','Dribble ACC %','SLiding Tackle ACC %','Interceptions ACC %'
                               ,'Ground loose ball duel ACC %','Ground Defending duel ACC %','Ground Attacking duel ACC %')).sort_values('Minutes Played',ascending=False).reset_index().drop('index',axis=1)        
## adding column with the country name 
italyplayers['Country']='Italy'

# %% [markdown]
# # England Players Stats

# %%
### ENGLAND
englanddf=pd.read_json('events_England.json')
# Extracting the coordinates and put them into multiple columns
# Split the "positions" column into two separate columns "from" and "to"
engdf = pd.concat([englanddf['positions'].apply(pd.Series), englanddf.drop('positions', axis = 1)], axis =1)
# Rename the columns to more descriptive names
engdf = engdf.rename(columns={0:'from',1:'to'})
# Split the "from" column into two separate columns "From X" and "From y"
engdf = pd.concat([engdf['from'].apply(pd.Series), engdf.drop('from', axis = 1)], axis =1)
engdf = engdf.rename(columns={'x':'From X','y':'From y'})
# Split the "to" column into two separate columns "To X" and "To y"
engdf = pd.concat([engdf['to'].apply(pd.Series), engdf.drop('to', axis = 1)], axis =1)
engdf = engdf.rename(columns={'x':'To X','y':'To y'})
# Drop the "f" column
engdf = engdf.rename(columns={0:'f'})
engdf = engdf.drop(['f'], axis=1)

# Extracting the tags and put them into multiple columns
engdf=engdf.rename(columns={'id':'id_0'})

engdf= pd.concat([engdf['tags'].apply(pd.Series), engdf.drop('tags', axis = 1)], axis =1)
engdf=engdf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
engdf= pd.concat([engdf['zero'].apply(pd.Series), engdf.drop('zero', axis = 1)], axis =1)
engdf=engdf.rename(columns={'id':'id_1'})
engdf= pd.concat([engdf['one'].apply(pd.Series), engdf.drop('one', axis = 1)], axis =1)


engdf=engdf.rename(columns={'id':'id_2',0:'a'})
engdf=engdf.dropna(axis=1,how='all')
engdf= pd.concat([engdf['two'].apply(pd.Series), engdf.drop('two', axis = 1)], axis =1)


engdf=engdf.rename(columns={'id':'id_3',0:'a'})
engdf=engdf.dropna(axis=1,how='all')
engdf= pd.concat([engdf['three'].apply(pd.Series), engdf.drop('three', axis = 1)], axis =1)


engdf=engdf.rename(columns={'id':'id_4',0:'a'})
engdf=engdf.dropna(axis=1,how='all')
engdf= pd.concat([engdf['four'].apply(pd.Series), engdf.drop('four', axis = 1)], axis =1)

    
engdf=engdf.rename(columns={'id':'id_5',0:'a'})
engdf=engdf.dropna(axis=1,how='all')

    
    
## Removing all tags except only tags related to Accuracy 
# Create a copy of engdf dataframe 
# Set values less than or equal to 1800 and greater than or equal to 1803 to NaN in all columns
engdfaccuracy=engdf.copy()
engdfaccuracy['id_1'] = np.where(engdfaccuracy['id_1'] <= 1800, np.NaN, engdfaccuracy['id_1'])
engdfaccuracy['id_1'] = np.where(engdfaccuracy['id_1'] >= 1803, np.NaN, engdfaccuracy['id_1'])

engdfaccuracy['id_2'] = np.where(engdfaccuracy['id_2'] <= 1800, np.NaN, engdfaccuracy['id_2'])
engdfaccuracy['id_2'] = np.where(engdfaccuracy['id_2'] >= 1803, np.NaN, engdfaccuracy['id_2'])

engdfaccuracy['id_3'] = np.where(engdfaccuracy['id_3'] <= 1800, np.NaN, engdfaccuracy['id_3'])
engdfaccuracy['id_3'] = np.where(engdfaccuracy['id_3'] >= 1803, np.NaN, engdfaccuracy['id_3'])

engdfaccuracy['id_4'] = np.where(engdfaccuracy['id_4'] <= 1800, np.NaN, engdfaccuracy['id_4'])
engdfaccuracy['id_4'] = np.where(engdfaccuracy['id_4'] >= 1803, np.NaN, engdfaccuracy['id_4'])
    
# apply function to DataFrame and create new column
engdfaccuracy['Accuracy'] = engdfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfaccuracy['Accuracy'] = engdfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
engdfaccuracy['Accuracy'] = engdfaccuracy['Accuracy'].astype(int)

# remove original columns
engdfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
# Create a copy of engdf dataframe 
# Set values less than or equal to 1400 and greater than or equal to 1402 to NaN in all columns    
engdfinterception=engdf.copy()
engdfinterception['id_1'] = np.where(engdfinterception['id_1'] <= 1400, np.NaN, engdfinterception['id_1'])
engdfinterception['id_1'] = np.where(engdfinterception['id_1'] >= 1402, np.NaN, engdfinterception['id_1'])

engdfinterception['id_2'] = np.where(engdfinterception['id_2'] <= 1400, np.NaN, engdfinterception['id_2'])
engdfinterception['id_2'] = np.where(engdfinterception['id_2'] >= 1402, np.NaN, engdfinterception['id_2'])

engdfinterception['id_3'] = np.where(engdfinterception['id_3'] <= 1400, np.NaN, engdfinterception['id_3'])
engdfinterception['id_3'] = np.where(engdfinterception['id_3'] >= 1402, np.NaN, engdfinterception['id_3'])

engdfinterception['id_4'] = np.where(engdfinterception['id_4'] <= 1400, np.NaN, engdfinterception['id_4'])
engdfinterception['id_4'] = np.where(engdfinterception['id_4'] >= 1402, np.NaN, engdfinterception['id_4'])

engdfinterception['id_5'] = np.where(engdfinterception['id_5'] <= 1400, np.NaN, engdfinterception['id_5'])
engdfinterception['id_5'] = np.where(engdfinterception['id_5'] >= 1402, np.NaN, engdfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
engdfinterception['interception'] = engdfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfinterception['interception'] = engdfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
engdfinterception['interception'] = engdfinterception['interception'].astype(int)

# remove original columns
engdfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    

# Create a copy of engdf dataframe 
# Set values less than or equal to 300 and greater than or equal to 303 to NaN in all columns    
engdfassist = engdf.copy()
engdfassist['id_1'] = np.where(engdfassist['id_1'] <= 300, np.NaN, engdfassist['id_1'])
engdfassist['id_1'] = np.where(engdfassist['id_1'] >= 303, np.NaN, engdfassist['id_1'])

engdfassist['id_2'] = np.where(engdfassist['id_2'] <= 300, np.NaN, engdfassist['id_2'])
engdfassist['id_2'] = np.where(engdfassist['id_2'] >= 303, np.NaN, engdfassist['id_2'])

engdfassist['id_3'] = np.where(engdfassist['id_3'] <= 300, np.NaN, engdfassist['id_3'])
engdfassist['id_3'] = np.where(engdfassist['id_3'] >= 303, np.NaN, engdfassist['id_3'])

engdfassist['id_4'] = np.where(engdfassist['id_4'] <= 300, np.NaN, engdfassist['id_4'])
engdfassist['id_4'] = np.where(engdfassist['id_4'] >= 303, np.NaN, engdfassist['id_4'])

engdfassist['id_5'] = np.where(engdfassist['id_5'] <= 300, np.NaN, engdfassist['id_5'])
engdfassist['id_5'] = np.where(engdfassist['id_5'] >= 303, np.NaN, engdfassist['id_5'])
    
# apply function to DataFrame and create new column
engdfassist['assist'] = engdfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfassist['assist'] = engdfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
engdfassist['assist'] = engdfassist['assist'].astype(int)

# remove original columns
engdfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
# Create a copy of engdf dataframe 
# Set values less than or equal to 900 and greater than or equal to 902 to NaN in all columns
engdfthrough = engdf.copy()
engdfthrough['id_1'] = np.where(engdfthrough['id_1'] <= 900, np.NaN, engdfthrough['id_1'])
engdfthrough['id_1'] = np.where(engdfthrough['id_1'] >= 902, np.NaN, engdfthrough['id_1'])

engdfthrough['id_2'] = np.where(engdfthrough['id_2'] <= 900, np.NaN, engdfthrough['id_2'])
engdfthrough['id_2'] = np.where(engdfthrough['id_2'] >= 902, np.NaN, engdfthrough['id_2'])

engdfthrough['id_3'] = np.where(engdfthrough['id_3'] <= 900, np.NaN, engdfthrough['id_3'])
engdfthrough['id_3'] = np.where(engdfthrough['id_3'] >= 902, np.NaN, engdfthrough['id_3'])

engdfthrough['id_4'] = np.where(engdfthrough['id_4'] <= 900, np.NaN, engdfthrough['id_4'])
engdfthrough['id_4'] = np.where(engdfthrough['id_4'] >= 902, np.NaN, engdfthrough['id_4'])

engdfthrough['id_5'] = np.where(engdfthrough['id_5'] <= 900, np.NaN, engdfthrough['id_5'])
engdfthrough['id_5'] = np.where(engdfthrough['id_5'] >= 902, np.NaN, engdfthrough['id_5'])

# apply function to DataFrame and create new column
engdfthrough['through'] = engdfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfthrough['through'] = engdfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
engdfthrough['through'] = engdfthrough['through'].astype(int)

# remove original columns
engdfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
# Create a copy of engdf dataframe 
# Set values less than or equal to 502 and greater than or equal to 505 to NaN in all columns    
engdfdribble= engdf.copy()
engdfdribble['id_1'] = np.where(engdfdribble['id_1'] <= 502, np.NaN, engdfdribble['id_1'])
engdfdribble['id_1'] = np.where(engdfdribble['id_1'] >= 505, np.NaN, engdfdribble['id_1'])

engdfdribble['id_2'] = np.where(engdfdribble['id_2'] <= 502, np.NaN, engdfdribble['id_2'])
engdfdribble['id_2'] = np.where(engdfdribble['id_2'] >= 505, np.NaN, engdfdribble['id_2'])

engdfdribble['id_3'] = np.where(engdfdribble['id_3'] <= 502, np.NaN, engdfdribble['id_3'])
engdfdribble['id_3'] = np.where(engdfdribble['id_3'] >= 505, np.NaN, engdfdribble['id_3'])

engdfdribble['id_4'] = np.where(engdfdribble['id_4'] <= 502, np.NaN, engdfdribble['id_4'])
engdfdribble['id_4'] = np.where(engdfdribble['id_4'] >= 505, np.NaN, engdfdribble['id_4'])

engdfdribble['id_5'] = np.where(engdfdribble['id_5'] <= 502, np.NaN, engdfdribble['id_5'])
engdfdribble['id_5'] = np.where(engdfdribble['id_5'] >= 505, np.NaN, engdfdribble['id_5'])
    
    
# apply function to DataFrame and create new column
engdfdribble['dribble'] = engdfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfdribble['dribble'] = engdfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
engdfdribble['dribble'] = engdfdribble['dribble'].astype(int)

# remove original columns
engdfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
# Create a copy of engdf dataframe 
# Set values less than or equal to 1600 and greater than or equal to 1602 to NaN in all columns    
engdftackle=engdf.copy()
engdftackle['id_1'] = np.where(engdftackle['id_1'] <= 1600, np.NaN, engdftackle['id_1'])
engdftackle['id_1'] = np.where(engdftackle['id_1'] >= 1602, np.NaN, engdftackle['id_1'])

engdftackle['id_2'] = np.where(engdftackle['id_2'] <= 1600, np.NaN, engdftackle['id_2'])
engdftackle['id_2'] = np.where(engdftackle['id_2'] >= 1602, np.NaN, engdftackle['id_2'])

engdftackle['id_3'] = np.where(engdftackle['id_3'] <= 1600, np.NaN, engdftackle['id_3'])
engdftackle['id_3'] = np.where(engdftackle['id_3'] >= 1602, np.NaN, engdftackle['id_3'])

engdftackle['id_4'] = np.where(engdftackle['id_4'] <= 1600, np.NaN, engdftackle['id_4'])
engdftackle['id_4'] = np.where(engdftackle['id_4'] >= 1602, np.NaN, engdftackle['id_4'])

engdftackle['id_5'] = np.where(engdftackle['id_5'] <= 1600, np.NaN, engdftackle['id_5'])
engdftackle['id_5'] = np.where(engdftackle['id_5'] >= 1602, np.NaN, engdftackle['id_5'])
    
    
# apply function to DataFrame and create new column
engdftackle['tackle'] = engdftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdftackle['tackle'] = engdftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
engdftackle['tackle'] = engdftackle['tackle'].astype(int)

# remove original columns
engdftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    
    
    
    
# Create a copy of engdf dataframe 
# Set values less than or equal to 1200 and greater than or equal to 1210 to NaN in all columns    
engdfgoalPos=engdf.copy()
engdfgoalPos['id_1'] = np.where(engdfgoalPos['id_1'] <= 1200, np.NaN, engdfgoalPos['id_1'])
engdfgoalPos['id_1'] = np.where(engdfgoalPos['id_1'] >= 1210, np.NaN, engdfgoalPos['id_1'])

engdfgoalPos['id_2'] = np.where(engdfgoalPos['id_2'] <= 1200, np.NaN, engdfgoalPos['id_2'])
engdfgoalPos['id_2'] = np.where(engdfgoalPos['id_2'] >= 1210, np.NaN, engdfgoalPos['id_2'])

engdfgoalPos['id_3'] = np.where(engdfgoalPos['id_3'] <= 1200, np.NaN, engdfgoalPos['id_3'])
engdfgoalPos['id_3'] = np.where(engdfgoalPos['id_3'] >= 1210, np.NaN, engdfgoalPos['id_3'])

engdfgoalPos['id_4'] = np.where(engdfgoalPos['id_4'] <= 1200, np.NaN, engdfgoalPos['id_4'])
engdfgoalPos['id_4'] = np.where(engdfgoalPos['id_4'] >= 1210, np.NaN, engdfgoalPos['id_4'])

engdfgoalPos['id_5'] = np.where(engdfgoalPos['id_5'] <= 1200, np.NaN, engdfgoalPos['id_5'])
engdfgoalPos['id_5'] = np.where(engdfgoalPos['id_5'] >= 1210, np.NaN, engdfgoalPos['id_5'])
    
    
# apply function to DataFrame and create new column
engdfgoalPos['goalPos'] = engdfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfgoalPos['goalPos'] = engdfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
engdfgoalPos['goalPos'] = engdfgoalPos['goalPos'].astype(int)

# remove original columns
engdfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)






# Create a copy of engdf dataframe 
# Set values less than or equal to 1900 and greater than or equal to 1902 to NaN in all columns    
engdfcounterAttack=engdf.copy()
engdfcounterAttack['id_1'] = np.where(engdfcounterAttack['id_1'] <= 1900, np.NaN, engdfcounterAttack['id_1'])
engdfcounterAttack['id_1'] = np.where(engdfcounterAttack['id_1'] >= 1902, np.NaN, engdfcounterAttack['id_1'])

engdfcounterAttack['id_2'] = np.where(engdfcounterAttack['id_2'] <= 1900, np.NaN, engdfcounterAttack['id_2'])
engdfcounterAttack['id_2'] = np.where(engdfcounterAttack['id_2'] >= 1902, np.NaN, engdfcounterAttack['id_2'])

engdfcounterAttack['id_3'] = np.where(engdfcounterAttack['id_3'] <= 1900, np.NaN, engdfcounterAttack['id_3'])
engdfcounterAttack['id_3'] = np.where(engdfcounterAttack['id_3'] >= 1902, np.NaN, engdfcounterAttack['id_3'])

engdfcounterAttack['id_4'] = np.where(engdfcounterAttack['id_4'] <= 1900, np.NaN, engdfcounterAttack['id_4'])
engdfcounterAttack['id_4'] = np.where(engdfcounterAttack['id_4'] >= 1902, np.NaN, engdfcounterAttack['id_4'])

engdfcounterAttack['id_5'] = np.where(engdfcounterAttack['id_5'] <= 1900, np.NaN, engdfcounterAttack['id_5'])
engdfcounterAttack['id_5'] = np.where(engdfcounterAttack['id_5'] >= 1902, np.NaN, engdfcounterAttack['id_5'])
    
    
# apply function to DataFrame and create new column
engdfcounterAttack['CounteAttack'] = engdfcounterAttack.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
engdfcounterAttack['CounteAttack'] = engdfcounterAttack['CounteAttack'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
engdfcounterAttack['CounteAttack'] = engdfcounterAttack['CounteAttack'].astype(int)

# remove original columns
engdfcounterAttack.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)



# Joining various dataframes on the engdf dataframe
engdf = engdf.join([engdfaccuracy['Accuracy'], engdfinterception['interception'], engdfassist['assist'], engdfthrough['through'], engdfdribble['dribble'], engdftackle['tackle'], engdfgoalPos['goalPos'], engdfcounterAttack['CounteAttack']])

# Renaming column 5 to 'non' and dropping unwanted columns
engdf=engdf.rename(columns={5:'non'})
engdf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)

# Adding columns for x and y distances, angle and pass positions
engdf['To x - From x']=engdf['To X']-engdf['From X']
engdf['To y - From y']=engdf['To y']-engdf['From y']
engdf['Angle']=np.degrees(np.arctan2(engdf['To y - From y'],engdf['To x - From x']))
engdf['Position'] = ['Left' if x < 0 else 'Right' for x in engdf['Angle']]
engdf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in engdf['Angle']]
engdf['distance']= (((engdf['To X']-engdf['From X'])**2)+((engdf['To y']-engdf['From y'])**2))**0.5

# Getting unique player IDs and selecting them from eurodf and worlddf dataframes
engdfids=engdf['playerId'].unique()
engeurodf=eurodf.loc[eurodf['playerId'].isin(engdfids)]
engworlddf=worlddf.loc[worlddf['playerId'].isin(engdfids)]

# Concatenating all dataframes into one
allengdf=pd.concat([engdf, engeurodf, engworlddf], ignore_index=True)
allengdf['CounteAttack'].fillna(0, inplace=True)

# Replacing 'Accuracy' values with strings
allengdf['Accuracy'].replace(1801, "Accurate", inplace=True)
allengdf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)



# Creating an empty list 'data'
engdata=[]
for i in engdfids :
    
    h=allengdf[allengdf['playerId']==i]
    #Pass
    x=h[h['eventName']=='Pass']
    #Back Right Pass
    s=x[x['pass Position']=='Back Right']
    ACC=s[s['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=s[s['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Through=s[s['through']!=0]
    AccThrough=Through[Through['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrough=Through[Through['Accuracy']=='Not Accurate'].value_counts().sum()
    
    KeyPass_Assist=s[s['assist']!=0]
    KeyPass_Assist1=KeyPass_Assist[KeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_RDis=s['distance'].mean()
    Sd_Br=s['distance'].std()
    av_brAng=s['Angle'].mean()
    
    
    #Forward Right Pass
    
    fr=x[x['pass Position']=='Forward Right']
    frACC=fr[fr['Accuracy']=='Accurate'].value_counts().sum()
    frNotAcc=fr[fr['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSimplepass=fr[fr['subEventName']=='Simple pass']
    frSimplepass1=frSimplepass[frSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    frSimplepass2=frSimplepass[frSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSmartPass=fr[fr['subEventName']=='Smart pass']
    frSmartPass1=frSmartPass[frSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    frSmartPass2=frSmartPass[frSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frCross=fr[fr['subEventName']=='Cross']
    frCross1=frCross[frCross['Accuracy']=='Accurate'].value_counts().sum()
    frCross2=frCross[frCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frHighpass=fr[fr['subEventName']=='High pass']
    frHighpass1=frHighpass[frHighpass['Accuracy']=='Accurate'].value_counts().sum()
    frHighpass2=frHighpass[frHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frHeadpass=fr[fr['subEventName']=='Head pass']
    frHeadpass1=frHeadpass[frHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    frHeadpass2=frHeadpass[frHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frThrough=fr[fr['through']!=0]
    frAccThrough=frThrough[frThrough['Accuracy']=='Accurate'].value_counts().sum()
    frNotAccThrough=frThrough[frThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frKeyPass_Assist=fr[fr['assist']!=0]
    frKeyPass_Assist1=frKeyPass_Assist[frKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    fraverage_RDis=fr['distance'].mean()
    Sd_fr=fr['distance'].std()
    av_frAng=fr['Angle'].mean()
    
    
    
    
    #Forward left Pass
    L=x[x['pass Position']=='Forward Left']
    LACC=L[L['Accuracy']=='Accurate'].value_counts().sum()
    LNotAcc=L[L['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSimplepass=L[L['subEventName']=='Simple pass']
    LSimplepass1=LSimplepass[LSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    LSimplepass2=LSimplepass[LSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSmartPass=L[L['subEventName']=='Smart pass']
    LSmartPass1=LSmartPass[LSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    LSmartPass2=LSmartPass[LSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LCross=L[L['subEventName']=='Cross']
    LCross1=LCross[LCross['Accuracy']=='Accurate'].value_counts().sum()
    LCross2=LCross[LCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LHighpass=L[L['subEventName']=='High pass']
    LHighpass1=LHighpass[LHighpass['Accuracy']=='Accurate'].value_counts().sum()
    LHighpass2=LHighpass[LHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LHeadpass=L[L['subEventName']=='Head pass']
    LHeadpass1=LHeadpass[LHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    LHeadpass2=LHeadpass[LHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LThrough=L[L['through']!=0]
    LAccThrough=LThrough[LThrough['Accuracy']=='Accurate'].value_counts().sum()
    LNotAccThrough=LThrough[LThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LKeyPass_Assist=L[L['assist']!=0]
    LKeyPass_Assist1=LKeyPass_Assist[LKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_LDis=L['distance'].mean()
    Sd_fl=L['distance'].std()
    av_flAng=L['Angle'].mean()
    
    #Back left Pass
    b=x[x['pass Position']=='Back Left']
    bLACC=b[b['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAcc=b[b['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSimplepass=b[b['subEventName']=='Simple pass']
    bLSimplepass1=bLSimplepass[bLSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    bLSimplepass2=bLSimplepass[bLSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSmartPass=b[b['subEventName']=='Smart pass']
    bLSmartPass1=bLSmartPass[bLSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    bLSmartPass2=bLSmartPass[bLSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLCross=b[b['subEventName']=='Cross']
    bLCross1=bLCross[bLCross['Accuracy']=='Accurate'].value_counts().sum()
    bLCross2=bLCross[bLCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLHighpass=b[b['subEventName']=='High pass']
    bLHighpass1=bLHighpass[bLHighpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHighpass2=bLHighpass[bLHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLHeadpass=b[b['subEventName']=='Head pass']
    bLHeadpass1=bLHeadpass[bLHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHeadpass2=bLHeadpass[bLHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLThrough=b[b['through']!=0]
    bLAccThrough=bLThrough[bLThrough['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAccThrough=bLThrough[bLThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLKeyPass_Assist=b[b['assist']!=0]
    bLKeyPass_Assist1=bLKeyPass_Assist[bLKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    baverage_LDis=b['distance'].mean()
    Sd_Bl=b['distance'].std()
    av_blAng=b['Angle'].mean()
    
    
    
    #info
    y= mi[mi['playerId']==i]
    Minutes=y['minutesPlayed'].sum()
    z=names[names['wyId']==i]
    c=z['firstName'].to_list()
    fname=' '.join(map(str, c))
    b=z['lastName'].to_list()
    lname=' '.join(map(str, b))
    e=z['code3'].to_list()
    position=' '.join(map(str, e))
    c=z['birthDate'].to_list()
    Birthdate=' '.join(map(str, c))
    
     
    #accuracy
    PassACC=((ACC/(ACC+NotAcc))/Minutes)*100
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/Minutes)*100
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/Minutes)*100
    CrossACC=((Cross1/(Cross1+Cross2))/Minutes)*100
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/Minutes)*100
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/Minutes)*100
    ThroughACC=((AccThrough/(AccThrough+NotAccThrough))/Minutes)*100
    KeyPass_AssistAcc=(KeyPass_Assist1/Minutes)*100
    
    
    
    frPassACC=((frACC/(frACC+frNotAcc))/Minutes)*100
    frSimplepassACC=((frSimplepass1/(frSimplepass1+frSimplepass2))/Minutes)*100
    frSmartPassACC=((frSmartPass1/(frSmartPass1+frSmartPass2))/Minutes)*100
    frCrossACC=((frCross1/(frCross1+frCross2))/Minutes)*100
    frHighpassACC=((frHighpass1/(frHighpass1+frHighpass2))/Minutes)*100
    frHeadpassACC=((frHeadpass1/(frHeadpass1+frHeadpass2))/Minutes)*100
    frThroughACC=((frAccThrough/(frAccThrough+frNotAccThrough))/Minutes)*100
    frKeyPass_AssistAcc=(frKeyPass_Assist1/Minutes)*100
    
    
    
    LPassACC=((LACC/(LACC+LNotAcc))/Minutes)*100
    LSimplepassACC=((LSimplepass1/(LSimplepass1+LSimplepass2))/Minutes)*100
    LSmartPassACC=((LSmartPass1/(LSmartPass1+LSmartPass2))/Minutes)*100
    LCrossACC=((LCross1/(LCross1+LCross2))/Minutes)*100
    LHighpassACC=((LHighpass1/(LHighpass1+LHighpass2))/Minutes)*100
    LHeadpassACC=((LHeadpass1/(LHeadpass1+LHeadpass2))/Minutes)*100
    LThroughACC=((LAccThrough/(LAccThrough+LNotAccThrough))/Minutes)*100
    LKeyPass_AssistAcc=(LKeyPass_Assist1/Minutes)*100
    
    
    bLPassACC=((bLACC/(bLACC+bLNotAcc))/Minutes)*100
    bLSimplepassACC=((bLSimplepass1/(bLSimplepass1+bLSimplepass2))/Minutes)*100
    bLSmartPassACC=((bLSmartPass1/(bLSmartPass1+bLSmartPass2))/Minutes)*100
    bLCrossACC=((bLCross1/(bLCross1+bLCross2))/Minutes)*100
    bLHighpassACC=((bLHighpass1/(bLHighpass1+bLHighpass2))/Minutes)*100
    bLHeadpassACC=((bLHeadpass1/(bLHeadpass1+bLHeadpass2))/Minutes)*100
    bLThroughACC=((bLAccThrough/(bLAccThrough+bLNotAccThrough))/Minutes)*100
    bLKeyPass_AssistAcc=(bLKeyPass_Assist1/Minutes)*100
    
    
    
    #duels
    d=h[h['eventName']=='Duel']
    
    AD=d[d['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Dribble=d[d['dribble']!=0]
    AccDribble=Dribble[Dribble['Accuracy']=='Accurate'].value_counts().sum()
    NotAccDribble=Dribble[Dribble['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Tackle=d[d['tackle']!=0]
    AccTackle=Tackle[Tackle['Accuracy']=='Accurate'].value_counts().sum()
    NotAccTackle=Tackle[Tackle['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Interceptions=d[d['interception']!=0]
    AccInterceptions=Interceptions[Interceptions['Accuracy']=='Accurate'].value_counts().sum()
    NotAccInterceptions=Interceptions[Interceptions['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=d[d['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=d[d['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=d[d['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    #duels Accuracy
    AD_ACC=(AccAD/(AccAD+NotAccAD))*100
    Dribble_Acc=(AccDribble/(AccDribble+NotAccDribble))*100
    Tackle_ACC=(AccTackle/(AccTackle+NotAccTackle))*100
    Interceptions_Acc=(AccInterceptions/(AccInterceptions+NotAccInterceptions))*100
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD))*100
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD))*100
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD))*100
    
    
    engdata.append((fname,lname,position,Birthdate,i,
                 
                 ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2
                 ,AccThrough,NotAccThrough,KeyPass_Assist1,average_RDis,Sd_Br,av_brAng,
                 
                 
                 frACC,frNotAcc,frSimplepass1,frSimplepass2,frSmartPass1,frSmartPass2,
                 frCross1,frCross2,frHighpass1,frHighpass2,frHeadpass1,frHeadpass2
                 ,frAccThrough,frNotAccThrough,frKeyPass_Assist1,fraverage_RDis,Sd_fr,av_frAng,
                 
                 
                 bLACC,bLNotAcc,bLSimplepass1,bLSimplepass2,bLSmartPass1,bLSmartPass2,
                 bLCross1,bLCross2,bLHighpass1,bLHighpass2,bLHeadpass1,bLHeadpass2
                 ,bLAccThrough,bLNotAccThrough,bLKeyPass_Assist1,baverage_LDis,Sd_Bl,av_blAng,
                 
                 
                 LACC,LNotAcc,LSimplepass1,LSimplepass2,LSmartPass1,LSmartPass2,
                 LCross1,LCross2,LHighpass1,LHighpass2,Headpass1,LHeadpass2
                 ,LAccThrough,LNotAccThrough,LKeyPass_Assist1,average_LDis,Sd_fl,av_flAng,
                 
                 
                
                
                 Minutes,PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,ThroughACC,KeyPass_AssistAcc,
                 
                 frPassACC,frSimplepassACC,frSmartPassACC,frCrossACC,frHighpassACC,frHeadpassACC,frThroughACC,frKeyPass_AssistAcc,
                
                
                 bLPassACC,bLSimplepassACC,bLSmartPassACC,bLCrossACC,bLHighpassACC,bLHeadpassACC,bLThroughACC,bLKeyPass_AssistAcc,
                 
                 
                 LPassACC,LSimplepassACC,LSmartPassACC,LCrossACC,LHighpassACC,LHeadpassACC,LThroughACC,LKeyPass_AssistAcc,
                  
                  
                 AccAD,NotAccAD,AccDribble,NotAccDribble,AccTackle,NotAccTackle,
                 AccInterceptions,NotAccInterceptions,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                  
                  
                 AD_ACC,Dribble_Acc,Tackle_ACC,Interceptions_Acc,GLD_Acc,GDD_Acc,GAD_Acc))
        

        
engplayers=pd.DataFrame(engdata,columns=('First Name','Last Name','position','Birth Date','Player ID',
                               
                               
                               'Accurate Back Right Passes','Not Accurate Back Right Passes','Accurate Simple Back Right Passes',
                               'Not Accurate Simple Back Right Passes','Accurate Smart Back Right Passes','Not Accurate Smart Back Right Passes',
                               'Accurate Back Right Cross','Not Accurate Back Right Cross','Accurate High Back Right Passes','Not Accurate High Back Right Passes',
                               'Accurate Head Back Right Passes','Not Accurate Head Back Right Passes',
                               'Acc Back Right Through','Not Acc Back Right Through','Back Right KeyPass+Assist','Back Right pass Average distance',
                               'Back Right pass Average distance SD','Back Right pass Average ANGLE',
                               
                               
                               'Accurate Forward Right Passes','Not Accurate Forward Right Passes','Accurate Simple Forward Right Passes',
                               'Not Accurate Simple Forward Right Passes','Accurate Smart Forward Right Passes','Not Accurate Smart Forward Right Passes',
                               'Accurate Forward Right Cross','Not Accurate Forward Right Cross','Accurate High Forward Right Passes','Not Accurate High Forward Right Passes',
                               'Accurate Head Forward Right Passes','Not Accurate Head Forward Right Passes',
                               'Acc Forward Right Through','Not Acc Forward Right Through','Forward Right KeyPass+Assist','Forward Right pass Average distance',
                               'Forward Right pass Average distance SD','Forward Right pass Average ANGLE',
                               
                               'Accurate Back Left Passes','Not Accurate Back Left Passes','Accurate Simple Back Left Passes',
                               'Not Accurate Simple Back Left Passes','Accurate Smart Back Left Passes','Not Accurate Smart Back Left Passes',
                               'Accurate Back Left Cross','Not Accurate Back Left Cross','Accurate High Back Left Passes','Not Accurate High Back Left Passes',
                               'Accurate Head Back Left Passes','Not Accurate Head Back Left Passes',
                               'Acc Back Left Through','Not Acc Back Left Through','Back Left KeyPass+Assist','Back Left pass Average distance',
                               'Back Left pass Average distance SD','Back Left pass Average ANGLE',
                               
                               'Accurate Forward Left Passes','Not Accurate Forward Left Passes','Accurate Simple Forward Left Passes',
                               'Not Accurate Simple Forward Left Passes','Accurate Smart Forward Left Passes','Not Accurate Smart Forward Left Passes',
                               'Accurate Forward Left Cross','Not Accurate Forward Left Cross','Accurate High Forward Left Passes','Not Accurate High Forward Left Passes',
                               'Accurate Head Forward Left Passes','Not Accurate Head Forward Left Passes',
                               'Acc Forward Left Through','Not Acc Forward Left Through','Forward Left KeyPass+Assist','Forward Left pass Average distance',
                               'Forward Left pass Average distance SD','Forward Left pass Average ANGLE',
                               
                               'Minutes Played','Back Right Pass ACC %','Back Right Simplepass ACC %','Back Right SmartPass ACC %',
                               'Back Right Cross ACC %','Back Right Highpass ACC %','Back Right Headpass ACC %','Back Right Through ACC %','Back Right Chances %',
                               
                               'Forward Right Pass ACC %','Forward Right Simplepass ACC %','Forward Right SmartPass ACC %',
                               'Forward Right Cross ACC %','Forward Right Highpass ACC %','Forward Right Headpass ACC %','Forward Right Through ACC %','Forward Right Chances %',
                               
                               'Back Left Pass ACC %','Back Left Simplepass ACC %','Back Left SmartPass ACC %',
                               'Back Left Cross ACC %','Back Left Highpass ACC %','Back Left Headpass ACC %','Back Left Through ACC %','Back Left Chances %',
                               
                               
                               'Forward Left Pass ACC %','Forward Left Simplepass ACC %','Forward Left SmartPass ACC %',
                               'Forward Left Cross ACC %','Forward Left Highpass ACC %','Forward Left Headpass ACC %','Forward Left Through ACC %','Forward Left Chances %',
                              
                              
                              
                              
                               'Accurate Air Duel','Not Accurate Air Duel','Acc Dribbles','Not Acc Dribbles',
                               'ACC Tackles','Not Acc Tackles','ACC Interceptions','Not Acc Interceptions',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel', 
                               'Air Duel ACC %','Dribble ACC %','SLiding Tackle ACC %','Interceptions ACC %'
                               ,'Ground loose ball duel ACC %','Ground Defending duel ACC %','Ground Attacking duel ACC %')).sort_values('Minutes Played',ascending=False).reset_index().drop('index',axis=1)        
## adding column with the country name 
engplayers['Country']='England'

# %% [markdown]
# # Spain Players Stats

# %%
### SPAIN
spaindf=pd.read_json('events_Spain.json')
# Extracting the coordinates and put them into multiple columns
# Split the "positions" column into two separate columns "from" and "to"
spaindf = pd.concat([spaindf['positions'].apply(pd.Series), spaindf.drop('positions', axis = 1)], axis =1)
# Rename the columns to more descriptive names
spaindf = spaindf.rename(columns={0:'from',1:'to'})
# Split the "from" column into two separate columns "From X" and "From y"
spaindf = pd.concat([spaindf['from'].apply(pd.Series), spaindf.drop('from', axis = 1)], axis =1)
spaindf = spaindf.rename(columns={'x':'From X','y':'From y'})
# Split the "to" column into two separate columns "To X" and "To y"
spaindf = pd.concat([spaindf['to'].apply(pd.Series), spaindf.drop('to', axis = 1)], axis =1)
spaindf = spaindf.rename(columns={'x':'To X','y':'To y'})
# Drop the "f" column
spaindf = spaindf.rename(columns={0:'f'})
spaindf = spaindf.drop(['f'], axis=1)

# Extracting the tags and put them into multiple columns
spaindf=spaindf.rename(columns={'id':'id_0'})

spaindf= pd.concat([spaindf['tags'].apply(pd.Series), spaindf.drop('tags', axis = 1)], axis =1)
spaindf=spaindf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
spaindf= pd.concat([spaindf['zero'].apply(pd.Series), spaindf.drop('zero', axis = 1)], axis =1)
spaindf=spaindf.rename(columns={'id':'id_1'})
spaindf= pd.concat([spaindf['one'].apply(pd.Series), spaindf.drop('one', axis = 1)], axis =1)


spaindf=spaindf.rename(columns={'id':'id_2',0:'a'})
spaindf=spaindf.dropna(axis=1,how='all')
spaindf= pd.concat([spaindf['two'].apply(pd.Series), spaindf.drop('two', axis = 1)], axis =1)


spaindf=spaindf.rename(columns={'id':'id_3',0:'a'})
spaindf=spaindf.dropna(axis=1,how='all')
spaindf= pd.concat([spaindf['three'].apply(pd.Series), spaindf.drop('three', axis = 1)], axis =1)


spaindf=spaindf.rename(columns={'id':'id_4',0:'a'})
spaindf=spaindf.dropna(axis=1,how='all')
spaindf= pd.concat([spaindf['four'].apply(pd.Series), spaindf.drop('four', axis = 1)], axis =1)

    
spaindf=spaindf.rename(columns={'id':'id_5',0:'a'})
spaindf=spaindf.dropna(axis=1,how='all')


## Removing all tags except only tags related to Accuracy 
# Create a copy of spaindf dataframe 
# Set values less than or equal to 1800 and greater than or equal to 1803 to NaN in all columns
spaindfaccuracy = spaindf.copy()
spaindfaccuracy['id_1'] = np.where(spaindfaccuracy['id_1'] <= 1800, np.NaN, spaindfaccuracy['id_1'])
spaindfaccuracy['id_1'] = np.where(spaindfaccuracy['id_1'] >= 1803, np.NaN, spaindfaccuracy['id_1'])

spaindfaccuracy['id_2'] = np.where(spaindfaccuracy['id_2'] <= 1800, np.NaN, spaindfaccuracy['id_2'])
spaindfaccuracy['id_2'] = np.where(spaindfaccuracy['id_2'] >= 1803, np.NaN, spaindfaccuracy['id_2'])

spaindfaccuracy['id_3'] = np.where(spaindfaccuracy['id_3'] <= 1800, np.NaN, spaindfaccuracy['id_3'])
spaindfaccuracy['id_3'] = np.where(spaindfaccuracy['id_3'] >= 1803, np.NaN, spaindfaccuracy['id_3'])

spaindfaccuracy['id_4'] = np.where(spaindfaccuracy['id_4'] <= 1800, np.NaN, spaindfaccuracy['id_4'])
spaindfaccuracy['id_4'] = np.where(spaindfaccuracy['id_4'] >= 1803, np.NaN, spaindfaccuracy['id_4'])

# apply function to DataFrame and create new column
spaindfaccuracy['Accuracy'] = spaindfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfaccuracy['Accuracy'] = spaindfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
spaindfaccuracy['Accuracy'] = spaindfaccuracy['Accuracy'].astype(int)

# remove original columns
spaindfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of spaindf dataframe 
# Set values less than or equal to 1400 and greater than or equal to 1402 to NaN in all columns    
spaindfinterception = spaindf.copy()
spaindfinterception['id_1'] = np.where(spaindfinterception['id_1'] <= 1400, np.NaN, spaindfinterception['id_1'])
spaindfinterception['id_1'] = np.where(spaindfinterception['id_1'] >= 1402, np.NaN, spaindfinterception['id_1'])

spaindfinterception['id_2'] = np.where(spaindfinterception['id_2'] <= 1400, np.NaN, spaindfinterception['id_2'])
spaindfinterception['id_2'] = np.where(spaindfinterception['id_2'] >= 1402, np.NaN, spaindfinterception['id_2'])

spaindfinterception['id_3'] = np.where(spaindfinterception['id_3'] <= 1400, np.NaN, spaindfinterception['id_3'])
spaindfinterception['id_3'] = np.where(spaindfinterception['id_3'] >= 1402, np.NaN, spaindfinterception['id_3'])

spaindfinterception['id_4'] = np.where(spaindfinterception['id_4'] <= 1400, np.NaN, spaindfinterception['id_4'])
spaindfinterception['id_4'] = np.where(spaindfinterception['id_4'] >= 1402, np.NaN, spaindfinterception['id_4'])

spaindfinterception['id_5'] = np.where(spaindfinterception['id_5'] <= 1400, np.NaN, spaindfinterception['id_5'])
spaindfinterception['id_5'] = np.where(spaindfinterception['id_5'] >= 1402, np.NaN, spaindfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
spaindfinterception['interception'] = spaindfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfinterception['interception'] = spaindfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
spaindfinterception['interception'] = spaindfinterception['interception'].astype(int)

# remove original columns
spaindfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    

# Create a copy of spaindf dataframe 
# Set values less than or equal to 300 and greater than or equal to 303 to NaN in all columns    
spaindfassist = spaindf.copy()
spaindfassist['id_1'] = np.where(spaindfassist['id_1'] <= 300, np.NaN, spaindfassist['id_1'])
spaindfassist['id_1'] = np.where(spaindfassist['id_1'] >= 303, np.NaN, spaindfassist['id_1'])

spaindfassist['id_2'] = np.where(spaindfassist['id_2'] <= 300, np.NaN, spaindfassist['id_2'])
spaindfassist['id_2'] = np.where(spaindfassist['id_2'] >= 303, np.NaN, spaindfassist['id_2'])

spaindfassist['id_3'] = np.where(spaindfassist['id_3'] <= 300, np.NaN, spaindfassist['id_3'])
spaindfassist['id_3'] = np.where(spaindfassist['id_3'] >= 303, np.NaN, spaindfassist['id_3'])

spaindfassist['id_4'] = np.where(spaindfassist['id_4'] <= 300, np.NaN, spaindfassist['id_4'])
spaindfassist['id_4'] = np.where(spaindfassist['id_4'] >= 303, np.NaN, spaindfassist['id_4'])

spaindfassist['id_5'] = np.where(spaindfassist['id_5'] <= 300, np.NaN, spaindfassist['id_5'])
spaindfassist['id_5'] = np.where(spaindfassist['id_5'] >= 303, np.NaN, spaindfassist['id_5'])

# apply function to DataFrame and create new column
spaindfassist['assist'] = spaindfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfassist['assist'] = spaindfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
spaindfassist['assist'] = spaindfassist['assist'].astype(int)

# remove original columns
spaindfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of spaindf dataframe 
# Set values less than or equal to 900 and greater than or equal to 902 to NaN in all columns
spaindfthrough = spaindf.copy()
spaindfthrough['id_1'] = np.where(spaindfthrough['id_1'] <= 900, np.NaN, spaindfthrough['id_1'])
spaindfthrough['id_1'] = np.where(spaindfthrough['id_1'] >= 902, np.NaN, spaindfthrough['id_1'])

spaindfthrough['id_2'] = np.where(spaindfthrough['id_2'] <= 900, np.NaN, spaindfthrough['id_2'])
spaindfthrough['id_2'] = np.where(spaindfthrough['id_2'] >= 902, np.NaN, spaindfthrough['id_2'])

spaindfthrough['id_3'] = np.where(spaindfthrough['id_3'] <= 900, np.NaN, spaindfthrough['id_3'])
spaindfthrough['id_3'] = np.where(spaindfthrough['id_3'] >= 902, np.NaN, spaindfthrough['id_3'])

spaindfthrough['id_4'] = np.where(spaindfthrough['id_4'] <= 900, np.NaN, spaindfthrough['id_4'])
spaindfthrough['id_4'] = np.where(spaindfthrough['id_4'] >= 902, np.NaN, spaindfthrough['id_4'])

spaindfthrough['id_5'] = np.where(spaindfthrough['id_5'] <= 900, np.NaN, spaindfthrough['id_5'])
spaindfthrough['id_5'] = np.where(spaindfthrough['id_5'] >= 902, np.NaN, spaindfthrough['id_5'])

# apply function to DataFrame and create new column
spaindfthrough['through'] = spaindfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfthrough['through'] = spaindfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
spaindfthrough['through'] = spaindfthrough['through'].astype(int)

# remove original columns
spaindfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of spaindf dataframe 
# Set values less than or equal to 502 and greater than or equal to 505 to NaN in all columns    
spaindfdribble= spaindf.copy()
spaindfdribble['id_1'] = np.where(spaindfdribble['id_1'] <= 502, np.NaN, spaindfdribble['id_1'])
spaindfdribble['id_1'] = np.where(spaindfdribble['id_1'] >= 505, np.NaN, spaindfdribble['id_1'])

spaindfdribble['id_2'] = np.where(spaindfdribble['id_2'] <= 502, np.NaN, spaindfdribble['id_2'])
spaindfdribble['id_2'] = np.where(spaindfdribble['id_2'] >= 505, np.NaN, spaindfdribble['id_2'])

spaindfdribble['id_3'] = np.where(spaindfdribble['id_3'] <= 502, np.NaN, spaindfdribble['id_3'])
spaindfdribble['id_3'] = np.where(spaindfdribble['id_3'] >= 505, np.NaN, spaindfdribble['id_3'])

spaindfdribble['id_4'] = np.where(spaindfdribble['id_4'] <= 502, np.NaN, spaindfdribble['id_4'])
spaindfdribble['id_4'] = np.where(spaindfdribble['id_4'] >= 505, np.NaN, spaindfdribble['id_4'])

spaindfdribble['id_5'] = np.where(spaindfdribble['id_5'] <= 502, np.NaN, spaindfdribble['id_5'])
spaindfdribble['id_5'] = np.where(spaindfdribble['id_5'] >= 505, np.NaN, spaindfdribble['id_5'])

# apply function to DataFrame and create new column
spaindfdribble['dribble'] = spaindfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfdribble['dribble'] = spaindfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
spaindfdribble['dribble'] = spaindfdribble['dribble'].astype(int)

# remove original columns
spaindfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
# Create a copy of Spain dataframe 
# Set values less than or equal to 1600 and greater than or equal to 1602 to NaN in all columns    
spaindftackle = spaindf.copy()
spaindftackle['id_1'] = np.where(spaindftackle['id_1'] <= 1600, np.NaN, spaindftackle['id_1'])
spaindftackle['id_1'] = np.where(spaindftackle['id_1'] >= 1602, np.NaN, spaindftackle['id_1'])

spaindftackle['id_2'] = np.where(spaindftackle['id_2'] <= 1600, np.NaN, spaindftackle['id_2'])
spaindftackle['id_2'] = np.where(spaindftackle['id_2'] >= 1602, np.NaN, spaindftackle['id_2'])

spaindftackle['id_3'] = np.where(spaindftackle['id_3'] <= 1600, np.NaN, spaindftackle['id_3'])
spaindftackle['id_3'] = np.where(spaindftackle['id_3'] >= 1602, np.NaN, spaindftackle['id_3'])

spaindftackle['id_4'] = np.where(spaindftackle['id_4'] <= 1600, np.NaN, spaindftackle['id_4'])
spaindftackle['id_4'] = np.where(spaindftackle['id_4'] >= 1602, np.NaN, spaindftackle['id_4'])

spaindftackle['id_5'] = np.where(spaindftackle['id_5'] <= 1600, np.NaN, spaindftackle['id_5'])
spaindftackle['id_5'] = np.where(spaindftackle['id_5'] >= 1602, np.NaN, spaindftackle['id_5'])
    
    
# apply function to DataFrame and create new column
spaindftackle['tackle'] = spaindftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindftackle['tackle'] = spaindftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
spaindftackle['tackle'] = spaindftackle['tackle'].astype(int)

# remove original columns
spaindftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of spaindf dataframe 
# Set values less than or equal to 1200 and greater than or equal to 1210 to NaN in all columns    
spaindfgoalPos=spaindf.copy()
spaindfgoalPos['id_1'] = np.where(spaindfgoalPos['id_1'] <= 1200, np.NaN, spaindfgoalPos['id_1'])
spaindfgoalPos['id_1'] = np.where(spaindfgoalPos['id_1'] >= 1210, np.NaN, spaindfgoalPos['id_1'])

spaindfgoalPos['id_2'] = np.where(spaindfgoalPos['id_2'] <= 1200, np.NaN, spaindfgoalPos['id_2'])
spaindfgoalPos['id_2'] = np.where(spaindfgoalPos['id_2'] >= 1210, np.NaN, spaindfgoalPos['id_2'])

spaindfgoalPos['id_3'] = np.where(spaindfgoalPos['id_3'] <= 1200, np.NaN, spaindfgoalPos['id_3'])
spaindfgoalPos['id_3'] = np.where(spaindfgoalPos['id_3'] >= 1210, np.NaN, spaindfgoalPos['id_3'])

spaindfgoalPos['id_4'] = np.where(spaindfgoalPos['id_4'] <= 1200, np.NaN, spaindfgoalPos['id_4'])
spaindfgoalPos['id_4'] = np.where(spaindfgoalPos['id_4'] >= 1210, np.NaN, spaindfgoalPos['id_4'])

spaindfgoalPos['id_5'] = np.where(spaindfgoalPos['id_5'] <= 1200, np.NaN, spaindfgoalPos['id_5'])
spaindfgoalPos['id_5'] = np.where(spaindfgoalPos['id_5'] >= 1210, np.NaN, spaindfgoalPos['id_5'])

# apply function to DataFrame and create new column
spaindfgoalPos['goalPos'] = spaindfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfgoalPos['goalPos'] = spaindfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
spaindfgoalPos['goalPos'] = spaindfgoalPos['goalPos'].astype(int)

# remove original columns
spaindfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)




spaindfcounterAttack=spaindf.copy()
spaindfcounterAttack['id_1'] = np.where(spaindfcounterAttack['id_1'] <= 1900, np.NaN, spaindfcounterAttack['id_1'])
spaindfcounterAttack['id_1'] = np.where(spaindfcounterAttack['id_1'] >= 1902, np.NaN, spaindfcounterAttack['id_1'])

spaindfcounterAttack['id_2'] = np.where(spaindfcounterAttack['id_2'] <= 1900, np.NaN, spaindfcounterAttack['id_2'])
spaindfcounterAttack['id_2'] = np.where(spaindfcounterAttack['id_2'] >= 1902, np.NaN, spaindfcounterAttack['id_2'])

spaindfcounterAttack['id_3'] = np.where(spaindfcounterAttack['id_3'] <= 1900, np.NaN, spaindfcounterAttack['id_3'])
spaindfcounterAttack['id_3'] = np.where(spaindfcounterAttack['id_3'] >= 1902, np.NaN, spaindfcounterAttack['id_3'])

spaindfcounterAttack['id_4'] = np.where(spaindfcounterAttack['id_4'] <= 1900, np.NaN, spaindfcounterAttack['id_4'])
spaindfcounterAttack['id_4'] = np.where(spaindfcounterAttack['id_4'] >= 1902, np.NaN, spaindfcounterAttack['id_4'])

spaindfcounterAttack['id_5'] = np.where(spaindfcounterAttack['id_5'] <= 1900, np.NaN, spaindfcounterAttack['id_5'])
spaindfcounterAttack['id_5'] = np.where(spaindfcounterAttack['id_5'] >= 1902, np.NaN, spaindfcounterAttack['id_5'])
    
    
# apply function to DataFrame and create new column
spaindfcounterAttack['CounteAttack'] = spaindfcounterAttack.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
spaindfcounterAttack['CounteAttack'] = spaindfcounterAttack['CounteAttack'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
spaindfcounterAttack['CounteAttack'] = spaindfcounterAttack['CounteAttack'].astype(int)

# remove original columns
spaindfcounterAttack.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)







# Joining various dataframes on the spaindf dataframe
spaindf = spaindf.join([spaindfaccuracy['Accuracy'], spaindfinterception['interception'], spaindfassist['assist'], spaindfthrough['through'], spaindfdribble['dribble'], spaindftackle['tackle'], spaindfgoalPos['goalPos'], spaindfcounterAttack['CounteAttack']])

# Renaming column 5 to 'non' and dropping unwanted columns
spaindf = spaindf.rename(columns={5:'non'})
spaindf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)

# Adding columns for x and y distances, angle and pass positions
spaindf['To x - From x']=spaindf['To X']-spaindf['From X']
spaindf['To y - From y']=spaindf['To y']-spaindf['From y']
spaindf['Angle']=np.degrees(np.arctan2(spaindf['To y - From y'],spaindf['To x - From x']))
spaindf['Position'] = ['Left' if x < 0 else 'Right' for x in spaindf['Angle']]
spaindf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in spaindf['Angle']]
spaindf['distance']= (((spaindf['To X']-spaindf['From X'])**2)+((spaindf['To y']-spaindf['From y'])**2))**0.5

# Getting unique player IDs and selecting them from eurodf and worlddf dataframes
spaindfids=spaindf['playerId'].unique()
spaineurodf=eurodf.loc[eurodf['playerId'].isin(spaindfids)]
spainworlddf=worlddf.loc[worlddf['playerId'].isin(spaindfids)]

# Concatenating all dataframes into one
allspaindf=pd.concat([spaindf, spaineurodf, spainworlddf], ignore_index=True)
allspaindf['CounteAttack'].fillna(0, inplace=True)
# Replacing 'Accuracy' values with strings
allspaindf['Accuracy'].replace(1801, "Accurate", inplace=True)
allspaindf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)


# Creating an empty list 'data'
spaindata=[]
for i in spaindfids :
    
    h=allspaindf[allspaindf['playerId']==i]
    #Pass
    x=h[h['eventName']=='Pass']
    #Back Right Pass
    s=x[x['pass Position']=='Back Right']
    ACC=s[s['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=s[s['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Through=s[s['through']!=0]
    AccThrough=Through[Through['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrough=Through[Through['Accuracy']=='Not Accurate'].value_counts().sum()
    
    KeyPass_Assist=s[s['assist']!=0]
    KeyPass_Assist1=KeyPass_Assist[KeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_RDis=s['distance'].mean()
    Sd_Br=s['distance'].std()
    av_brAng=s['Angle'].mean()
    
    
    #Forward Right Pass
    
    fr=x[x['pass Position']=='Forward Right']
    frACC=fr[fr['Accuracy']=='Accurate'].value_counts().sum()
    frNotAcc=fr[fr['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSimplepass=fr[fr['subEventName']=='Simple pass']
    frSimplepass1=frSimplepass[frSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    frSimplepass2=frSimplepass[frSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSmartPass=fr[fr['subEventName']=='Smart pass']
    frSmartPass1=frSmartPass[frSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    frSmartPass2=frSmartPass[frSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frCross=fr[fr['subEventName']=='Cross']
    frCross1=frCross[frCross['Accuracy']=='Accurate'].value_counts().sum()
    frCross2=frCross[frCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frHighpass=fr[fr['subEventName']=='High pass']
    frHighpass1=frHighpass[frHighpass['Accuracy']=='Accurate'].value_counts().sum()
    frHighpass2=frHighpass[frHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frHeadpass=fr[fr['subEventName']=='Head pass']
    frHeadpass1=frHeadpass[frHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    frHeadpass2=frHeadpass[frHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frThrough=fr[fr['through']!=0]
    frAccThrough=frThrough[frThrough['Accuracy']=='Accurate'].value_counts().sum()
    frNotAccThrough=frThrough[frThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frKeyPass_Assist=fr[fr['assist']!=0]
    frKeyPass_Assist1=frKeyPass_Assist[frKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    fraverage_RDis=fr['distance'].mean()
    Sd_fr=fr['distance'].std()
    av_frAng=fr['Angle'].mean()
    
    
    
    
    #Forward left Pass
    L=x[x['pass Position']=='Forward Left']
    LACC=L[L['Accuracy']=='Accurate'].value_counts().sum()
    LNotAcc=L[L['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSimplepass=L[L['subEventName']=='Simple pass']
    LSimplepass1=LSimplepass[LSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    LSimplepass2=LSimplepass[LSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSmartPass=L[L['subEventName']=='Smart pass']
    LSmartPass1=LSmartPass[LSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    LSmartPass2=LSmartPass[LSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LCross=L[L['subEventName']=='Cross']
    LCross1=LCross[LCross['Accuracy']=='Accurate'].value_counts().sum()
    LCross2=LCross[LCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LHighpass=L[L['subEventName']=='High pass']
    LHighpass1=LHighpass[LHighpass['Accuracy']=='Accurate'].value_counts().sum()
    LHighpass2=LHighpass[LHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LHeadpass=L[L['subEventName']=='Head pass']
    LHeadpass1=LHeadpass[LHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    LHeadpass2=LHeadpass[LHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LThrough=L[L['through']!=0]
    LAccThrough=LThrough[LThrough['Accuracy']=='Accurate'].value_counts().sum()
    LNotAccThrough=LThrough[LThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LKeyPass_Assist=L[L['assist']!=0]
    LKeyPass_Assist1=LKeyPass_Assist[LKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_LDis=L['distance'].mean()
    Sd_fl=L['distance'].std()
    av_flAng=L['Angle'].mean()
    
    #Back left Pass
    b=x[x['pass Position']=='Back Left']
    bLACC=b[b['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAcc=b[b['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSimplepass=b[b['subEventName']=='Simple pass']
    bLSimplepass1=bLSimplepass[bLSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    bLSimplepass2=bLSimplepass[bLSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSmartPass=b[b['subEventName']=='Smart pass']
    bLSmartPass1=bLSmartPass[bLSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    bLSmartPass2=bLSmartPass[bLSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLCross=b[b['subEventName']=='Cross']
    bLCross1=bLCross[bLCross['Accuracy']=='Accurate'].value_counts().sum()
    bLCross2=bLCross[bLCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLHighpass=b[b['subEventName']=='High pass']
    bLHighpass1=bLHighpass[bLHighpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHighpass2=bLHighpass[bLHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLHeadpass=b[b['subEventName']=='Head pass']
    bLHeadpass1=bLHeadpass[bLHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHeadpass2=bLHeadpass[bLHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLThrough=b[b['through']!=0]
    bLAccThrough=bLThrough[bLThrough['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAccThrough=bLThrough[bLThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLKeyPass_Assist=b[b['assist']!=0]
    bLKeyPass_Assist1=bLKeyPass_Assist[bLKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    baverage_LDis=b['distance'].mean()
    Sd_Bl=b['distance'].std()
    av_blAng=b['Angle'].mean()
    
    
    
    #info
    y= mi[mi['playerId']==i]
    Minutes=y['minutesPlayed'].sum()
    z=names[names['wyId']==i]
    c=z['firstName'].to_list()
    fname=' '.join(map(str, c))
    b=z['lastName'].to_list()
    lname=' '.join(map(str, b))
    e=z['code3'].to_list()
    position=' '.join(map(str, e))
    c=z['birthDate'].to_list()
    Birthdate=' '.join(map(str, c))
    
     
    #accuracy
    PassACC=((ACC/(ACC+NotAcc))/Minutes)*100
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/Minutes)*100
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/Minutes)*100
    CrossACC=((Cross1/(Cross1+Cross2))/Minutes)*100
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/Minutes)*100
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/Minutes)*100
    ThroughACC=((AccThrough/(AccThrough+NotAccThrough))/Minutes)*100
    KeyPass_AssistAcc=(KeyPass_Assist1/Minutes)*100
    
    
    
    frPassACC=((frACC/(frACC+frNotAcc))/Minutes)*100
    frSimplepassACC=((frSimplepass1/(frSimplepass1+frSimplepass2))/Minutes)*100
    frSmartPassACC=((frSmartPass1/(frSmartPass1+frSmartPass2))/Minutes)*100
    frCrossACC=((frCross1/(frCross1+frCross2))/Minutes)*100
    frHighpassACC=((frHighpass1/(frHighpass1+frHighpass2))/Minutes)*100
    frHeadpassACC=((frHeadpass1/(frHeadpass1+frHeadpass2))/Minutes)*100
    frThroughACC=((frAccThrough/(frAccThrough+frNotAccThrough))/Minutes)*100
    frKeyPass_AssistAcc=(frKeyPass_Assist1/Minutes)*100
    
    
    
    LPassACC=((LACC/(LACC+LNotAcc))/Minutes)*100
    LSimplepassACC=((LSimplepass1/(LSimplepass1+LSimplepass2))/Minutes)*100
    LSmartPassACC=((LSmartPass1/(LSmartPass1+LSmartPass2))/Minutes)*100
    LCrossACC=((LCross1/(LCross1+LCross2))/Minutes)*100
    LHighpassACC=((LHighpass1/(LHighpass1+LHighpass2))/Minutes)*100
    LHeadpassACC=((LHeadpass1/(LHeadpass1+LHeadpass2))/Minutes)*100
    LThroughACC=((LAccThrough/(LAccThrough+LNotAccThrough))/Minutes)*100
    LKeyPass_AssistAcc=(LKeyPass_Assist1/Minutes)*100
    
    
    bLPassACC=((bLACC/(bLACC+bLNotAcc))/Minutes)*100
    bLSimplepassACC=((bLSimplepass1/(bLSimplepass1+bLSimplepass2))/Minutes)*100
    bLSmartPassACC=((bLSmartPass1/(bLSmartPass1+bLSmartPass2))/Minutes)*100
    bLCrossACC=((bLCross1/(bLCross1+bLCross2))/Minutes)*100
    bLHighpassACC=((bLHighpass1/(bLHighpass1+bLHighpass2))/Minutes)*100
    bLHeadpassACC=((bLHeadpass1/(bLHeadpass1+bLHeadpass2))/Minutes)*100
    bLThroughACC=((bLAccThrough/(bLAccThrough+bLNotAccThrough))/Minutes)*100
    bLKeyPass_AssistAcc=(bLKeyPass_Assist1/Minutes)*100
    
    
    
    #duels
    d=h[h['eventName']=='Duel']
    
    AD=d[d['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Dribble=d[d['dribble']!=0]
    AccDribble=Dribble[Dribble['Accuracy']=='Accurate'].value_counts().sum()
    NotAccDribble=Dribble[Dribble['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Tackle=d[d['tackle']!=0]
    AccTackle=Tackle[Tackle['Accuracy']=='Accurate'].value_counts().sum()
    NotAccTackle=Tackle[Tackle['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Interceptions=d[d['interception']!=0]
    AccInterceptions=Interceptions[Interceptions['Accuracy']=='Accurate'].value_counts().sum()
    NotAccInterceptions=Interceptions[Interceptions['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=d[d['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=d[d['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=d[d['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    #duels Accuracy
    AD_ACC=(AccAD/(AccAD+NotAccAD))*100
    Dribble_Acc=(AccDribble/(AccDribble+NotAccDribble))*100
    Tackle_ACC=(AccTackle/(AccTackle+NotAccTackle))*100
    Interceptions_Acc=(AccInterceptions/(AccInterceptions+NotAccInterceptions))*100
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD))*100
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD))*100
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD))*100
    
    
    spaindata.append((fname,lname,position,Birthdate,i,
                 
                 ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2
                 ,AccThrough,NotAccThrough,KeyPass_Assist1,average_RDis,Sd_Br,av_brAng,
                 
                 
                 frACC,frNotAcc,frSimplepass1,frSimplepass2,frSmartPass1,frSmartPass2,
                 frCross1,frCross2,frHighpass1,frHighpass2,frHeadpass1,frHeadpass2
                 ,frAccThrough,frNotAccThrough,frKeyPass_Assist1,fraverage_RDis,Sd_fr,av_frAng,
                 
                 
                 bLACC,bLNotAcc,bLSimplepass1,bLSimplepass2,bLSmartPass1,bLSmartPass2,
                 bLCross1,bLCross2,bLHighpass1,bLHighpass2,bLHeadpass1,bLHeadpass2
                 ,bLAccThrough,bLNotAccThrough,bLKeyPass_Assist1,baverage_LDis,Sd_Bl,av_blAng,
                 
                 
                 LACC,LNotAcc,LSimplepass1,LSimplepass2,LSmartPass1,LSmartPass2,
                 LCross1,LCross2,LHighpass1,LHighpass2,Headpass1,LHeadpass2
                 ,LAccThrough,LNotAccThrough,LKeyPass_Assist1,average_LDis,Sd_fl,av_flAng,
                 
                 
                
                
                 Minutes,PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,ThroughACC,KeyPass_AssistAcc,
                 
                 frPassACC,frSimplepassACC,frSmartPassACC,frCrossACC,frHighpassACC,frHeadpassACC,frThroughACC,frKeyPass_AssistAcc,
                
                
                 bLPassACC,bLSimplepassACC,bLSmartPassACC,bLCrossACC,bLHighpassACC,bLHeadpassACC,bLThroughACC,bLKeyPass_AssistAcc,
                 
                 
                 LPassACC,LSimplepassACC,LSmartPassACC,LCrossACC,LHighpassACC,LHeadpassACC,LThroughACC,LKeyPass_AssistAcc,
                  
                  
                 AccAD,NotAccAD,AccDribble,NotAccDribble,AccTackle,NotAccTackle,
                 AccInterceptions,NotAccInterceptions,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                  
                  
                 AD_ACC,Dribble_Acc,Tackle_ACC,Interceptions_Acc,GLD_Acc,GDD_Acc,GAD_Acc))
        

        
spainplayers=pd.DataFrame(spaindata,columns=('First Name','Last Name','position','Birth Date','Player ID',
                               
                               
                               'Accurate Back Right Passes','Not Accurate Back Right Passes','Accurate Simple Back Right Passes',
                               'Not Accurate Simple Back Right Passes','Accurate Smart Back Right Passes','Not Accurate Smart Back Right Passes',
                               'Accurate Back Right Cross','Not Accurate Back Right Cross','Accurate High Back Right Passes','Not Accurate High Back Right Passes',
                               'Accurate Head Back Right Passes','Not Accurate Head Back Right Passes',
                               'Acc Back Right Through','Not Acc Back Right Through','Back Right KeyPass+Assist','Back Right pass Average distance',
                               'Back Right pass Average distance SD','Back Right pass Average ANGLE',
                               
                               
                               'Accurate Forward Right Passes','Not Accurate Forward Right Passes','Accurate Simple Forward Right Passes',
                               'Not Accurate Simple Forward Right Passes','Accurate Smart Forward Right Passes','Not Accurate Smart Forward Right Passes',
                               'Accurate Forward Right Cross','Not Accurate Forward Right Cross','Accurate High Forward Right Passes','Not Accurate High Forward Right Passes',
                               'Accurate Head Forward Right Passes','Not Accurate Head Forward Right Passes',
                               'Acc Forward Right Through','Not Acc Forward Right Through','Forward Right KeyPass+Assist','Forward Right pass Average distance',
                               'Forward Right pass Average distance SD','Forward Right pass Average ANGLE',
                               
                               'Accurate Back Left Passes','Not Accurate Back Left Passes','Accurate Simple Back Left Passes',
                               'Not Accurate Simple Back Left Passes','Accurate Smart Back Left Passes','Not Accurate Smart Back Left Passes',
                               'Accurate Back Left Cross','Not Accurate Back Left Cross','Accurate High Back Left Passes','Not Accurate High Back Left Passes',
                               'Accurate Head Back Left Passes','Not Accurate Head Back Left Passes',
                               'Acc Back Left Through','Not Acc Back Left Through','Back Left KeyPass+Assist','Back Left pass Average distance',
                               'Back Left pass Average distance SD','Back Left pass Average ANGLE',
                               
                               'Accurate Forward Left Passes','Not Accurate Forward Left Passes','Accurate Simple Forward Left Passes',
                               'Not Accurate Simple Forward Left Passes','Accurate Smart Forward Left Passes','Not Accurate Smart Forward Left Passes',
                               'Accurate Forward Left Cross','Not Accurate Forward Left Cross','Accurate High Forward Left Passes','Not Accurate High Forward Left Passes',
                               'Accurate Head Forward Left Passes','Not Accurate Head Forward Left Passes',
                               'Acc Forward Left Through','Not Acc Forward Left Through','Forward Left KeyPass+Assist','Forward Left pass Average distance',
                               'Forward Left pass Average distance SD','Forward Left pass Average ANGLE',
                               
                               'Minutes Played','Back Right Pass ACC %','Back Right Simplepass ACC %','Back Right SmartPass ACC %',
                               'Back Right Cross ACC %','Back Right Highpass ACC %','Back Right Headpass ACC %','Back Right Through ACC %','Back Right Chances %',
                               
                               'Forward Right Pass ACC %','Forward Right Simplepass ACC %','Forward Right SmartPass ACC %',
                               'Forward Right Cross ACC %','Forward Right Highpass ACC %','Forward Right Headpass ACC %','Forward Right Through ACC %','Forward Right Chances %',
                               
                               'Back Left Pass ACC %','Back Left Simplepass ACC %','Back Left SmartPass ACC %',
                               'Back Left Cross ACC %','Back Left Highpass ACC %','Back Left Headpass ACC %','Back Left Through ACC %','Back Left Chances %',
                               
                               
                               'Forward Left Pass ACC %','Forward Left Simplepass ACC %','Forward Left SmartPass ACC %',
                               'Forward Left Cross ACC %','Forward Left Highpass ACC %','Forward Left Headpass ACC %','Forward Left Through ACC %','Forward Left Chances %',
                              
                              
                              
                              
                               'Accurate Air Duel','Not Accurate Air Duel','Acc Dribbles','Not Acc Dribbles',
                               'ACC Tackles','Not Acc Tackles','ACC Interceptions','Not Acc Interceptions',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel', 
                               'Air Duel ACC %','Dribble ACC %','SLiding Tackle ACC %','Interceptions ACC %'
                               ,'Ground loose ball duel ACC %','Ground Defending duel ACC %','Ground Attacking duel ACC %')).sort_values('Minutes Played',ascending=False).reset_index().drop('index',axis=1)        
## adding column with the country name 
spainplayers['Country']='Spain'

# %% [markdown]
# # France Players Stats

# %%
### France 
francedf = pd.read_json('events_France.json')
# Extracting the coordinates and put them into multiple columns
# Split the "positions" column into two separate columns "from" and "to"
francedf = pd.concat([francedf['positions'].apply(pd.Series), francedf.drop('positions', axis = 1)], axis =1)
# Rename the columns to more descriptive names
francedf = francedf.rename(columns={0:'from',1:'to'})
# Split the "from" column into two separate columns "From X" and "From y"
francedf = pd.concat([francedf['from'].apply(pd.Series), francedf.drop('from', axis = 1)], axis =1)
francedf = francedf.rename(columns={'x':'From X','y':'From y'})
# Split the "to" column into two separate columns "To X" and "To y"
francedf = pd.concat([francedf['to'].apply(pd.Series), francedf.drop('to', axis = 1)], axis =1)
francedf = francedf.rename(columns={'x':'To X','y':'To y'})
# Drop the "f" column
francedf = francedf.rename(columns={0:'f'})
francedf = francedf.drop(['f'], axis=1)

# Extracting the tags and put them into multiple columns
francedf=francedf.rename(columns={'id':'id_0'})

francedf= pd.concat([francedf['tags'].apply(pd.Series), francedf.drop('tags', axis = 1)], axis =1)
francedf=francedf.rename(columns={0:'zero',1:'one',2:'two',3:'three',4:'four'})
francedf= pd.concat([francedf['zero'].apply(pd.Series), francedf.drop('zero', axis = 1)], axis =1)
francedf=francedf.rename(columns={'id':'id_1'})
francedf= pd.concat([francedf['one'].apply(pd.Series), francedf.drop('one', axis = 1)], axis =1)


francedf=francedf.rename(columns={'id':'id_2',0:'a'})
francedf=francedf.dropna(axis=1,how='all')
francedf= pd.concat([francedf['two'].apply(pd.Series), francedf.drop('two', axis = 1)], axis =1)


francedf=francedf.rename(columns={'id':'id_3',0:'a'})
francedf=francedf.dropna(axis=1,how='all')
francedf= pd.concat([francedf['three'].apply(pd.Series), francedf.drop('three', axis = 1)], axis =1)


francedf=francedf.rename(columns={'id':'id_4',0:'a'})
francedf=francedf.dropna(axis=1,how='all')
francedf= pd.concat([francedf['four'].apply(pd.Series), francedf.drop('four', axis = 1)], axis =1)

    
francedf=francedf.rename(columns={'id':'id_5',0:'a'})
francedf=francedf.dropna(axis=1,how='all')

## Removing all tags except only tags related to Accuracy 
# Create a copy of francedf dataframe 
# Set values less than or equal to 1800 and greater than or equal to 1803 to NaN in all columns
francedfaccuracy = francedf.copy()
francedfaccuracy['id_1'] = np.where(francedfaccuracy['id_1'] <= 1800, np.NaN, francedfaccuracy['id_1'])
francedfaccuracy['id_1'] = np.where(francedfaccuracy['id_1'] >= 1803, np.NaN, francedfaccuracy['id_1'])

francedfaccuracy['id_2'] = np.where(francedfaccuracy['id_2'] <= 1800, np.NaN, francedfaccuracy['id_2'])
francedfaccuracy['id_2'] = np.where(francedfaccuracy['id_2'] >= 1803, np.NaN, francedfaccuracy['id_2'])

francedfaccuracy['id_3'] = np.where(francedfaccuracy['id_3'] <= 1800, np.NaN, francedfaccuracy['id_3'])
francedfaccuracy['id_3'] = np.where(francedfaccuracy['id_3'] >= 1803, np.NaN, francedfaccuracy['id_3'])

francedfaccuracy['id_4'] = np.where(francedfaccuracy['id_4'] <= 1800, np.NaN, francedfaccuracy['id_4'])
francedfaccuracy['id_4'] = np.where(francedfaccuracy['id_4'] >= 1803, np.NaN, francedfaccuracy['id_4'])

# apply function to DataFrame and create new column
francedfaccuracy['Accuracy'] = francedfaccuracy.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfaccuracy['Accuracy'] = francedfaccuracy['Accuracy'].str.extract(r'(\d+)').fillna(0)

# convert "Accuracy" column to integers
francedfaccuracy['Accuracy'] = francedfaccuracy['Accuracy'].astype(int)

# remove original columns
francedfaccuracy.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of francedf dataframe 
# Set values less than or equal to 1400 and greater than or equal to 1402 to NaN in all columns    
francedfinterception = francedf.copy()
francedfinterception['id_1'] = np.where(francedfinterception['id_1'] <= 1400, np.NaN, francedfinterception['id_1'])
francedfinterception['id_1'] = np.where(francedfinterception['id_1'] >= 1402, np.NaN, francedfinterception['id_1'])

francedfinterception['id_2'] = np.where(francedfinterception['id_2'] <= 1400, np.NaN, francedfinterception['id_2'])
francedfinterception['id_2'] = np.where(francedfinterception['id_2'] >= 1402, np.NaN, francedfinterception['id_2'])

francedfinterception['id_3'] = np.where(francedfinterception['id_3'] <= 1400, np.NaN, francedfinterception['id_3'])
francedfinterception['id_3'] = np.where(francedfinterception['id_3'] >= 1402, np.NaN, francedfinterception['id_3'])

francedfinterception['id_4'] = np.where(francedfinterception['id_4'] <= 1400, np.NaN, francedfinterception['id_4'])
francedfinterception['id_4'] = np.where(francedfinterception['id_4'] >= 1402, np.NaN, francedfinterception['id_4'])

francedfinterception['id_5'] = np.where(francedfinterception['id_5'] <= 1400, np.NaN, francedfinterception['id_5'])
francedfinterception['id_5'] = np.where(francedfinterception['id_5'] >= 1402, np.NaN, francedfinterception['id_5'])
    
    
# apply function to DataFrame and create new column
francedfinterception['interception'] = francedfinterception.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfinterception['interception'] = francedfinterception['interception'].str.extract(r'(\d+)').fillna(0)

# convert "interception" column to integers
francedfinterception['interception'] = francedfinterception['interception'].astype(int)

# remove original columns
francedfinterception.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)
    
    

# Create a copy of francedf dataframe 
# Set values less than or equal to 300 and greater than or equal to 303 to NaN in all columns    
francedfassist = francedf.copy()
francedfassist['id_1'] = np.where(francedfassist['id_1'] <= 300, np.NaN, francedfassist['id_1'])
francedfassist['id_1'] = np.where(francedfassist['id_1'] >= 303, np.NaN, francedfassist['id_1'])

francedfassist['id_2'] = np.where(francedfassist['id_2'] <= 300, np.NaN, francedfassist['id_2'])
francedfassist['id_2'] = np.where(francedfassist['id_2'] >= 303, np.NaN, francedfassist['id_2'])

francedfassist['id_3'] = np.where(francedfassist['id_3'] <= 300, np.NaN, francedfassist['id_3'])
francedfassist['id_3'] = np.where(francedfassist['id_3'] >= 303, np.NaN, francedfassist['id_3'])

francedfassist['id_4'] = np.where(francedfassist['id_4'] <= 300, np.NaN, francedfassist['id_4'])
francedfassist['id_4'] = np.where(francedfassist['id_4'] >= 303, np.NaN, francedfassist['id_4'])

francedfassist['id_5'] = np.where(francedfassist['id_5'] <= 300, np.NaN, francedfassist['id_5'])
francedfassist['id_5'] = np.where(francedfassist['id_5'] >= 303, np.NaN, francedfassist['id_5'])

# apply function to DataFrame and create new column
francedfassist['assist'] = francedfassist.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfassist['assist'] = francedfassist['assist'].str.extract(r'(\d+)').fillna(0)

# convert "assist" column to integers
francedfassist['assist'] = francedfassist['assist'].astype(int)

# remove original columns
francedfassist.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of francedf dataframe 
# Set values less than or equal to 900 and greater than or equal to 902 to NaN in all columns
francedfthrough = francedf.copy()
francedfthrough['id_1'] = np.where(francedfthrough['id_1'] <= 900, np.NaN, francedfthrough['id_1'])
francedfthrough['id_1'] = np.where(francedfthrough['id_1'] >= 902, np.NaN, francedfthrough['id_1'])

francedfthrough['id_2'] = np.where(francedfthrough['id_2'] <= 900, np.NaN, francedfthrough['id_2'])
francedfthrough['id_2'] = np.where(francedfthrough['id_2'] >= 902, np.NaN, francedfthrough['id_2'])

francedfthrough['id_3'] = np.where(francedfthrough['id_3'] <= 900, np.NaN, francedfthrough['id_3'])
francedfthrough['id_3'] = np.where(francedfthrough['id_3'] >= 902, np.NaN, francedfthrough['id_3'])

francedfthrough['id_4'] = np.where(francedfthrough['id_4'] <= 900, np.NaN, francedfthrough['id_4'])
francedfthrough['id_4'] = np.where(francedfthrough['id_4'] >= 902, np.NaN, francedfthrough['id_4'])

francedfthrough['id_5'] = np.where(francedfthrough['id_5'] <= 900, np.NaN, francedfthrough['id_5'])
francedfthrough['id_5'] = np.where(francedfthrough['id_5'] >= 902, np.NaN, francedfthrough['id_5'])

# apply function to DataFrame and create new column
francedfthrough['through'] = francedfthrough.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfthrough['through'] = francedfthrough['through'].str.extract(r'(\d+)').fillna(0)

# convert "through" column to integers
francedfthrough['through'] = francedfthrough['through'].astype(int)

# remove original columns
francedfthrough.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of francedf dataframe 
# Set values less than or equal to 502 and greater than or equal to 505 to NaN in all columns    
francedfdribble= francedf.copy()
francedfdribble['id_1'] = np.where(francedfdribble['id_1'] <= 502, np.NaN, francedfdribble['id_1'])
francedfdribble['id_1'] = np.where(francedfdribble['id_1'] >= 505, np.NaN, francedfdribble['id_1'])

francedfdribble['id_2'] = np.where(francedfdribble['id_2'] <= 502, np.NaN, francedfdribble['id_2'])
francedfdribble['id_2'] = np.where(francedfdribble['id_2'] >= 505, np.NaN, francedfdribble['id_2'])

francedfdribble['id_3'] = np.where(francedfdribble['id_3'] <= 502, np.NaN, francedfdribble['id_3'])
francedfdribble['id_3'] = np.where(francedfdribble['id_3'] >= 505, np.NaN, francedfdribble['id_3'])

francedfdribble['id_4'] = np.where(francedfdribble['id_4'] <= 502, np.NaN, francedfdribble['id_4'])
francedfdribble['id_4'] = np.where(francedfdribble['id_4'] >= 505, np.NaN, francedfdribble['id_4'])

francedfdribble['id_5'] = np.where(francedfdribble['id_5'] <= 502, np.NaN, francedfdribble['id_5'])
francedfdribble['id_5'] = np.where(francedfdribble['id_5'] >= 505, np.NaN, francedfdribble['id_5'])

# apply function to DataFrame and create new column
francedfdribble['dribble'] = francedfdribble.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfdribble['dribble'] = francedfdribble['dribble'].str.extract(r'(\d+)').fillna(0)

# convert "dribble" column to integers
francedfdribble['dribble'] = francedfdribble['dribble'].astype(int)

# remove original columns
francedfdribble.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Create a copy of France dataframe
# Set values less than or equal to 1600 and greater than or equal to 1602 to NaN in all columns
francedftackle = francedf.copy()
francedftackle['id_1'] = np.where(francedftackle['id_1'] <= 1600, np.NaN, francedftackle['id_1'])
francedftackle['id_1'] = np.where(francedftackle['id_1'] >= 1602, np.NaN, francedftackle['id_1'])

francedftackle['id_2'] = np.where(francedftackle['id_2'] <= 1600, np.NaN, francedftackle['id_2'])
francedftackle['id_2'] = np.where(francedftackle['id_2'] >= 1602, np.NaN, francedftackle['id_2'])

francedftackle['id_3'] = np.where(francedftackle['id_3'] <= 1600, np.NaN, francedftackle['id_3'])
francedftackle['id_3'] = np.where(francedftackle['id_3'] >= 1602, np.NaN, francedftackle['id_3'])

francedftackle['id_4'] = np.where(francedftackle['id_4'] <= 1600, np.NaN, francedftackle['id_4'])
francedftackle['id_4'] = np.where(francedftackle['id_4'] >= 1602, np.NaN, francedftackle['id_4'])

francedftackle['id_5'] = np.where(francedftackle['id_5'] <= 1600, np.NaN, francedftackle['id_5'])
francedftackle['id_5'] = np.where(francedftackle['id_5'] >= 1602, np.NaN, francedftackle['id_5'])

# apply function to DataFrame and create new column
francedftackle['tackle'] = francedftackle.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedftackle['tackle'] = francedftackle['tackle'].str.extract(r'(\d+)').fillna(0)

# convert "tackle" column to integers
francedftackle['tackle'] = francedftackle['tackle'].astype(int)

# remove original columns
francedftackle.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)


# Create a copy of France dataframe 
francedfgoalPos=francedf.copy()

# Set values less than or equal to 1200 and greater than or equal to 1210 to NaN in all columns    
francedfgoalPos['id_1'] = np.where(francedfgoalPos['id_1'] <= 1200, np.NaN, francedfgoalPos['id_1'])
francedfgoalPos['id_1'] = np.where(francedfgoalPos['id_1'] >= 1210, np.NaN, francedfgoalPos['id_1'])

francedfgoalPos['id_2'] = np.where(francedfgoalPos['id_2'] <= 1200, np.NaN, francedfgoalPos['id_2'])
francedfgoalPos['id_2'] = np.where(francedfgoalPos['id_2'] >= 1210, np.NaN, francedfgoalPos['id_2'])

francedfgoalPos['id_3'] = np.where(francedfgoalPos['id_3'] <= 1200, np.NaN, francedfgoalPos['id_3'])
francedfgoalPos['id_3'] = np.where(francedfgoalPos['id_3'] >= 1210, np.NaN, francedfgoalPos['id_3'])

francedfgoalPos['id_4'] = np.where(francedfgoalPos['id_4'] <= 1200, np.NaN, francedfgoalPos['id_4'])
francedfgoalPos['id_4'] = np.where(francedfgoalPos['id_4'] >= 1210, np.NaN, francedfgoalPos['id_4'])

francedfgoalPos['id_5'] = np.where(francedfgoalPos['id_5'] <= 1200, np.NaN, francedfgoalPos['id_5'])
francedfgoalPos['id_5'] = np.where(francedfgoalPos['id_5'] >= 1210, np.NaN, francedfgoalPos['id_5'])




# apply function to DataFrame and create new column
francedfgoalPos['goalPos'] = francedfgoalPos.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfgoalPos['goalPos'] = francedfgoalPos['goalPos'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
francedfgoalPos['goalPos'] = francedfgoalPos['goalPos'].astype(int)

# remove original columns
francedfgoalPos.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)




# Create a copy of engdf dataframe 
# Set values less than or equal to 1900 and greater than or equal to 1902 to NaN in all columns    
francedfcounterAttack=francedf.copy()
francedfcounterAttack['id_1'] = np.where(francedfcounterAttack['id_1'] <= 1900, np.NaN, francedfcounterAttack['id_1'])
francedfcounterAttack['id_1'] = np.where(francedfcounterAttack['id_1'] >= 1902, np.NaN, francedfcounterAttack['id_1'])

francedfcounterAttack['id_2'] = np.where(francedfcounterAttack['id_2'] <= 1900, np.NaN, francedfcounterAttack['id_2'])
francedfcounterAttack['id_2'] = np.where(francedfcounterAttack['id_2'] >= 1902, np.NaN, francedfcounterAttack['id_2'])

francedfcounterAttack['id_3'] = np.where(francedfcounterAttack['id_3'] <= 1900, np.NaN, francedfcounterAttack['id_3'])
francedfcounterAttack['id_3'] = np.where(francedfcounterAttack['id_3'] >= 1902, np.NaN, francedfcounterAttack['id_3'])

francedfcounterAttack['id_4'] = np.where(francedfcounterAttack['id_4'] <= 1900, np.NaN, francedfcounterAttack['id_4'])
francedfcounterAttack['id_4'] = np.where(francedfcounterAttack['id_4'] >= 1902, np.NaN, francedfcounterAttack['id_4'])

francedfcounterAttack['id_5'] = np.where(francedfcounterAttack['id_5'] <= 1900, np.NaN, francedfcounterAttack['id_5'])
francedfcounterAttack['id_5'] = np.where(francedfcounterAttack['id_5'] >= 1902, np.NaN, francedfcounterAttack['id_5'])
    
    
# apply function to DataFrame and create new column
francedfcounterAttack['CounteAttack'] = francedfcounterAttack.apply(concat_cols, axis=1)

# extract numeric values and replace empty string with 0
francedfcounterAttack['CounteAttack'] = francedfcounterAttack['CounteAttack'].str.extract(r'(\d+)').fillna(0)

# convert "goalPos" column to integers
francedfcounterAttack['CounteAttack'] = francedfcounterAttack['CounteAttack'].astype(int)

# remove original columns
francedfcounterAttack.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5'], inplace=True)

# Joining various dataframes on the francedf dataframe
francedf = francedf.join([francedfaccuracy['Accuracy'], francedfinterception['interception'], francedfassist['assist'], francedfthrough['through'], francedfdribble['dribble'], francedftackle['tackle'], francedfgoalPos['goalPos'], francedfcounterAttack['CounteAttack']])

# Renaming column 5 to 'non' and dropping unwanted columns
francedf = francedf.rename(columns={5:'non'})
francedf.drop(columns=['id_1', 'id_2', 'id_3', 'id_4', 'id_5','non'], inplace=True)

# Adding columns for x and y distances, angle and pass positions
francedf['To x - From x']=francedf['To X']-francedf['From X']
francedf['To y - From y']=francedf['To y']-francedf['From y']
francedf['Angle']=np.degrees(np.arctan2(francedf['To y - From y'],francedf['To x - From x']))
francedf['Position'] = ['Left' if x < 0 else 'Right' for x in francedf['Angle']]
francedf['pass Position'] = ['Back Left' if x < -90 else 'Forward Left' if x < 0 else 'Forward Right' if x < 90 else 'Back Right' for x in francedf['Angle']]
francedf['distance']= (((francedf['To X']-francedf['From X'])**2)+((francedf['To y']-francedf['From y'])**2))**0.5

# Getting unique player IDs and selecting them from eurodf and worlddf dataframes
francedfids=francedf['playerId'].unique()
franceeurodf=eurodf.loc[eurodf['playerId'].isin(francedfids)]
franceworlddf=worlddf.loc[worlddf['playerId'].isin(francedfids)]

# Concatenating all dataframes into one
allfrancedf=pd.concat([francedf, franceeurodf, franceworlddf], ignore_index=True)
allfrancedf['CounteAttack'].fillna(0, inplace=True)
# Replacing 'Accuracy' values with strings
allfrancedf['Accuracy'].replace(1801, "Accurate", inplace=True)
allfrancedf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)

# Creating an empty list 'data'
francedata=[]
for i in francedfids :
    
    h=allfrancedf[allfrancedf['playerId']==i]
    #Pass
    x=h[h['eventName']=='Pass']
    #Back Right Pass
    s=x[x['pass Position']=='Back Right']
    ACC=s[s['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=s[s['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Through=s[s['through']!=0]
    AccThrough=Through[Through['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrough=Through[Through['Accuracy']=='Not Accurate'].value_counts().sum()
    
    KeyPass_Assist=s[s['assist']!=0]
    KeyPass_Assist1=KeyPass_Assist[KeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_RDis=s['distance'].mean()
    Sd_Br=s['distance'].std()
    av_brAng=s['Angle'].mean()
    
    
    #Forward Right Pass
    
    fr=x[x['pass Position']=='Forward Right']
    frACC=fr[fr['Accuracy']=='Accurate'].value_counts().sum()
    frNotAcc=fr[fr['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSimplepass=fr[fr['subEventName']=='Simple pass']
    frSimplepass1=frSimplepass[frSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    frSimplepass2=frSimplepass[frSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSmartPass=fr[fr['subEventName']=='Smart pass']
    frSmartPass1=frSmartPass[frSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    frSmartPass2=frSmartPass[frSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frCross=fr[fr['subEventName']=='Cross']
    frCross1=frCross[frCross['Accuracy']=='Accurate'].value_counts().sum()
    frCross2=frCross[frCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frHighpass=fr[fr['subEventName']=='High pass']
    frHighpass1=frHighpass[frHighpass['Accuracy']=='Accurate'].value_counts().sum()
    frHighpass2=frHighpass[frHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frHeadpass=fr[fr['subEventName']=='Head pass']
    frHeadpass1=frHeadpass[frHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    frHeadpass2=frHeadpass[frHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frThrough=fr[fr['through']!=0]
    frAccThrough=frThrough[frThrough['Accuracy']=='Accurate'].value_counts().sum()
    frNotAccThrough=frThrough[frThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frKeyPass_Assist=fr[fr['assist']!=0]
    frKeyPass_Assist1=frKeyPass_Assist[frKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    fraverage_RDis=fr['distance'].mean()
    Sd_fr=fr['distance'].std()
    av_frAng=fr['Angle'].mean()
    
    
    
    
    #Forward left Pass
    L=x[x['pass Position']=='Forward Left']
    LACC=L[L['Accuracy']=='Accurate'].value_counts().sum()
    LNotAcc=L[L['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSimplepass=L[L['subEventName']=='Simple pass']
    LSimplepass1=LSimplepass[LSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    LSimplepass2=LSimplepass[LSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSmartPass=L[L['subEventName']=='Smart pass']
    LSmartPass1=LSmartPass[LSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    LSmartPass2=LSmartPass[LSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LCross=L[L['subEventName']=='Cross']
    LCross1=LCross[LCross['Accuracy']=='Accurate'].value_counts().sum()
    LCross2=LCross[LCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LHighpass=L[L['subEventName']=='High pass']
    LHighpass1=LHighpass[LHighpass['Accuracy']=='Accurate'].value_counts().sum()
    LHighpass2=LHighpass[LHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LHeadpass=L[L['subEventName']=='Head pass']
    LHeadpass1=LHeadpass[LHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    LHeadpass2=LHeadpass[LHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LThrough=L[L['through']!=0]
    LAccThrough=LThrough[LThrough['Accuracy']=='Accurate'].value_counts().sum()
    LNotAccThrough=LThrough[LThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LKeyPass_Assist=L[L['assist']!=0]
    LKeyPass_Assist1=LKeyPass_Assist[LKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_LDis=L['distance'].mean()
    Sd_fl=L['distance'].std()
    av_flAng=L['Angle'].mean()
    
    #Back left Pass
    b=x[x['pass Position']=='Back Left']
    bLACC=b[b['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAcc=b[b['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSimplepass=b[b['subEventName']=='Simple pass']
    bLSimplepass1=bLSimplepass[bLSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    bLSimplepass2=bLSimplepass[bLSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSmartPass=b[b['subEventName']=='Smart pass']
    bLSmartPass1=bLSmartPass[bLSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    bLSmartPass2=bLSmartPass[bLSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLCross=b[b['subEventName']=='Cross']
    bLCross1=bLCross[bLCross['Accuracy']=='Accurate'].value_counts().sum()
    bLCross2=bLCross[bLCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLHighpass=b[b['subEventName']=='High pass']
    bLHighpass1=bLHighpass[bLHighpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHighpass2=bLHighpass[bLHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLHeadpass=b[b['subEventName']=='Head pass']
    bLHeadpass1=bLHeadpass[bLHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHeadpass2=bLHeadpass[bLHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLThrough=b[b['through']!=0]
    bLAccThrough=bLThrough[bLThrough['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAccThrough=bLThrough[bLThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLKeyPass_Assist=b[b['assist']!=0]
    bLKeyPass_Assist1=bLKeyPass_Assist[bLKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    baverage_LDis=b['distance'].mean()
    Sd_Bl=b['distance'].std()
    av_blAng=b['Angle'].mean()
    
    
    
    #info
    y= mi[mi['playerId']==i]
    Minutes=y['minutesPlayed'].sum()
    z=names[names['wyId']==i]
    c=z['firstName'].to_list()
    fname=' '.join(map(str, c))
    b=z['lastName'].to_list()
    lname=' '.join(map(str, b))
    e=z['code3'].to_list()
    position=' '.join(map(str, e))
    c=z['birthDate'].to_list()
    Birthdate=' '.join(map(str, c))
    
     
    #accuracy
    PassACC=((ACC/(ACC+NotAcc))/Minutes)*100
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/Minutes)*100
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/Minutes)*100
    CrossACC=((Cross1/(Cross1+Cross2))/Minutes)*100
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/Minutes)*100
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/Minutes)*100
    ThroughACC=((AccThrough/(AccThrough+NotAccThrough))/Minutes)*100
    KeyPass_AssistAcc=(KeyPass_Assist1/Minutes)*100
    
    
    
    frPassACC=((frACC/(frACC+frNotAcc))/Minutes)*100
    frSimplepassACC=((frSimplepass1/(frSimplepass1+frSimplepass2))/Minutes)*100
    frSmartPassACC=((frSmartPass1/(frSmartPass1+frSmartPass2))/Minutes)*100
    frCrossACC=((frCross1/(frCross1+frCross2))/Minutes)*100
    frHighpassACC=((frHighpass1/(frHighpass1+frHighpass2))/Minutes)*100
    frHeadpassACC=((frHeadpass1/(frHeadpass1+frHeadpass2))/Minutes)*100
    frThroughACC=((frAccThrough/(frAccThrough+frNotAccThrough))/Minutes)*100
    frKeyPass_AssistAcc=(frKeyPass_Assist1/Minutes)*100
    
    
    
    LPassACC=((LACC/(LACC+LNotAcc))/Minutes)*100
    LSimplepassACC=((LSimplepass1/(LSimplepass1+LSimplepass2))/Minutes)*100
    LSmartPassACC=((LSmartPass1/(LSmartPass1+LSmartPass2))/Minutes)*100
    LCrossACC=((LCross1/(LCross1+LCross2))/Minutes)*100
    LHighpassACC=((LHighpass1/(LHighpass1+LHighpass2))/Minutes)*100
    LHeadpassACC=((LHeadpass1/(LHeadpass1+LHeadpass2))/Minutes)*100
    LThroughACC=((LAccThrough/(LAccThrough+LNotAccThrough))/Minutes)*100
    LKeyPass_AssistAcc=(LKeyPass_Assist1/Minutes)*100
    
    
    bLPassACC=((bLACC/(bLACC+bLNotAcc))/Minutes)*100
    bLSimplepassACC=((bLSimplepass1/(bLSimplepass1+bLSimplepass2))/Minutes)*100
    bLSmartPassACC=((bLSmartPass1/(bLSmartPass1+bLSmartPass2))/Minutes)*100
    bLCrossACC=((bLCross1/(bLCross1+bLCross2))/Minutes)*100
    bLHighpassACC=((bLHighpass1/(bLHighpass1+bLHighpass2))/Minutes)*100
    bLHeadpassACC=((bLHeadpass1/(bLHeadpass1+bLHeadpass2))/Minutes)*100
    bLThroughACC=((bLAccThrough/(bLAccThrough+bLNotAccThrough))/Minutes)*100
    bLKeyPass_AssistAcc=(bLKeyPass_Assist1/Minutes)*100
    
    
    
    #duels
    d=h[h['eventName']=='Duel']
    
    AD=d[d['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Dribble=d[d['dribble']!=0]
    AccDribble=Dribble[Dribble['Accuracy']=='Accurate'].value_counts().sum()
    NotAccDribble=Dribble[Dribble['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Tackle=d[d['tackle']!=0]
    AccTackle=Tackle[Tackle['Accuracy']=='Accurate'].value_counts().sum()
    NotAccTackle=Tackle[Tackle['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Interceptions=d[d['interception']!=0]
    AccInterceptions=Interceptions[Interceptions['Accuracy']=='Accurate'].value_counts().sum()
    NotAccInterceptions=Interceptions[Interceptions['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=d[d['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=d[d['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=d[d['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    #duels Accuracy
    AD_ACC=(AccAD/(AccAD+NotAccAD))*100
    Dribble_Acc=(AccDribble/(AccDribble+NotAccDribble))*100
    Tackle_ACC=(AccTackle/(AccTackle+NotAccTackle))*100
    Interceptions_Acc=(AccInterceptions/(AccInterceptions+NotAccInterceptions))*100
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD))*100
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD))*100
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD))*100
    
    
    francedata.append((fname,lname,position,Birthdate,i,
                 
                 ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2
                 ,AccThrough,NotAccThrough,KeyPass_Assist1,average_RDis,Sd_Br,av_brAng,
                 
                 
                 frACC,frNotAcc,frSimplepass1,frSimplepass2,frSmartPass1,frSmartPass2,
                 frCross1,frCross2,frHighpass1,frHighpass2,frHeadpass1,frHeadpass2
                 ,frAccThrough,frNotAccThrough,frKeyPass_Assist1,fraverage_RDis,Sd_fr,av_frAng,
                 
                 
                 bLACC,bLNotAcc,bLSimplepass1,bLSimplepass2,bLSmartPass1,bLSmartPass2,
                 bLCross1,bLCross2,bLHighpass1,bLHighpass2,bLHeadpass1,bLHeadpass2
                 ,bLAccThrough,bLNotAccThrough,bLKeyPass_Assist1,baverage_LDis,Sd_Bl,av_blAng,
                 
                 
                 LACC,LNotAcc,LSimplepass1,LSimplepass2,LSmartPass1,LSmartPass2,
                 LCross1,LCross2,LHighpass1,LHighpass2,Headpass1,LHeadpass2
                 ,LAccThrough,LNotAccThrough,LKeyPass_Assist1,average_LDis,Sd_fl,av_flAng,
                 
                 
                
                
                 Minutes,PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,ThroughACC,KeyPass_AssistAcc,
                 
                 frPassACC,frSimplepassACC,frSmartPassACC,frCrossACC,frHighpassACC,frHeadpassACC,frThroughACC,frKeyPass_AssistAcc,
                
                
                 bLPassACC,bLSimplepassACC,bLSmartPassACC,bLCrossACC,bLHighpassACC,bLHeadpassACC,bLThroughACC,bLKeyPass_AssistAcc,
                 
                 
                 LPassACC,LSimplepassACC,LSmartPassACC,LCrossACC,LHighpassACC,LHeadpassACC,LThroughACC,LKeyPass_AssistAcc,
                  
                  
                 AccAD,NotAccAD,AccDribble,NotAccDribble,AccTackle,NotAccTackle,
                 AccInterceptions,NotAccInterceptions,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                  
                  
                 AD_ACC,Dribble_Acc,Tackle_ACC,Interceptions_Acc,GLD_Acc,GDD_Acc,GAD_Acc))
        

        
franceplayers=pd.DataFrame(francedata,columns=('First Name','Last Name','position','Birth Date','Player ID',
                               
                               
                               'Accurate Back Right Passes','Not Accurate Back Right Passes','Accurate Simple Back Right Passes',
                               'Not Accurate Simple Back Right Passes','Accurate Smart Back Right Passes','Not Accurate Smart Back Right Passes',
                               'Accurate Back Right Cross','Not Accurate Back Right Cross','Accurate High Back Right Passes','Not Accurate High Back Right Passes',
                               'Accurate Head Back Right Passes','Not Accurate Head Back Right Passes',
                               'Acc Back Right Through','Not Acc Back Right Through','Back Right KeyPass+Assist','Back Right pass Average distance',
                               'Back Right pass Average distance SD','Back Right pass Average ANGLE',
                               
                               
                               'Accurate Forward Right Passes','Not Accurate Forward Right Passes','Accurate Simple Forward Right Passes',
                               'Not Accurate Simple Forward Right Passes','Accurate Smart Forward Right Passes','Not Accurate Smart Forward Right Passes',
                               'Accurate Forward Right Cross','Not Accurate Forward Right Cross','Accurate High Forward Right Passes','Not Accurate High Forward Right Passes',
                               'Accurate Head Forward Right Passes','Not Accurate Head Forward Right Passes',
                               'Acc Forward Right Through','Not Acc Forward Right Through','Forward Right KeyPass+Assist','Forward Right pass Average distance',
                               'Forward Right pass Average distance SD','Forward Right pass Average ANGLE',
                               
                               'Accurate Back Left Passes','Not Accurate Back Left Passes','Accurate Simple Back Left Passes',
                               'Not Accurate Simple Back Left Passes','Accurate Smart Back Left Passes','Not Accurate Smart Back Left Passes',
                               'Accurate Back Left Cross','Not Accurate Back Left Cross','Accurate High Back Left Passes','Not Accurate High Back Left Passes',
                               'Accurate Head Back Left Passes','Not Accurate Head Back Left Passes',
                               'Acc Back Left Through','Not Acc Back Left Through','Back Left KeyPass+Assist','Back Left pass Average distance',
                               'Back Left pass Average distance SD','Back Left pass Average ANGLE',
                               
                               'Accurate Forward Left Passes','Not Accurate Forward Left Passes','Accurate Simple Forward Left Passes',
                               'Not Accurate Simple Forward Left Passes','Accurate Smart Forward Left Passes','Not Accurate Smart Forward Left Passes',
                               'Accurate Forward Left Cross','Not Accurate Forward Left Cross','Accurate High Forward Left Passes','Not Accurate High Forward Left Passes',
                               'Accurate Head Forward Left Passes','Not Accurate Head Forward Left Passes',
                               'Acc Forward Left Through','Not Acc Forward Left Through','Forward Left KeyPass+Assist','Forward Left pass Average distance',
                               'Forward Left pass Average distance SD','Forward Left pass Average ANGLE',
                               
                               'Minutes Played','Back Right Pass ACC %','Back Right Simplepass ACC %','Back Right SmartPass ACC %',
                               'Back Right Cross ACC %','Back Right Highpass ACC %','Back Right Headpass ACC %','Back Right Through ACC %','Back Right Chances %',
                               
                               'Forward Right Pass ACC %','Forward Right Simplepass ACC %','Forward Right SmartPass ACC %',
                               'Forward Right Cross ACC %','Forward Right Highpass ACC %','Forward Right Headpass ACC %','Forward Right Through ACC %','Forward Right Chances %',
                               
                               'Back Left Pass ACC %','Back Left Simplepass ACC %','Back Left SmartPass ACC %',
                               'Back Left Cross ACC %','Back Left Highpass ACC %','Back Left Headpass ACC %','Back Left Through ACC %','Back Left Chances %',
                               
                               
                               'Forward Left Pass ACC %','Forward Left Simplepass ACC %','Forward Left SmartPass ACC %',
                               'Forward Left Cross ACC %','Forward Left Highpass ACC %','Forward Left Headpass ACC %','Forward Left Through ACC %','Forward Left Chances %',
                              
                              
                              
                              
                               'Accurate Air Duel','Not Accurate Air Duel','Acc Dribbles','Not Acc Dribbles',
                               'ACC Tackles','Not Acc Tackles','ACC Interceptions','Not Acc Interceptions',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel', 
                               'Air Duel ACC %','Dribble ACC %','SLiding Tackle ACC %','Interceptions ACC %'
                               ,'Ground loose ball duel ACC %','Ground Defending duel ACC %','Ground Attacking duel ACC %')).sort_values('Minutes Played',ascending=False).reset_index().drop('index',axis=1)        
## adding column with the country name 
franceplayers['Country']='France'

# %%
Lplayers=[engplayers,spainplayers,italyplayers,franceplayers,germanyplayers]
leaguesplayers=pd.concat(Lplayers).reset_index().drop('index',axis=1)

# %%
leaguesids = leaguesplayers['Player ID'].unique()
othereuro=eurodf.loc[~eurodf['playerId'].isin(leaguesids)]
otherworld=worlddf.loc[~worlddf['playerId'].isin(leaguesids)]
other = [othereuro,otherworld]
othersdf = pd.concat(other).reset_index().drop('index',axis=1)
othersdf.fillna(0, inplace=True)
othersdf['Accuracy'].replace(1801, "Accurate", inplace=True)
othersdf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)
otherids = othersdf['playerId'].unique()
othersdata = []
for i in otherids :
    
    h=othersdf[othersdf['playerId']==i]
    #Pass
    x=h[h['eventName']=='Pass']
    #Back Right Pass
    s=x[x['pass Position']=='Back Right']
    ACC=s[s['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=s[s['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Through=s[s['through']!=0]
    AccThrough=Through[Through['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrough=Through[Through['Accuracy']=='Not Accurate'].value_counts().sum()
    
    KeyPass_Assist=s[s['assist']!=0]
    KeyPass_Assist1=KeyPass_Assist[KeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_RDis=s['distance'].mean()
    Sd_Br=s['distance'].std()
    av_brAng=s['Angle'].mean()
    
    
    #Forward Right Pass
    
    fr=x[x['pass Position']=='Forward Right']
    frACC=fr[fr['Accuracy']=='Accurate'].value_counts().sum()
    frNotAcc=fr[fr['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSimplepass=fr[fr['subEventName']=='Simple pass']
    frSimplepass1=frSimplepass[frSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    frSimplepass2=frSimplepass[frSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frSmartPass=fr[fr['subEventName']=='Smart pass']
    frSmartPass1=frSmartPass[frSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    frSmartPass2=frSmartPass[frSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frCross=fr[fr['subEventName']=='Cross']
    frCross1=frCross[frCross['Accuracy']=='Accurate'].value_counts().sum()
    frCross2=frCross[frCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frHighpass=fr[fr['subEventName']=='High pass']
    frHighpass1=frHighpass[frHighpass['Accuracy']=='Accurate'].value_counts().sum()
    frHighpass2=frHighpass[frHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frHeadpass=fr[fr['subEventName']=='Head pass']
    frHeadpass1=frHeadpass[frHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    frHeadpass2=frHeadpass[frHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    frThrough=fr[fr['through']!=0]
    frAccThrough=frThrough[frThrough['Accuracy']=='Accurate'].value_counts().sum()
    frNotAccThrough=frThrough[frThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    frKeyPass_Assist=fr[fr['assist']!=0]
    frKeyPass_Assist1=frKeyPass_Assist[frKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    fraverage_RDis=fr['distance'].mean()
    Sd_fr=fr['distance'].std()
    av_frAng=fr['Angle'].mean()
    
    
    
    
    #Forward left Pass
    L=x[x['pass Position']=='Forward Left']
    LACC=L[L['Accuracy']=='Accurate'].value_counts().sum()
    LNotAcc=L[L['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSimplepass=L[L['subEventName']=='Simple pass']
    LSimplepass1=LSimplepass[LSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    LSimplepass2=LSimplepass[LSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LSmartPass=L[L['subEventName']=='Smart pass']
    LSmartPass1=LSmartPass[LSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    LSmartPass2=LSmartPass[LSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LCross=L[L['subEventName']=='Cross']
    LCross1=LCross[LCross['Accuracy']=='Accurate'].value_counts().sum()
    LCross2=LCross[LCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LHighpass=L[L['subEventName']=='High pass']
    LHighpass1=LHighpass[LHighpass['Accuracy']=='Accurate'].value_counts().sum()
    LHighpass2=LHighpass[LHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LHeadpass=L[L['subEventName']=='Head pass']
    LHeadpass1=LHeadpass[LHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    LHeadpass2=LHeadpass[LHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    LThrough=L[L['through']!=0]
    LAccThrough=LThrough[LThrough['Accuracy']=='Accurate'].value_counts().sum()
    LNotAccThrough=LThrough[LThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    LKeyPass_Assist=L[L['assist']!=0]
    LKeyPass_Assist1=LKeyPass_Assist[LKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    average_LDis=L['distance'].mean()
    Sd_fl=L['distance'].std()
    av_flAng=L['Angle'].mean()
    
    #Back left Pass
    b=x[x['pass Position']=='Back Left']
    bLACC=b[b['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAcc=b[b['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSimplepass=b[b['subEventName']=='Simple pass']
    bLSimplepass1=bLSimplepass[bLSimplepass['Accuracy']=='Accurate'].value_counts().sum()
    bLSimplepass2=bLSimplepass[bLSimplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLSmartPass=b[b['subEventName']=='Smart pass']
    bLSmartPass1=bLSmartPass[bLSmartPass['Accuracy']=='Accurate'].value_counts().sum()
    bLSmartPass2=bLSmartPass[bLSmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLCross=b[b['subEventName']=='Cross']
    bLCross1=bLCross[bLCross['Accuracy']=='Accurate'].value_counts().sum()
    bLCross2=bLCross[bLCross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLHighpass=b[b['subEventName']=='High pass']
    bLHighpass1=bLHighpass[bLHighpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHighpass2=bLHighpass[bLHighpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLHeadpass=b[b['subEventName']=='Head pass']
    bLHeadpass1=bLHeadpass[bLHeadpass['Accuracy']=='Accurate'].value_counts().sum()
    bLHeadpass2=bLHeadpass[bLHeadpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    bLThrough=b[b['through']!=0]
    bLAccThrough=bLThrough[bLThrough['Accuracy']=='Accurate'].value_counts().sum()
    bLNotAccThrough=bLThrough[bLThrough['Accuracy']=='Not Accurate'].value_counts().sum()
    
    bLKeyPass_Assist=b[b['assist']!=0]
    bLKeyPass_Assist1=bLKeyPass_Assist[bLKeyPass_Assist['Accuracy']=='Accurate'].value_counts().sum()
    
    baverage_LDis=b['distance'].mean()
    Sd_Bl=b['distance'].std()
    av_blAng=b['Angle'].mean()
    
    
    
    #info
    y= mi[mi['playerId']==i]
    Minutes=y['minutesPlayed'].sum()
    z=names[names['wyId']==i]
    c=z['firstName'].to_list()
    fname=' '.join(map(str, c))
    b=z['lastName'].to_list()
    lname=' '.join(map(str, b))
    e=z['code3'].to_list()
    position=' '.join(map(str, e))
    c=z['birthDate'].to_list()
    Birthdate=' '.join(map(str, c))
    
     
    #accuracy
    PassACC=((ACC/(ACC+NotAcc))/Minutes)*100
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/Minutes)*100
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/Minutes)*100
    CrossACC=((Cross1/(Cross1+Cross2))/Minutes)*100
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/Minutes)*100
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/Minutes)*100
    ThroughACC=((AccThrough/(AccThrough+NotAccThrough))/Minutes)*100
    KeyPass_AssistAcc=(KeyPass_Assist1/Minutes)*100
    
    
    
    frPassACC=((frACC/(frACC+frNotAcc))/Minutes)*100
    frSimplepassACC=((frSimplepass1/(frSimplepass1+frSimplepass2))/Minutes)*100
    frSmartPassACC=((frSmartPass1/(frSmartPass1+frSmartPass2))/Minutes)*100
    frCrossACC=((frCross1/(frCross1+frCross2))/Minutes)*100
    frHighpassACC=((frHighpass1/(frHighpass1+frHighpass2))/Minutes)*100
    frHeadpassACC=((frHeadpass1/(frHeadpass1+frHeadpass2))/Minutes)*100
    frThroughACC=((frAccThrough/(frAccThrough+frNotAccThrough))/Minutes)*100
    frKeyPass_AssistAcc=(frKeyPass_Assist1/Minutes)*100
    
    
    
    LPassACC=((LACC/(LACC+LNotAcc))/Minutes)*100
    LSimplepassACC=((LSimplepass1/(LSimplepass1+LSimplepass2))/Minutes)*100
    LSmartPassACC=((LSmartPass1/(LSmartPass1+LSmartPass2))/Minutes)*100
    LCrossACC=((LCross1/(LCross1+LCross2))/Minutes)*100
    LHighpassACC=((LHighpass1/(LHighpass1+LHighpass2))/Minutes)*100
    LHeadpassACC=((LHeadpass1/(LHeadpass1+LHeadpass2))/Minutes)*100
    LThroughACC=((LAccThrough/(LAccThrough+LNotAccThrough))/Minutes)*100
    LKeyPass_AssistAcc=(LKeyPass_Assist1/Minutes)*100
    
    
    bLPassACC=((bLACC/(bLACC+bLNotAcc))/Minutes)*100
    bLSimplepassACC=((bLSimplepass1/(bLSimplepass1+bLSimplepass2))/Minutes)*100
    bLSmartPassACC=((bLSmartPass1/(bLSmartPass1+bLSmartPass2))/Minutes)*100
    bLCrossACC=((bLCross1/(bLCross1+bLCross2))/Minutes)*100
    bLHighpassACC=((bLHighpass1/(bLHighpass1+bLHighpass2))/Minutes)*100
    bLHeadpassACC=((bLHeadpass1/(bLHeadpass1+bLHeadpass2))/Minutes)*100
    bLThroughACC=((bLAccThrough/(bLAccThrough+bLNotAccThrough))/Minutes)*100
    bLKeyPass_AssistAcc=(bLKeyPass_Assist1/Minutes)*100
    
    
    
    #duels
    d=h[h['eventName']=='Duel']
    
    AD=d[d['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Dribble=d[d['dribble']!=0]
    AccDribble=Dribble[Dribble['Accuracy']=='Accurate'].value_counts().sum()
    NotAccDribble=Dribble[Dribble['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Tackle=d[d['tackle']!=0]
    AccTackle=Tackle[Tackle['Accuracy']=='Accurate'].value_counts().sum()
    NotAccTackle=Tackle[Tackle['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Interceptions=d[d['interception']!=0]
    AccInterceptions=Interceptions[Interceptions['Accuracy']=='Accurate'].value_counts().sum()
    NotAccInterceptions=Interceptions[Interceptions['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=d[d['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=d[d['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=d[d['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    #duels Accuracy
    AD_ACC=(AccAD/(AccAD+NotAccAD))*100
    Dribble_Acc=(AccDribble/(AccDribble+NotAccDribble))*100
    Tackle_ACC=(AccTackle/(AccTackle+NotAccTackle))*100
    Interceptions_Acc=(AccInterceptions/(AccInterceptions+NotAccInterceptions))*100
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD))*100
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD))*100
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD))*100
    
    
    othersdata.append((fname,lname,position,Birthdate,i,
                 
                 ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2
                 ,AccThrough,NotAccThrough,KeyPass_Assist1,average_RDis,Sd_Br,av_brAng,
                 
                 
                 frACC,frNotAcc,frSimplepass1,frSimplepass2,frSmartPass1,frSmartPass2,
                 frCross1,frCross2,frHighpass1,frHighpass2,frHeadpass1,frHeadpass2
                 ,frAccThrough,frNotAccThrough,frKeyPass_Assist1,fraverage_RDis,Sd_fr,av_frAng,
                 
                 
                 bLACC,bLNotAcc,bLSimplepass1,bLSimplepass2,bLSmartPass1,bLSmartPass2,
                 bLCross1,bLCross2,bLHighpass1,bLHighpass2,bLHeadpass1,bLHeadpass2
                 ,bLAccThrough,bLNotAccThrough,bLKeyPass_Assist1,baverage_LDis,Sd_Bl,av_blAng,
                 
                 
                 LACC,LNotAcc,LSimplepass1,LSimplepass2,LSmartPass1,LSmartPass2,
                 LCross1,LCross2,LHighpass1,LHighpass2,Headpass1,LHeadpass2
                 ,LAccThrough,LNotAccThrough,LKeyPass_Assist1,average_LDis,Sd_fl,av_flAng,
                 
                 
                
                
                 Minutes,PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,ThroughACC,KeyPass_AssistAcc,
                 
                 frPassACC,frSimplepassACC,frSmartPassACC,frCrossACC,frHighpassACC,frHeadpassACC,frThroughACC,frKeyPass_AssistAcc,
                
                
                 bLPassACC,bLSimplepassACC,bLSmartPassACC,bLCrossACC,bLHighpassACC,bLHeadpassACC,bLThroughACC,bLKeyPass_AssistAcc,
                 
                 
                 LPassACC,LSimplepassACC,LSmartPassACC,LCrossACC,LHighpassACC,LHeadpassACC,LThroughACC,LKeyPass_AssistAcc,
                  
                  
                 AccAD,NotAccAD,AccDribble,NotAccDribble,AccTackle,NotAccTackle,
                 AccInterceptions,NotAccInterceptions,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                  
                  
                 AD_ACC,Dribble_Acc,Tackle_ACC,Interceptions_Acc,GLD_Acc,GDD_Acc,GAD_Acc))
        

        
otherplayers=pd.DataFrame(othersdata,columns=('First Name','Last Name','position','Birth Date','Player ID',
                               
                               
                               'Accurate Back Right Passes','Not Accurate Back Right Passes','Accurate Simple Back Right Passes',
                               'Not Accurate Simple Back Right Passes','Accurate Smart Back Right Passes','Not Accurate Smart Back Right Passes',
                               'Accurate Back Right Cross','Not Accurate Back Right Cross','Accurate High Back Right Passes','Not Accurate High Back Right Passes',
                               'Accurate Head Back Right Passes','Not Accurate Head Back Right Passes',
                               'Acc Back Right Through','Not Acc Back Right Through','Back Right KeyPass+Assist','Back Right pass Average distance',
                               'Back Right pass Average distance SD','Back Right pass Average ANGLE',
                               
                               
                               'Accurate Forward Right Passes','Not Accurate Forward Right Passes','Accurate Simple Forward Right Passes',
                               'Not Accurate Simple Forward Right Passes','Accurate Smart Forward Right Passes','Not Accurate Smart Forward Right Passes',
                               'Accurate Forward Right Cross','Not Accurate Forward Right Cross','Accurate High Forward Right Passes','Not Accurate High Forward Right Passes',
                               'Accurate Head Forward Right Passes','Not Accurate Head Forward Right Passes',
                               'Acc Forward Right Through','Not Acc Forward Right Through','Forward Right KeyPass+Assist','Forward Right pass Average distance',
                               'Forward Right pass Average distance SD','Forward Right pass Average ANGLE',
                               
                               'Accurate Back Left Passes','Not Accurate Back Left Passes','Accurate Simple Back Left Passes',
                               'Not Accurate Simple Back Left Passes','Accurate Smart Back Left Passes','Not Accurate Smart Back Left Passes',
                               'Accurate Back Left Cross','Not Accurate Back Left Cross','Accurate High Back Left Passes','Not Accurate High Back Left Passes',
                               'Accurate Head Back Left Passes','Not Accurate Head Back Left Passes',
                               'Acc Back Left Through','Not Acc Back Left Through','Back Left KeyPass+Assist','Back Left pass Average distance',
                               'Back Left pass Average distance SD','Back Left pass Average ANGLE',
                               
                               'Accurate Forward Left Passes','Not Accurate Forward Left Passes','Accurate Simple Forward Left Passes',
                               'Not Accurate Simple Forward Left Passes','Accurate Smart Forward Left Passes','Not Accurate Smart Forward Left Passes',
                               'Accurate Forward Left Cross','Not Accurate Forward Left Cross','Accurate High Forward Left Passes','Not Accurate High Forward Left Passes',
                               'Accurate Head Forward Left Passes','Not Accurate Head Forward Left Passes',
                               'Acc Forward Left Through','Not Acc Forward Left Through','Forward Left KeyPass+Assist','Forward Left pass Average distance',
                               'Forward Left pass Average distance SD','Forward Left pass Average ANGLE',
                               
                               'Minutes Played','Back Right Pass ACC %','Back Right Simplepass ACC %','Back Right SmartPass ACC %',
                               'Back Right Cross ACC %','Back Right Highpass ACC %','Back Right Headpass ACC %','Back Right Through ACC %','Back Right Chances %',
                               
                               'Forward Right Pass ACC %','Forward Right Simplepass ACC %','Forward Right SmartPass ACC %',
                               'Forward Right Cross ACC %','Forward Right Highpass ACC %','Forward Right Headpass ACC %','Forward Right Through ACC %','Forward Right Chances %',
                               
                               'Back Left Pass ACC %','Back Left Simplepass ACC %','Back Left SmartPass ACC %',
                               'Back Left Cross ACC %','Back Left Highpass ACC %','Back Left Headpass ACC %','Back Left Through ACC %','Back Left Chances %',
                               
                               
                               'Forward Left Pass ACC %','Forward Left Simplepass ACC %','Forward Left SmartPass ACC %',
                               'Forward Left Cross ACC %','Forward Left Highpass ACC %','Forward Left Headpass ACC %','Forward Left Through ACC %','Forward Left Chances %',
                              
                              
                              
                              
                               'Accurate Air Duel','Not Accurate Air Duel','Acc Dribbles','Not Acc Dribbles',
                               'ACC Tackles','Not Acc Tackles','ACC Interceptions','Not Acc Interceptions',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel', 
                               'Air Duel ACC %','Dribble ACC %','SLiding Tackle ACC %','Interceptions ACC %'
                               ,'Ground loose ball duel ACC %','Ground Defending duel ACC %','Ground Attacking duel ACC %')).sort_values('Minutes Played',ascending=False).reset_index().drop('index',axis=1)        
## adding column with the country name 
otherplayers['Country']='other'

# %%
All=[leaguesplayers,otherplayers]
AllPlayersStats=pd.concat(All).reset_index().drop('index',axis=1)
AllPlayersStats.drop(AllPlayersStats[AllPlayersStats['Player ID'] == 0].index, inplace=True)
AllPlayersStats.to_csv('Players Stats.csv',index=False)

# %% [markdown]
# # Teams Stats

# %% [markdown]
# # England Teams Stats

# %%
engTeamsdata=[]
engteamsids = engdf['teamId'].unique()
engdf['Accuracy'].replace(1801, "Accurate", inplace=True)
engdf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)
for i in engteamsids :
    
    s=engdf[engdf['teamId']==i]
    
    m=s[s['eventName']=='Pass']
    ACC=m[m['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=m[m['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Launch=s[s['subEventName']=='Launch']
    Launch1=Launch[Launch['Accuracy']=='Accurate'].value_counts().sum()
    Launch2=Launch[Launch['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Handpass=s[s['subEventName']=='Hand pass']
    Handpass1=Handpass[Handpass['Accuracy']=='Accurate'].value_counts().sum()
    Handpass2=Handpass[Handpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    AD=s[s['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=s[s['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=s[s['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=s[s['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Free_K=s[s['subEventName']=='Free Kick']
    AccFree_K=Free_K[Free_K['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_K=Free_K[Free_K['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Shot=s[s['subEventName']=='Shot']
    AccShot=Shot[Shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccShot=Shot[Shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Reflexes=s[s['subEventName']=='Reflexes']
    AccReflexes=Reflexes[Reflexes['Accuracy']=='Accurate'].value_counts().sum()
    NotAccReflexes=Reflexes[Reflexes['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Clearance=s[s['subEventName']=='Clearance']
    AccClearance=Clearance[Clearance['Accuracy']=='Accurate'].value_counts().sum()
    NotAccClearance=Clearance[Clearance['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Throw_in=s[s['subEventName']=='Throw in']
    AccThrow_in=Throw_in[Throw_in['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrow_in=Throw_in[Throw_in['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Corner=s[s['subEventName']=='Corner']
    AccCorner=Corner[Corner['Accuracy']=='Accurate'].value_counts().sum()
    NotAccCorner=Corner[Corner['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Save_attempt=s[s['subEventName']=='Save attempt']
    AccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Accurate'].value_counts().sum()
    NotAccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Acceleration=s[s['subEventName']=='Acceleration']
    AccAcceleration=Acceleration[Acceleration['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAcceleration=Acceleration[Acceleration['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_shot=s[s['subEventName']=='Free kick shot']
    AccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_cross=s[s['subEventName']=='Free kick cross']
    AccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Penalty=s[s['subEventName']=='Penalty']
    AccPenalty=Penalty[Penalty['Accuracy']=='Accurate'].value_counts().sum()
    NotAccPenalty=Penalty[Penalty['Accuracy']=='Not Accurate'].value_counts().sum()
    


    
    
    Foul=s[s['subEventName']=='Foul'].value_counts().sum()
        
    Touch=s[s['subEventName']=='Touch'].value_counts().sum()
    
    BOF=s[s['subEventName']=='Ball out of the field'].value_counts().sum()
    
    GK=s[s['subEventName']=='Goal kick'].value_counts().sum()
    
    GLL=s[s['subEventName']=='Goalkeeper leaving line'].value_counts().sum()
    
    HF=s[s['subEventName']=='Hand foul'].value_counts().sum()
    
    Vf=s[s['subEventName']=='Violent Foul'].value_counts().sum()
    
    Pro=s[s['subEventName']=='Protest'].value_counts().sum()
    
    Whi=s[s['subEventName']=='Whistle'].value_counts().sum()
    
    LCF=s[s['subEventName']=='Late card foul'].value_counts().sum()
    
    OGF=s[s['subEventName']=='Out of game foul'].value_counts().sum()
    
    TLF=s[s['subEventName']=='Time lost foul'].value_counts().sum()

    Sim=s[s['subEventName']=='Simulation'].value_counts().sum()
    
    
    
    
    
    PassACC=((ACC/(ACC+NotAcc))/38)
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/38)
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/38)
    CrossACC=((Cross1/(Cross1+Cross2))/38)
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/38)
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/38)
    LaunchACC=((Launch1/(Launch1+Launch2))/38)
    HandpassACC=((Handpass1/(Handpass1+Handpass2))/38)
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD)/38)
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD)/38)
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD)/38)
    AD_ACC=(AccAD/(AccAD+NotAccAD)/38)
    
    Free_KACC=((AccFree_K/(AccFree_K+NotAccFree_K))/38)
    ShotACC=((AccShot/(AccShot+NotAccShot))/38)
    ReflexesACC=((AccReflexes/(AccReflexes+NotAccReflexes))/38)
    ClearanceACC=((AccClearance/(AccClearance+NotAccClearance))/38)
    Throw_inACC=((AccThrow_in/(AccThrow_in+NotAccThrow_in))/38)
    CornerACC=((AccCorner/(AccCorner+NotAccCorner))/38)
    Save_attemptACC=((AccSave_attempt/(AccSave_attempt+NotAccSave_attempt))/38)
    AccelerationACC=((AccAcceleration/(AccAcceleration+NotAccAcceleration))/38)
    Free_kick_shotACC=((AccFree_kick_shot/(AccFree_kick_shot+NotAccFree_kick_shot))/38)
    Free_kick_crossACC=((AccFree_kick_cross/(AccFree_kick_cross+NotAccFree_kick_cross))/38)
    PenaltyACC=((AccPenalty/(AccPenalty+NotAccPenalty))/38)
    
    
    FoulACC=Foul/38
    TouchACC=Touch/38
    BOFACC=BOF/38
    GKACC=GK/38
    GLLACC=GLL/38
    HFACC=HF/38
    VfACC=Vf/38
    ProACC=Pro/38
    WhiACC=Whi/38
    LCFACC=LCF/38
    OGFACC=OGF/38
    TLFACC=TLF/38
    SimACC=Sim/38
    
    
    
    z=teams[teams['wyId']==i]
    c=z['officialName'].to_list()
    Cname=' '.join(map(str, c))
    b=z['type'].to_list()
    Type=' '.join(map(str, b))
    
    
    
    
    
    
    
    
    engTeamsdata.append((Cname,Type,i,ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2,Launch1,Launch2,
                 Handpass1,Handpass2,
                
                
                 AccAD,NotAccAD,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                
                 AccFree_K,NotAccFree_K,AccShot,NotAccShot,AccReflexes,NotAccReflexes,
                 AccClearance,NotAccClearance,AccThrow_in,NotAccThrow_in,AccCorner,
                 NotAccCorner,AccSave_attempt,NotAccSave_attempt,AccAcceleration,
                 NotAccAcceleration,AccFree_kick_shot,NotAccFree_kick_shot,AccFree_kick_cross,
                 NotAccFree_kick_cross,AccPenalty,NotAccPenalty,
                 
                 Foul,Touch,BOF,GK,GLL,HF,Vf,Pro,Whi,LCF,OGF,TLF,Sim,
                 
                 
                 
                 PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,LaunchACC,
                 HandpassACC,
                 
                 AD_ACC,GLD_Acc,GDD_Acc,GAD_Acc,
                 
                 Free_KACC,ShotACC,ReflexesACC,ClearanceACC,Throw_inACC,CornerACC,Save_attemptACC,
                 AccelerationACC,Free_kick_shotACC,Free_kick_crossACC,PenaltyACC,
                 
                 FoulACC,TouchACC,BOFACC,GKACC,GLLACC,HFACC,VfACC,ProACC,WhiACC,LCFACC,
                 OGFACC,TLFACC,SimACC
                
                
                ))
    
    
engTeams=pd.DataFrame(engTeamsdata,columns=('Name','Type','Team ID','Accurate Passes',
                               'Not Accurate Passes','Accurate Simple Passes','Not Accurate Simple Passes',
                               'Accurate Smart Passes','Not Accurate Smart Passes', 'Accurate Cross','Not Accurate Cross',
                               'Accurate High Passes','Not Accurate High Passes','Accurate Head Passes','Not Accurate Head Passes','Accurate Launch','Not Accurate Launch',
                               'Accurate Hand Passes','Not Accurate Hand Passes',
                               
                               
                               'Accurate Air Duel','Not Accurate Air Duel',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel',
                               
                               
                               'Accurate Free Kick','Not Accurate Free Kick','Accurate Shot','Not Accurate Shot',
                               'Accurate Reflexes','Not Accurate Reflexes', 'Accurate Clearance','Not Accurate Clearance',
                               'Accurate Throw in','Not Accurate Throw in','Accurate Corner','Not Accurate Corner',
                               'Accurate Save attempt','Not Accurate Save attempt','Accurate Acceleration','Not Accurate Acceleration',
                               
                               'Accurate Free kick shot','Not Accurate Free kick shot','Accurate Free kick cross',
                               'Not Accurate Free kick cross','Accurate Penalty','Not Accurate Penalty',
                               
                               
                               'Foul','Touch','Ball Out of Field','Goal Kick','Goalkeeper leaving line','Hand Foul'
                               ,'Violent foul','Protest','Whistle','Late Card Foul','Out of Game Foul','Time lost foul','Simulation',
                               
                            
                               
                               'Pass Accuracy','Simplepass Accuracy','SmartPass Accuracy',
                               'Cross Accuracy','Highpass Accuracy','Headpass Accuracy','Launch Accuracy',
                               'Handpass Accuracy',
                               
                               
                               'Air Duel ACC %','Ground loose ball duel ACC %',
                               'Ground Defending duel ACC %','Ground Attacking duel ACC %',
                               
                               
                               'Free Kick Accuracy','Shot Accuracy','Reflexes Accuracy',
                               'Clearance Accuracy','Throw in Accuracy','Corner Accuracy','Save attempt Accuracy',
                               'Acceleration Accuracy','Free kick shot Accuracy','Free kick cross Accuracy','Penalty Accuracy',
                               
                               'Foul Per Match','Touch Per Match','Ball Out of Field Per Match','Goal Kick Per Match','Goalkeeper leaving linePer Match',
                               'Hand Foul Per Match','Violent foul Per Match','Protest Per Match','Whistle Per Match','Late Card Foul Per Match',
                               'Out of Game Foul Per Match','Time lost foul Per Match','Simulation Per Match'
                               
                              

                              )).sort_values('Accurate Passes',ascending=False).reset_index().drop('index',axis=1)
engTeams['Country']='England'

# %% [markdown]
# # Italy Teams Stats

# %%
italyTeamsdata=[]
italyTeamsids = italydf['teamId'].unique()
italydf['Accuracy'].replace(1801, "Accurate", inplace=True)
italydf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)
for i in italyTeamsids :
    
    s=italydf[italydf['teamId']==i]
    
    m=s[s['eventName']=='Pass']
    ACC=m[m['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=m[m['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Launch=s[s['subEventName']=='Launch']
    Launch1=Launch[Launch['Accuracy']=='Accurate'].value_counts().sum()
    Launch2=Launch[Launch['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Handpass=s[s['subEventName']=='Hand pass']
    Handpass1=Handpass[Handpass['Accuracy']=='Accurate'].value_counts().sum()
    Handpass2=Handpass[Handpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    AD=s[s['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=s[s['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=s[s['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=s[s['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Free_K=s[s['subEventName']=='Free Kick']
    AccFree_K=Free_K[Free_K['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_K=Free_K[Free_K['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Shot=s[s['subEventName']=='Shot']
    AccShot=Shot[Shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccShot=Shot[Shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Reflexes=s[s['subEventName']=='Reflexes']
    AccReflexes=Reflexes[Reflexes['Accuracy']=='Accurate'].value_counts().sum()
    NotAccReflexes=Reflexes[Reflexes['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Clearance=s[s['subEventName']=='Clearance']
    AccClearance=Clearance[Clearance['Accuracy']=='Accurate'].value_counts().sum()
    NotAccClearance=Clearance[Clearance['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Throw_in=s[s['subEventName']=='Throw in']
    AccThrow_in=Throw_in[Throw_in['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrow_in=Throw_in[Throw_in['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Corner=s[s['subEventName']=='Corner']
    AccCorner=Corner[Corner['Accuracy']=='Accurate'].value_counts().sum()
    NotAccCorner=Corner[Corner['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Save_attempt=s[s['subEventName']=='Save attempt']
    AccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Accurate'].value_counts().sum()
    NotAccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Acceleration=s[s['subEventName']=='Acceleration']
    AccAcceleration=Acceleration[Acceleration['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAcceleration=Acceleration[Acceleration['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_shot=s[s['subEventName']=='Free kick shot']
    AccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_cross=s[s['subEventName']=='Free kick cross']
    AccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Penalty=s[s['subEventName']=='Penalty']
    AccPenalty=Penalty[Penalty['Accuracy']=='Accurate'].value_counts().sum()
    NotAccPenalty=Penalty[Penalty['Accuracy']=='Not Accurate'].value_counts().sum()
    


    
    
    Foul=s[s['subEventName']=='Foul'].value_counts().sum()
        
    Touch=s[s['subEventName']=='Touch'].value_counts().sum()
    
    BOF=s[s['subEventName']=='Ball out of the field'].value_counts().sum()
    
    GK=s[s['subEventName']=='Goal kick'].value_counts().sum()
    
    GLL=s[s['subEventName']=='Goalkeeper leaving line'].value_counts().sum()
    
    HF=s[s['subEventName']=='Hand foul'].value_counts().sum()
    
    Vf=s[s['subEventName']=='Violent Foul'].value_counts().sum()
    
    Pro=s[s['subEventName']=='Protest'].value_counts().sum()
    
    Whi=s[s['subEventName']=='Whistle'].value_counts().sum()
    
    LCF=s[s['subEventName']=='Late card foul'].value_counts().sum()
    
    OGF=s[s['subEventName']=='Out of game foul'].value_counts().sum()
    
    TLF=s[s['subEventName']=='Time lost foul'].value_counts().sum()

    Sim=s[s['subEventName']=='Simulation'].value_counts().sum()
    
    
    
    
    
    PassACC=((ACC/(ACC+NotAcc))/38)
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/38)
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/38)
    CrossACC=((Cross1/(Cross1+Cross2))/38)
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/38)
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/38)
    LaunchACC=((Launch1/(Launch1+Launch2))/38)
    HandpassACC=((Handpass1/(Handpass1+Handpass2))/38)
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD)/38)
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD)/38)
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD)/38)
    AD_ACC=(AccAD/(AccAD+NotAccAD)/38)
    
    Free_KACC=((AccFree_K/(AccFree_K+NotAccFree_K))/38)
    ShotACC=((AccShot/(AccShot+NotAccShot))/38)
    ReflexesACC=((AccReflexes/(AccReflexes+NotAccReflexes))/38)
    ClearanceACC=((AccClearance/(AccClearance+NotAccClearance))/38)
    Throw_inACC=((AccThrow_in/(AccThrow_in+NotAccThrow_in))/38)
    CornerACC=((AccCorner/(AccCorner+NotAccCorner))/38)
    Save_attemptACC=((AccSave_attempt/(AccSave_attempt+NotAccSave_attempt))/38)
    AccelerationACC=((AccAcceleration/(AccAcceleration+NotAccAcceleration))/38)
    Free_kick_shotACC=((AccFree_kick_shot/(AccFree_kick_shot+NotAccFree_kick_shot))/38)
    Free_kick_crossACC=((AccFree_kick_cross/(AccFree_kick_cross+NotAccFree_kick_cross))/38)
    PenaltyACC=((AccPenalty/(AccPenalty+NotAccPenalty))/38)
    
    
    FoulACC=Foul/38
    TouchACC=Touch/38
    BOFACC=BOF/38
    GKACC=GK/38
    GLLACC=GLL/38
    HFACC=HF/38
    VfACC=Vf/38
    ProACC=Pro/38
    WhiACC=Whi/38
    LCFACC=LCF/38
    OGFACC=OGF/38
    TLFACC=TLF/38
    SimACC=Sim/38
    
    
    
    z=teams[teams['wyId']==i]
    c=z['officialName'].to_list()
    Cname=' '.join(map(str, c))
    b=z['type'].to_list()
    Type=' '.join(map(str, b))
    
    
    
    
    
    
    
    
    italyTeamsdata.append((Cname,Type,i,ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2,Launch1,Launch2,
                 Handpass1,Handpass2,
                
                
                 AccAD,NotAccAD,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                
                 AccFree_K,NotAccFree_K,AccShot,NotAccShot,AccReflexes,NotAccReflexes,
                 AccClearance,NotAccClearance,AccThrow_in,NotAccThrow_in,AccCorner,
                 NotAccCorner,AccSave_attempt,NotAccSave_attempt,AccAcceleration,
                 NotAccAcceleration,AccFree_kick_shot,NotAccFree_kick_shot,AccFree_kick_cross,
                 NotAccFree_kick_cross,AccPenalty,NotAccPenalty,
                 
                 Foul,Touch,BOF,GK,GLL,HF,Vf,Pro,Whi,LCF,OGF,TLF,Sim,
                 
                 
                 
                 PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,LaunchACC,
                 HandpassACC,
                 
                 AD_ACC,GLD_Acc,GDD_Acc,GAD_Acc,
                 
                 Free_KACC,ShotACC,ReflexesACC,ClearanceACC,Throw_inACC,CornerACC,Save_attemptACC,
                 AccelerationACC,Free_kick_shotACC,Free_kick_crossACC,PenaltyACC,
                 
                 FoulACC,TouchACC,BOFACC,GKACC,GLLACC,HFACC,VfACC,ProACC,WhiACC,LCFACC,
                 OGFACC,TLFACC,SimACC
                
                
                ))
    
    
italyTeams=pd.DataFrame(italyTeamsdata,columns=('Name','Type','Team ID','Accurate Passes',
                               'Not Accurate Passes','Accurate Simple Passes','Not Accurate Simple Passes',
                               'Accurate Smart Passes','Not Accurate Smart Passes', 'Accurate Cross','Not Accurate Cross',
                               'Accurate High Passes','Not Accurate High Passes','Accurate Head Passes','Not Accurate Head Passes','Accurate Launch','Not Accurate Launch',
                               'Accurate Hand Passes','Not Accurate Hand Passes',
                               
                               
                               'Accurate Air Duel','Not Accurate Air Duel',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel',
                               
                               
                               'Accurate Free Kick','Not Accurate Free Kick','Accurate Shot','Not Accurate Shot',
                               'Accurate Reflexes','Not Accurate Reflexes', 'Accurate Clearance','Not Accurate Clearance',
                               'Accurate Throw in','Not Accurate Throw in','Accurate Corner','Not Accurate Corner',
                               'Accurate Save attempt','Not Accurate Save attempt','Accurate Acceleration','Not Accurate Acceleration',
                               
                               'Accurate Free kick shot','Not Accurate Free kick shot','Accurate Free kick cross',
                               'Not Accurate Free kick cross','Accurate Penalty','Not Accurate Penalty',
                               
                               
                               'Foul','Touch','Ball Out of Field','Goal Kick','Goalkeeper leaving line','Hand Foul'
                               ,'Violent foul','Protest','Whistle','Late Card Foul','Out of Game Foul','Time lost foul','Simulation',
                               
                            
                               
                               'Pass Accuracy','Simplepass Accuracy','SmartPass Accuracy',
                               'Cross Accuracy','Highpass Accuracy','Headpass Accuracy','Launch Accuracy',
                               'Handpass Accuracy',
                               
                               
                               'Air Duel ACC %','Ground loose ball duel ACC %',
                               'Ground Defending duel ACC %','Ground Attacking duel ACC %',
                               
                               
                               'Free Kick Accuracy','Shot Accuracy','Reflexes Accuracy',
                               'Clearance Accuracy','Throw in Accuracy','Corner Accuracy','Save attempt Accuracy',
                               'Acceleration Accuracy','Free kick shot Accuracy','Free kick cross Accuracy','Penalty Accuracy',
                               
                               'Foul Per Match','Touch Per Match','Ball Out of Field Per Match','Goal Kick Per Match','Goalkeeper leaving linePer Match',
                               'Hand Foul Per Match','Violent foul Per Match','Protest Per Match','Whistle Per Match','Late Card Foul Per Match',
                               'Out of Game Foul Per Match','Time lost foul Per Match','Simulation Per Match'
                               
                              

                              )).sort_values('Accurate Passes',ascending=False).reset_index().drop('index',axis=1)
italyTeams['Country']='Italy'

# %% [markdown]
# # Spain Teams Stats

# %%
spainTeamsdata=[]
spainTeamsids = spaindf['teamId'].unique()
spaindf['Accuracy'].replace(1801, "Accurate", inplace=True)
spaindf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)
for i in spainTeamsids :
    
    s=spaindf[spaindf['teamId']==i]
    
    m=s[s['eventName']=='Pass']
    ACC=m[m['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=m[m['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Launch=s[s['subEventName']=='Launch']
    Launch1=Launch[Launch['Accuracy']=='Accurate'].value_counts().sum()
    Launch2=Launch[Launch['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Handpass=s[s['subEventName']=='Hand pass']
    Handpass1=Handpass[Handpass['Accuracy']=='Accurate'].value_counts().sum()
    Handpass2=Handpass[Handpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    AD=s[s['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=s[s['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=s[s['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=s[s['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Free_K=s[s['subEventName']=='Free Kick']
    AccFree_K=Free_K[Free_K['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_K=Free_K[Free_K['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Shot=s[s['subEventName']=='Shot']
    AccShot=Shot[Shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccShot=Shot[Shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Reflexes=s[s['subEventName']=='Reflexes']
    AccReflexes=Reflexes[Reflexes['Accuracy']=='Accurate'].value_counts().sum()
    NotAccReflexes=Reflexes[Reflexes['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Clearance=s[s['subEventName']=='Clearance']
    AccClearance=Clearance[Clearance['Accuracy']=='Accurate'].value_counts().sum()
    NotAccClearance=Clearance[Clearance['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Throw_in=s[s['subEventName']=='Throw in']
    AccThrow_in=Throw_in[Throw_in['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrow_in=Throw_in[Throw_in['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Corner=s[s['subEventName']=='Corner']
    AccCorner=Corner[Corner['Accuracy']=='Accurate'].value_counts().sum()
    NotAccCorner=Corner[Corner['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Save_attempt=s[s['subEventName']=='Save attempt']
    AccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Accurate'].value_counts().sum()
    NotAccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Acceleration=s[s['subEventName']=='Acceleration']
    AccAcceleration=Acceleration[Acceleration['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAcceleration=Acceleration[Acceleration['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_shot=s[s['subEventName']=='Free kick shot']
    AccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_cross=s[s['subEventName']=='Free kick cross']
    AccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Penalty=s[s['subEventName']=='Penalty']
    AccPenalty=Penalty[Penalty['Accuracy']=='Accurate'].value_counts().sum()
    NotAccPenalty=Penalty[Penalty['Accuracy']=='Not Accurate'].value_counts().sum()
    


    
    
    Foul=s[s['subEventName']=='Foul'].value_counts().sum()
        
    Touch=s[s['subEventName']=='Touch'].value_counts().sum()
    
    BOF=s[s['subEventName']=='Ball out of the field'].value_counts().sum()
    
    GK=s[s['subEventName']=='Goal kick'].value_counts().sum()
    
    GLL=s[s['subEventName']=='Goalkeeper leaving line'].value_counts().sum()
    
    HF=s[s['subEventName']=='Hand foul'].value_counts().sum()
    
    Vf=s[s['subEventName']=='Violent Foul'].value_counts().sum()
    
    Pro=s[s['subEventName']=='Protest'].value_counts().sum()
    
    Whi=s[s['subEventName']=='Whistle'].value_counts().sum()
    
    LCF=s[s['subEventName']=='Late card foul'].value_counts().sum()
    
    OGF=s[s['subEventName']=='Out of game foul'].value_counts().sum()
    
    TLF=s[s['subEventName']=='Time lost foul'].value_counts().sum()

    Sim=s[s['subEventName']=='Simulation'].value_counts().sum()
    
    
    
    
    
    PassACC=((ACC/(ACC+NotAcc))/38)
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/38)
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/38)
    CrossACC=((Cross1/(Cross1+Cross2))/38)
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/38)
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/38)
    LaunchACC=((Launch1/(Launch1+Launch2))/38)
    HandpassACC=((Handpass1/(Handpass1+Handpass2))/38)
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD)/38)
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD)/38)
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD)/38)
    AD_ACC=(AccAD/(AccAD+NotAccAD)/38)
    
    Free_KACC=((AccFree_K/(AccFree_K+NotAccFree_K))/38)
    ShotACC=((AccShot/(AccShot+NotAccShot))/38)
    ReflexesACC=((AccReflexes/(AccReflexes+NotAccReflexes))/38)
    ClearanceACC=((AccClearance/(AccClearance+NotAccClearance))/38)
    Throw_inACC=((AccThrow_in/(AccThrow_in+NotAccThrow_in))/38)
    CornerACC=((AccCorner/(AccCorner+NotAccCorner))/38)
    Save_attemptACC=((AccSave_attempt/(AccSave_attempt+NotAccSave_attempt))/38)
    AccelerationACC=((AccAcceleration/(AccAcceleration+NotAccAcceleration))/38)
    Free_kick_shotACC=((AccFree_kick_shot/(AccFree_kick_shot+NotAccFree_kick_shot))/38)
    Free_kick_crossACC=((AccFree_kick_cross/(AccFree_kick_cross+NotAccFree_kick_cross))/38)
    PenaltyACC=((AccPenalty/(AccPenalty+NotAccPenalty))/38)
    
    
    FoulACC=Foul/38
    TouchACC=Touch/38
    BOFACC=BOF/38
    GKACC=GK/38
    GLLACC=GLL/38
    HFACC=HF/38
    VfACC=Vf/38
    ProACC=Pro/38
    WhiACC=Whi/38
    LCFACC=LCF/38
    OGFACC=OGF/38
    TLFACC=TLF/38
    SimACC=Sim/38
    
    
    
    z=teams[teams['wyId']==i]
    c=z['officialName'].to_list()
    Cname=' '.join(map(str, c))
    b=z['type'].to_list()
    Type=' '.join(map(str, b))
    
    
    
    
    
    
    
    
    spainTeamsdata.append((Cname,Type,i,ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2,Launch1,Launch2,
                 Handpass1,Handpass2,
                
                
                 AccAD,NotAccAD,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                
                 AccFree_K,NotAccFree_K,AccShot,NotAccShot,AccReflexes,NotAccReflexes,
                 AccClearance,NotAccClearance,AccThrow_in,NotAccThrow_in,AccCorner,
                 NotAccCorner,AccSave_attempt,NotAccSave_attempt,AccAcceleration,
                 NotAccAcceleration,AccFree_kick_shot,NotAccFree_kick_shot,AccFree_kick_cross,
                 NotAccFree_kick_cross,AccPenalty,NotAccPenalty,
                 
                 Foul,Touch,BOF,GK,GLL,HF,Vf,Pro,Whi,LCF,OGF,TLF,Sim,
                 
                 
                 
                 PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,LaunchACC,
                 HandpassACC,
                 
                 AD_ACC,GLD_Acc,GDD_Acc,GAD_Acc,
                 
                 Free_KACC,ShotACC,ReflexesACC,ClearanceACC,Throw_inACC,CornerACC,Save_attemptACC,
                 AccelerationACC,Free_kick_shotACC,Free_kick_crossACC,PenaltyACC,
                 
                 FoulACC,TouchACC,BOFACC,GKACC,GLLACC,HFACC,VfACC,ProACC,WhiACC,LCFACC,
                 OGFACC,TLFACC,SimACC
                
                
                ))
    
    
spainTeams=pd.DataFrame(spainTeamsdata,columns=('Name','Type','Team ID','Accurate Passes',
                               'Not Accurate Passes','Accurate Simple Passes','Not Accurate Simple Passes',
                               'Accurate Smart Passes','Not Accurate Smart Passes', 'Accurate Cross','Not Accurate Cross',
                               'Accurate High Passes','Not Accurate High Passes','Accurate Head Passes','Not Accurate Head Passes','Accurate Launch','Not Accurate Launch',
                               'Accurate Hand Passes','Not Accurate Hand Passes',
                               
                               
                               'Accurate Air Duel','Not Accurate Air Duel',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel',
                               
                               
                               'Accurate Free Kick','Not Accurate Free Kick','Accurate Shot','Not Accurate Shot',
                               'Accurate Reflexes','Not Accurate Reflexes', 'Accurate Clearance','Not Accurate Clearance',
                               'Accurate Throw in','Not Accurate Throw in','Accurate Corner','Not Accurate Corner',
                               'Accurate Save attempt','Not Accurate Save attempt','Accurate Acceleration','Not Accurate Acceleration',
                               
                               'Accurate Free kick shot','Not Accurate Free kick shot','Accurate Free kick cross',
                               'Not Accurate Free kick cross','Accurate Penalty','Not Accurate Penalty',
                               
                               
                               'Foul','Touch','Ball Out of Field','Goal Kick','Goalkeeper leaving line','Hand Foul'
                               ,'Violent foul','Protest','Whistle','Late Card Foul','Out of Game Foul','Time lost foul','Simulation',
                               
                            
                               
                               'Pass Accuracy','Simplepass Accuracy','SmartPass Accuracy',
                               'Cross Accuracy','Highpass Accuracy','Headpass Accuracy','Launch Accuracy',
                               'Handpass Accuracy',
                               
                               
                               'Air Duel ACC %','Ground loose ball duel ACC %',
                               'Ground Defending duel ACC %','Ground Attacking duel ACC %',
                               
                               
                               'Free Kick Accuracy','Shot Accuracy','Reflexes Accuracy',
                               'Clearance Accuracy','Throw in Accuracy','Corner Accuracy','Save attempt Accuracy',
                               'Acceleration Accuracy','Free kick shot Accuracy','Free kick cross Accuracy','Penalty Accuracy',
                               
                               'Foul Per Match','Touch Per Match','Ball Out of Field Per Match','Goal Kick Per Match','Goalkeeper leaving linePer Match',
                               'Hand Foul Per Match','Violent foul Per Match','Protest Per Match','Whistle Per Match','Late Card Foul Per Match',
                               'Out of Game Foul Per Match','Time lost foul Per Match','Simulation Per Match'
                               
                              

                              )).sort_values('Accurate Passes',ascending=False).reset_index().drop('index',axis=1)
spainTeams['Country']='Spain'

# %% [markdown]
# # France Teams Stats

# %%
franceTeamsdata=[]
franceTeamsids = francedf['teamId'].unique()
francedf['Accuracy'].replace(1801, "Accurate", inplace=True)
francedf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)
for i in franceTeamsids :
    
    s=francedf[francedf['teamId']==i]
    
    m=s[s['eventName']=='Pass']
    ACC=m[m['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=m[m['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Launch=s[s['subEventName']=='Launch']
    Launch1=Launch[Launch['Accuracy']=='Accurate'].value_counts().sum()
    Launch2=Launch[Launch['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Handpass=s[s['subEventName']=='Hand pass']
    Handpass1=Handpass[Handpass['Accuracy']=='Accurate'].value_counts().sum()
    Handpass2=Handpass[Handpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    AD=s[s['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=s[s['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=s[s['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=s[s['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Free_K=s[s['subEventName']=='Free Kick']
    AccFree_K=Free_K[Free_K['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_K=Free_K[Free_K['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Shot=s[s['subEventName']=='Shot']
    AccShot=Shot[Shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccShot=Shot[Shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Reflexes=s[s['subEventName']=='Reflexes']
    AccReflexes=Reflexes[Reflexes['Accuracy']=='Accurate'].value_counts().sum()
    NotAccReflexes=Reflexes[Reflexes['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Clearance=s[s['subEventName']=='Clearance']
    AccClearance=Clearance[Clearance['Accuracy']=='Accurate'].value_counts().sum()
    NotAccClearance=Clearance[Clearance['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Throw_in=s[s['subEventName']=='Throw in']
    AccThrow_in=Throw_in[Throw_in['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrow_in=Throw_in[Throw_in['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Corner=s[s['subEventName']=='Corner']
    AccCorner=Corner[Corner['Accuracy']=='Accurate'].value_counts().sum()
    NotAccCorner=Corner[Corner['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Save_attempt=s[s['subEventName']=='Save attempt']
    AccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Accurate'].value_counts().sum()
    NotAccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Acceleration=s[s['subEventName']=='Acceleration']
    AccAcceleration=Acceleration[Acceleration['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAcceleration=Acceleration[Acceleration['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_shot=s[s['subEventName']=='Free kick shot']
    AccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_cross=s[s['subEventName']=='Free kick cross']
    AccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Penalty=s[s['subEventName']=='Penalty']
    AccPenalty=Penalty[Penalty['Accuracy']=='Accurate'].value_counts().sum()
    NotAccPenalty=Penalty[Penalty['Accuracy']=='Not Accurate'].value_counts().sum()
    


    
    
    Foul=s[s['subEventName']=='Foul'].value_counts().sum()
        
    Touch=s[s['subEventName']=='Touch'].value_counts().sum()
    
    BOF=s[s['subEventName']=='Ball out of the field'].value_counts().sum()
    
    GK=s[s['subEventName']=='Goal kick'].value_counts().sum()
    
    GLL=s[s['subEventName']=='Goalkeeper leaving line'].value_counts().sum()
    
    HF=s[s['subEventName']=='Hand foul'].value_counts().sum()
    
    Vf=s[s['subEventName']=='Violent Foul'].value_counts().sum()
    
    Pro=s[s['subEventName']=='Protest'].value_counts().sum()
    
    Whi=s[s['subEventName']=='Whistle'].value_counts().sum()
    
    LCF=s[s['subEventName']=='Late card foul'].value_counts().sum()
    
    OGF=s[s['subEventName']=='Out of game foul'].value_counts().sum()
    
    TLF=s[s['subEventName']=='Time lost foul'].value_counts().sum()

    Sim=s[s['subEventName']=='Simulation'].value_counts().sum()
    
    
    
    
    
    PassACC=((ACC/(ACC+NotAcc))/38)
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/38)
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/38)
    CrossACC=((Cross1/(Cross1+Cross2))/38)
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/38)
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/38)
    LaunchACC=((Launch1/(Launch1+Launch2))/38)
    HandpassACC=((Handpass1/(Handpass1+Handpass2))/38)
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD)/38)
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD)/38)
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD)/38)
    AD_ACC=(AccAD/(AccAD+NotAccAD)/38)
    
    Free_KACC=((AccFree_K/(AccFree_K+NotAccFree_K))/38)
    ShotACC=((AccShot/(AccShot+NotAccShot))/38)
    ReflexesACC=((AccReflexes/(AccReflexes+NotAccReflexes))/38)
    ClearanceACC=((AccClearance/(AccClearance+NotAccClearance))/38)
    Throw_inACC=((AccThrow_in/(AccThrow_in+NotAccThrow_in))/38)
    CornerACC=((AccCorner/(AccCorner+NotAccCorner))/38)
    Save_attemptACC=((AccSave_attempt/(AccSave_attempt+NotAccSave_attempt))/38)
    AccelerationACC=((AccAcceleration/(AccAcceleration+NotAccAcceleration))/38)
    Free_kick_shotACC=((AccFree_kick_shot/(AccFree_kick_shot+NotAccFree_kick_shot))/38)
    Free_kick_crossACC=((AccFree_kick_cross/(AccFree_kick_cross+NotAccFree_kick_cross))/38)
    PenaltyACC=((AccPenalty/(AccPenalty+NotAccPenalty))/38)
    
    
    FoulACC=Foul/38
    TouchACC=Touch/38
    BOFACC=BOF/38
    GKACC=GK/38
    GLLACC=GLL/38
    HFACC=HF/38
    VfACC=Vf/38
    ProACC=Pro/38
    WhiACC=Whi/38
    LCFACC=LCF/38
    OGFACC=OGF/38
    TLFACC=TLF/38
    SimACC=Sim/38
    
    
    
    z=teams[teams['wyId']==i]
    c=z['officialName'].to_list()
    Cname=' '.join(map(str, c))
    b=z['type'].to_list()
    Type=' '.join(map(str, b))
    
    
    
    
    
    
    
    
    franceTeamsdata.append((Cname,Type,i,ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2,Launch1,Launch2,
                 Handpass1,Handpass2,
                
                
                 AccAD,NotAccAD,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                
                 AccFree_K,NotAccFree_K,AccShot,NotAccShot,AccReflexes,NotAccReflexes,
                 AccClearance,NotAccClearance,AccThrow_in,NotAccThrow_in,AccCorner,
                 NotAccCorner,AccSave_attempt,NotAccSave_attempt,AccAcceleration,
                 NotAccAcceleration,AccFree_kick_shot,NotAccFree_kick_shot,AccFree_kick_cross,
                 NotAccFree_kick_cross,AccPenalty,NotAccPenalty,
                 
                 Foul,Touch,BOF,GK,GLL,HF,Vf,Pro,Whi,LCF,OGF,TLF,Sim,
                 
                 
                 
                 PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,LaunchACC,
                 HandpassACC,
                 
                 AD_ACC,GLD_Acc,GDD_Acc,GAD_Acc,
                 
                 Free_KACC,ShotACC,ReflexesACC,ClearanceACC,Throw_inACC,CornerACC,Save_attemptACC,
                 AccelerationACC,Free_kick_shotACC,Free_kick_crossACC,PenaltyACC,
                 
                 FoulACC,TouchACC,BOFACC,GKACC,GLLACC,HFACC,VfACC,ProACC,WhiACC,LCFACC,
                 OGFACC,TLFACC,SimACC
                
                
                ))
    
    
franceTeams=pd.DataFrame(franceTeamsdata,columns=('Name','Type','Team ID','Accurate Passes',
                               'Not Accurate Passes','Accurate Simple Passes','Not Accurate Simple Passes',
                               'Accurate Smart Passes','Not Accurate Smart Passes', 'Accurate Cross','Not Accurate Cross',
                               'Accurate High Passes','Not Accurate High Passes','Accurate Head Passes','Not Accurate Head Passes','Accurate Launch','Not Accurate Launch',
                               'Accurate Hand Passes','Not Accurate Hand Passes',
                               
                               
                               'Accurate Air Duel','Not Accurate Air Duel',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel',
                               
                               
                               'Accurate Free Kick','Not Accurate Free Kick','Accurate Shot','Not Accurate Shot',
                               'Accurate Reflexes','Not Accurate Reflexes', 'Accurate Clearance','Not Accurate Clearance',
                               'Accurate Throw in','Not Accurate Throw in','Accurate Corner','Not Accurate Corner',
                               'Accurate Save attempt','Not Accurate Save attempt','Accurate Acceleration','Not Accurate Acceleration',
                               
                               'Accurate Free kick shot','Not Accurate Free kick shot','Accurate Free kick cross',
                               'Not Accurate Free kick cross','Accurate Penalty','Not Accurate Penalty',
                               
                               
                               'Foul','Touch','Ball Out of Field','Goal Kick','Goalkeeper leaving line','Hand Foul'
                               ,'Violent foul','Protest','Whistle','Late Card Foul','Out of Game Foul','Time lost foul','Simulation',
                               
                            
                               
                               'Pass Accuracy','Simplepass Accuracy','SmartPass Accuracy',
                               'Cross Accuracy','Highpass Accuracy','Headpass Accuracy','Launch Accuracy',
                               'Handpass Accuracy',
                               
                               
                               'Air Duel ACC %','Ground loose ball duel ACC %',
                               'Ground Defending duel ACC %','Ground Attacking duel ACC %',
                               
                               
                               'Free Kick Accuracy','Shot Accuracy','Reflexes Accuracy',
                               'Clearance Accuracy','Throw in Accuracy','Corner Accuracy','Save attempt Accuracy',
                               'Acceleration Accuracy','Free kick shot Accuracy','Free kick cross Accuracy','Penalty Accuracy',
                               
                               'Foul Per Match','Touch Per Match','Ball Out of Field Per Match','Goal Kick Per Match','Goalkeeper leaving linePer Match',
                               'Hand Foul Per Match','Violent foul Per Match','Protest Per Match','Whistle Per Match','Late Card Foul Per Match',
                               'Out of Game Foul Per Match','Time lost foul Per Match','Simulation Per Match'
                               
                              

                              )).sort_values('Accurate Passes',ascending=False).reset_index().drop('index',axis=1)
franceTeams['Country']='France'

# %% [markdown]
# # Germany Teams Stats

# %%
germanyTeamsdata=[]
germanyTeamsids = germanydf['teamId'].unique()
germanydf['Accuracy'].replace(1801, "Accurate", inplace=True)
germanydf['Accuracy'].replace(1802, 'Not Accurate', inplace=True)
for i in germanyTeamsids :
    
    s=germanydf[germanydf['teamId']==i]
    
    m=s[s['eventName']=='Pass']
    ACC=m[m['Accuracy']=='Accurate'].value_counts().sum()
    NotAcc=m[m['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Simplepass=s[s['subEventName']=='Simple pass']
    Simplepass1=Simplepass[Simplepass['Accuracy']=='Accurate'].value_counts().sum()
    Simplepass2=Simplepass[Simplepass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    SmartPass=s[s['subEventName']=='Smart pass']
    SmartPass1=SmartPass[SmartPass['Accuracy']=='Accurate'].value_counts().sum()
    SmartPass2=SmartPass[SmartPass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Headpass=s[s['subEventName']=='Head pass']
    Headpass1=Headpass[Headpass['Accuracy']=='Accurate'].value_counts().sum()
    Headpass2=Headpass[Headpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Cross=s[s['subEventName']=='Cross']
    Cross1=Cross[Cross['Accuracy']=='Accurate'].value_counts().sum()
    Cross2=Cross[Cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Highpass=s[s['subEventName']=='High pass']
    Highpass1=Highpass[Highpass['Accuracy']=='Accurate'].value_counts().sum()
    Highpass2=Highpass[Highpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Launch=s[s['subEventName']=='Launch']
    Launch1=Launch[Launch['Accuracy']=='Accurate'].value_counts().sum()
    Launch2=Launch[Launch['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Handpass=s[s['subEventName']=='Hand pass']
    Handpass1=Handpass[Handpass['Accuracy']=='Accurate'].value_counts().sum()
    Handpass2=Handpass[Handpass['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    AD=s[s['subEventName']=='Air duel']
    AccAD=AD[AD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAD=AD[AD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GLD=s[s['subEventName']=='Ground loose ball duel']
    AccGLD=GLD[GLD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGLD=GLD[GLD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GDD=s[s['subEventName']=='Ground defending duel']
    AccGDD=GDD[GDD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGDD=GDD[GDD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    GAD=s[s['subEventName']=='Ground attacking duel']
    AccGAD=GAD[GAD['Accuracy']=='Accurate'].value_counts().sum()
    NotAccGAD=GAD[GAD['Accuracy']=='Not Accurate'].value_counts().sum()
    
    Free_K=s[s['subEventName']=='Free Kick']
    AccFree_K=Free_K[Free_K['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_K=Free_K[Free_K['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Shot=s[s['subEventName']=='Shot']
    AccShot=Shot[Shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccShot=Shot[Shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Reflexes=s[s['subEventName']=='Reflexes']
    AccReflexes=Reflexes[Reflexes['Accuracy']=='Accurate'].value_counts().sum()
    NotAccReflexes=Reflexes[Reflexes['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Clearance=s[s['subEventName']=='Clearance']
    AccClearance=Clearance[Clearance['Accuracy']=='Accurate'].value_counts().sum()
    NotAccClearance=Clearance[Clearance['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Throw_in=s[s['subEventName']=='Throw in']
    AccThrow_in=Throw_in[Throw_in['Accuracy']=='Accurate'].value_counts().sum()
    NotAccThrow_in=Throw_in[Throw_in['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    
    Corner=s[s['subEventName']=='Corner']
    AccCorner=Corner[Corner['Accuracy']=='Accurate'].value_counts().sum()
    NotAccCorner=Corner[Corner['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Save_attempt=s[s['subEventName']=='Save attempt']
    AccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Accurate'].value_counts().sum()
    NotAccSave_attempt=Save_attempt[Save_attempt['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Acceleration=s[s['subEventName']=='Acceleration']
    AccAcceleration=Acceleration[Acceleration['Accuracy']=='Accurate'].value_counts().sum()
    NotAccAcceleration=Acceleration[Acceleration['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_shot=s[s['subEventName']=='Free kick shot']
    AccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_shot=Free_kick_shot[Free_kick_shot['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Free_kick_cross=s[s['subEventName']=='Free kick cross']
    AccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Accurate'].value_counts().sum()
    NotAccFree_kick_cross=Free_kick_cross[Free_kick_cross['Accuracy']=='Not Accurate'].value_counts().sum()
    
    
    Penalty=s[s['subEventName']=='Penalty']
    AccPenalty=Penalty[Penalty['Accuracy']=='Accurate'].value_counts().sum()
    NotAccPenalty=Penalty[Penalty['Accuracy']=='Not Accurate'].value_counts().sum()
    


    
    
    Foul=s[s['subEventName']=='Foul'].value_counts().sum()
        
    Touch=s[s['subEventName']=='Touch'].value_counts().sum()
    
    BOF=s[s['subEventName']=='Ball out of the field'].value_counts().sum()
    
    GK=s[s['subEventName']=='Goal kick'].value_counts().sum()
    
    GLL=s[s['subEventName']=='Goalkeeper leaving line'].value_counts().sum()
    
    HF=s[s['subEventName']=='Hand foul'].value_counts().sum()
    
    Vf=s[s['subEventName']=='Violent Foul'].value_counts().sum()
    
    Pro=s[s['subEventName']=='Protest'].value_counts().sum()
    
    Whi=s[s['subEventName']=='Whistle'].value_counts().sum()
    
    LCF=s[s['subEventName']=='Late card foul'].value_counts().sum()
    
    OGF=s[s['subEventName']=='Out of game foul'].value_counts().sum()
    
    TLF=s[s['subEventName']=='Time lost foul'].value_counts().sum()

    Sim=s[s['subEventName']=='Simulation'].value_counts().sum()
    
    
    
    
    
    PassACC=((ACC/(ACC+NotAcc))/34)
    SimplepassACC=((Simplepass1/(Simplepass1+Simplepass2))/34)
    SmartPassACC=((SmartPass1/(SmartPass1+SmartPass2))/34)
    CrossACC=((Cross1/(Cross1+Cross2))/34)
    HighpassACC=((Highpass1/(Highpass1+Highpass2))/34)
    HeadpassACC=((Headpass1/(Headpass1+Headpass2))/34)
    LaunchACC=((Launch1/(Launch1+Launch2))/34)
    HandpassACC=((Handpass1/(Handpass1+Handpass2))/34)
    GLD_Acc=(AccGLD/(AccGLD+NotAccGLD)/34)
    GDD_Acc=(AccGDD/(AccGDD+NotAccGDD)/34)
    GAD_Acc=(AccGAD/(AccGAD+NotAccGAD)/34)
    AD_ACC=(AccAD/(AccAD+NotAccAD)/34)
    
    Free_KACC=((AccFree_K/(AccFree_K+NotAccFree_K))/34)
    ShotACC=((AccShot/(AccShot+NotAccShot))/34)
    ReflexesACC=((AccReflexes/(AccReflexes+NotAccReflexes))/34)
    ClearanceACC=((AccClearance/(AccClearance+NotAccClearance))/34)
    Throw_inACC=((AccThrow_in/(AccThrow_in+NotAccThrow_in))/34)
    CornerACC=((AccCorner/(AccCorner+NotAccCorner))/34)
    Save_attemptACC=((AccSave_attempt/(AccSave_attempt+NotAccSave_attempt))/34)
    AccelerationACC=((AccAcceleration/(AccAcceleration+NotAccAcceleration))/34)
    Free_kick_shotACC=((AccFree_kick_shot/(AccFree_kick_shot+NotAccFree_kick_shot))/34)
    Free_kick_crossACC=((AccFree_kick_cross/(AccFree_kick_cross+NotAccFree_kick_cross))/34)
    PenaltyACC=((AccPenalty/(AccPenalty+NotAccPenalty))/34)
    
    
    FoulACC=Foul/34
    TouchACC=Touch/34
    BOFACC=BOF/34
    GKACC=GK/34
    GLLACC=GLL/34
    HFACC=HF/34
    VfACC=Vf/34
    ProACC=Pro/34
    WhiACC=Whi/34
    LCFACC=LCF/34
    OGFACC=OGF/34
    TLFACC=TLF/34
    SimACC=Sim/34
    
    
    
    z=teams[teams['wyId']==i]
    c=z['officialName'].to_list()
    Cname=' '.join(map(str, c))
    b=z['type'].to_list()
    Type=' '.join(map(str, b))
    
    
    
    
    
    
    
    
    germanyTeamsdata.append((Cname,Type,i,ACC,NotAcc,Simplepass1,Simplepass2,SmartPass1,SmartPass2,
                 Cross1,Cross2,Highpass1,Highpass2,Headpass1,Headpass2,Launch1,Launch2,
                 Handpass1,Handpass2,
                
                
                 AccAD,NotAccAD,AccGLD,NotAccGLD,AccGDD,
                 NotAccGDD,AccGAD,NotAccGAD,
                
                 AccFree_K,NotAccFree_K,AccShot,NotAccShot,AccReflexes,NotAccReflexes,
                 AccClearance,NotAccClearance,AccThrow_in,NotAccThrow_in,AccCorner,
                 NotAccCorner,AccSave_attempt,NotAccSave_attempt,AccAcceleration,
                 NotAccAcceleration,AccFree_kick_shot,NotAccFree_kick_shot,AccFree_kick_cross,
                 NotAccFree_kick_cross,AccPenalty,NotAccPenalty,
                 
                 Foul,Touch,BOF,GK,GLL,HF,Vf,Pro,Whi,LCF,OGF,TLF,Sim,
                 
                 
                 
                 PassACC,SimplepassACC,SmartPassACC,CrossACC,HighpassACC,HeadpassACC,LaunchACC,
                 HandpassACC,
                 
                 AD_ACC,GLD_Acc,GDD_Acc,GAD_Acc,
                 
                 Free_KACC,ShotACC,ReflexesACC,ClearanceACC,Throw_inACC,CornerACC,Save_attemptACC,
                 AccelerationACC,Free_kick_shotACC,Free_kick_crossACC,PenaltyACC,
                 
                 FoulACC,TouchACC,BOFACC,GKACC,GLLACC,HFACC,VfACC,ProACC,WhiACC,LCFACC,
                 OGFACC,TLFACC,SimACC
                
                
                ))
    
    
germanyTeams=pd.DataFrame(germanyTeamsdata,columns=('Name','Type','Team ID','Accurate Passes',
                               'Not Accurate Passes','Accurate Simple Passes','Not Accurate Simple Passes',
                               'Accurate Smart Passes','Not Accurate Smart Passes', 'Accurate Cross','Not Accurate Cross',
                               'Accurate High Passes','Not Accurate High Passes','Accurate Head Passes','Not Accurate Head Passes','Accurate Launch','Not Accurate Launch',
                               'Accurate Hand Passes','Not Accurate Hand Passes',
                               
                               
                               'Accurate Air Duel','Not Accurate Air Duel',
                               'Acc Ground loose ball duel','Not Acc Ground loose ball duel',
                               'Acc Ground Defending duel','Not Acc Ground Defending duel','Acc Ground Attacking duel',
                               'Not Acc Ground Attacking duel',
                               
                               
                               'Accurate Free Kick','Not Accurate Free Kick','Accurate Shot','Not Accurate Shot',
                               'Accurate Reflexes','Not Accurate Reflexes', 'Accurate Clearance','Not Accurate Clearance',
                               'Accurate Throw in','Not Accurate Throw in','Accurate Corner','Not Accurate Corner',
                               'Accurate Save attempt','Not Accurate Save attempt','Accurate Acceleration','Not Accurate Acceleration',
                               
                               'Accurate Free kick shot','Not Accurate Free kick shot','Accurate Free kick cross',
                               'Not Accurate Free kick cross','Accurate Penalty','Not Accurate Penalty',
                               
                               
                               'Foul','Touch','Ball Out of Field','Goal Kick','Goalkeeper leaving line','Hand Foul'
                               ,'Violent foul','Protest','Whistle','Late Card Foul','Out of Game Foul','Time lost foul','Simulation',
                               
                            
                               
                               'Pass Accuracy','Simplepass Accuracy','SmartPass Accuracy',
                               'Cross Accuracy','Highpass Accuracy','Headpass Accuracy','Launch Accuracy',
                               'Handpass Accuracy',
                               
                               
                               'Air Duel ACC %','Ground loose ball duel ACC %',
                               'Ground Defending duel ACC %','Ground Attacking duel ACC %',
                               
                               
                               'Free Kick Accuracy','Shot Accuracy','Reflexes Accuracy',
                               'Clearance Accuracy','Throw in Accuracy','Corner Accuracy','Save attempt Accuracy',
                               'Acceleration Accuracy','Free kick shot Accuracy','Free kick cross Accuracy','Penalty Accuracy',
                               
                               'Foul Per Match','Touch Per Match','Ball Out of Field Per Match','Goal Kick Per Match','Goalkeeper leaving linePer Match',
                               'Hand Foul Per Match','Violent foul Per Match','Protest Per Match','Whistle Per Match','Late Card Foul Per Match',
                               'Out of Game Foul Per Match','Time lost foul Per Match','Simulation Per Match'
                               
                              

                              )).sort_values('Accurate Passes',ascending=False).reset_index().drop('index',axis=1)
germanyTeams['Country']='Germany'

# %%
AllT=[engTeams,spainTeams,italyTeams,franceTeams,germanyTeams]
AllTeamsStats=pd.concat(AllT).reset_index().drop('index',axis=1)
AllTeamsStats.to_csv('Teams Stats.csv',index=False)

# %% [markdown]
# # Teams Pre Assist Stats

# %% [markdown]
# ## England Teams

# %%
Teams= teams.rename(columns={'wyId': 'teamId'})
Names= names.rename(columns={'wyId': 'playerId'})
sort_columns = ['matchId', 'matchPeriod', 'eventSec']
engpreAssist= engdf.copy()
engpreAssist['assist'].replace(301, 'Assist', inplace=True) 
engpreAssist=engpreAssist.rename(columns={'From X':'X','From y':'Y'})
engextracted_rows = pd.DataFrame(columns=engpreAssist.columns)
for index, row in engpreAssist.iterrows():
    if row['assist'] == 'Assist':
        team_id = row['teamId']
        start_row_index = index
        while start_row_index > 0 and engpreAssist.iloc[start_row_index - 1]['teamId'] == team_id:
            start_row_index -= 1
        end_row_index = index + 1
        while end_row_index < len(engpreAssist) and engpreAssist.iloc[end_row_index]['teamId'] == team_id:
            end_row_index += 1
        engextracted_rows = engextracted_rows.append(engpreAssist.iloc[start_row_index:end_row_index], ignore_index=True)
engextracted_rows=engextracted_rows[engextracted_rows['eventName'].isin(['Pass','Free Kick'])] 
engDfpreAssist = pd.merge(engextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
engDfpreAssist = pd.merge(engDfpreAssist, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
engDfpreAssist['player Name']=engDfpreAssist['firstName']+" "+engDfpreAssist['lastName']
engDfpreAssist = pd.merge(engDfpreAssist, Names[['code3','playerId']], on='playerId', how='inner')
engDfpreAssist= engDfpreAssist.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
engDfpreAssist =engDfpreAssist.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
engDfpreAssist['assist'].replace(0, 'Pre Assist', inplace=True)
engDfpreAssist = engDfpreAssist.rename(columns={'assist':'Type'})
engDfpreAssist = engDfpreAssist.sort_values(by=sort_columns)

# %% [markdown]
# ## Spain Teams

# %%
spainpreAssist= spaindf.copy()
spainpreAssist['assist'].replace(301, 'Assist', inplace=True) 
spainpreAssist=spainpreAssist.rename(columns={'From X':'X','From y':'Y'})
spainextracted_rows = pd.DataFrame(columns=spainpreAssist.columns)
for index, row in spainpreAssist.iterrows():
    if row['assist'] == 'Assist':
        team_id = row['teamId']
        start_row_index = index
        while start_row_index > 0 and spainpreAssist.iloc[start_row_index - 1]['teamId'] == team_id:
            start_row_index -= 1
        end_row_index = index + 1
        while end_row_index < len(spainpreAssist) and spainpreAssist.iloc[end_row_index]['teamId'] == team_id:
            end_row_index += 1
        spainextracted_rows = spainextracted_rows.append(spainpreAssist.iloc[start_row_index:end_row_index], ignore_index=True)
spainextracted_rows=spainextracted_rows[spainextracted_rows['eventName'].isin(['Pass','Free Kick'])] 
spainDfpreAssist = pd.merge(spainextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
spainDfpreAssist = pd.merge(spainDfpreAssist, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
spainDfpreAssist['player Name']=spainDfpreAssist['firstName']+" "+spainDfpreAssist['lastName']
spainDfpreAssist = pd.merge(spainDfpreAssist, Names[['code3','playerId']], on='playerId', how='inner')
spainDfpreAssist= spainDfpreAssist.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
spainDfpreAssist =spainDfpreAssist.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
spainDfpreAssist['assist'].replace(0, 'Pre Assist', inplace=True)
spainDfpreAssist=spainDfpreAssist.rename(columns={'assist':'Type'})
spainDfpreAssist = spainDfpreAssist.sort_values(by=sort_columns)

# %% [markdown]
# ## Italy Teams

# %%
italypreAssist= italydf.copy()
italypreAssist['assist'].replace(301, 'Assist', inplace=True) 
italypreAssist=italypreAssist.rename(columns={'From X':'X','From y':'Y'})
italyextracted_rows = pd.DataFrame(columns=italypreAssist.columns)
for index, row in italypreAssist.iterrows():
    if row['assist'] == 'Assist':
        team_id = row['teamId']
        start_row_index = index
        while start_row_index > 0 and italypreAssist.iloc[start_row_index - 1]['teamId'] == team_id:
            start_row_index -= 1
        end_row_index = index + 1
        while end_row_index < len(italypreAssist) and italypreAssist.iloc[end_row_index]['teamId'] == team_id:
            end_row_index += 1
        italyextracted_rows = italyextracted_rows.append(italypreAssist.iloc[start_row_index:end_row_index], ignore_index=True)
italyextracted_rows=italyextracted_rows[italyextracted_rows['eventName'].isin(['Pass','Free Kick'])] 
italyDfpreAssist = pd.merge(italyextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
italyDfpreAssist = pd.merge(italyDfpreAssist, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
italyDfpreAssist['player Name']=italyDfpreAssist['firstName']+" "+italyDfpreAssist['lastName']
italyDfpreAssist = pd.merge(italyDfpreAssist, Names[['code3','playerId']], on='playerId', how='inner')
italyDfpreAssist= italyDfpreAssist.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
italyDfpreAssist =italyDfpreAssist.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
italyDfpreAssist['assist'].replace(0, 'Pre Assist', inplace=True)
italyDfpreAssist=italyDfpreAssist.rename(columns={'assist':'Type'})
italyDfpreAssist = italyDfpreAssist.sort_values(by=sort_columns)

# %% [markdown]
# ## France Teams

# %%
francepreAssist= francedf.copy()
francepreAssist['assist'].replace(301, 'Assist', inplace=True) 
francepreAssist=francepreAssist.rename(columns={'From X':'X','From y':'Y'})
franceextracted_rows = pd.DataFrame(columns=francepreAssist.columns)
for index, row in francepreAssist.iterrows():
    if row['assist'] == 'Assist':
        team_id = row['teamId']
        start_row_index = index
        while start_row_index > 0 and francepreAssist.iloc[start_row_index - 1]['teamId'] == team_id:
            start_row_index -= 1
        end_row_index = index + 1
        while end_row_index < len(francepreAssist) and francepreAssist.iloc[end_row_index]['teamId'] == team_id:
            end_row_index += 1
        franceextracted_rows = franceextracted_rows.append(francepreAssist.iloc[start_row_index:end_row_index], ignore_index=True)
franceextracted_rows=franceextracted_rows[franceextracted_rows['eventName'].isin(['Pass','Free Kick'])] 
franceDfpreAssist = pd.merge(franceextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
franceDfpreAssist = pd.merge(franceDfpreAssist, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
franceDfpreAssist['player Name']=franceDfpreAssist['firstName']+" "+franceDfpreAssist['lastName']
franceDfpreAssist = pd.merge(franceDfpreAssist, Names[['code3','playerId']], on='playerId', how='inner')
franceDfpreAssist= franceDfpreAssist.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
franceDfpreAssist =franceDfpreAssist.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
franceDfpreAssist['assist'].replace(0, 'Pre Assist', inplace=True)
franceDfpreAssist=franceDfpreAssist.rename(columns={'assist':'Type'})
franceDfpreAssist = franceDfpreAssist.sort_values(by=sort_columns)

# %% [markdown]
# ## Germany Teams

# %%
germanypreAssist= germanydf.copy()
germanypreAssist['assist'].replace(301, 'Assist', inplace=True) 
germanypreAssist=germanypreAssist.rename(columns={'From X':'X','From y':'Y'})
germanyextracted_rows = pd.DataFrame(columns=germanypreAssist.columns)
for index, row in germanypreAssist.iterrows():
    if row['assist'] == 'Assist':
        team_id = row['teamId']
        start_row_index = index
        while start_row_index > 0 and germanypreAssist.iloc[start_row_index - 1]['teamId'] == team_id:
            start_row_index -= 1
        end_row_index = index + 1
        while end_row_index < len(germanypreAssist) and germanypreAssist.iloc[end_row_index]['teamId'] == team_id:
            end_row_index += 1
        germanyextracted_rows = germanyextracted_rows.append(germanypreAssist.iloc[start_row_index:end_row_index], ignore_index=True)
germanyextracted_rows=germanyextracted_rows[germanyextracted_rows['eventName'].isin(['Pass','Free Kick'])] 
germanyDfpreAssist = pd.merge(germanyextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
germanyDfpreAssist = pd.merge(germanyDfpreAssist, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
germanyDfpreAssist['player Name']=germanyDfpreAssist['firstName']+" "+germanyDfpreAssist['lastName']
germanyDfpreAssist = pd.merge(germanyDfpreAssist, Names[['code3','playerId']], on='playerId', how='inner')
germanyDfpreAssist= germanyDfpreAssist.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
germanyDfpreAssist =germanyDfpreAssist.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
germanyDfpreAssist['assist'].replace(0, 'Pre Assist', inplace=True)
germanyDfpreAssist=germanyDfpreAssist.rename(columns={'assist':'Type'})
germanyDfpreAssist = germanyDfpreAssist.sort_values(by=sort_columns)

# %%
AllpreA=[engDfpreAssist,italyDfpreAssist,spainDfpreAssist,franceDfpreAssist,germanyDfpreAssist]
AllpreAssist=pd.concat(AllpreA).reset_index().drop('index',axis=1)
AllpreAssist.to_csv('Teams Pre Assist.csv',index=False)

# %% [markdown]
# # Teams Assists and Key Passes

# %% [markdown]
# ## England Teams

# %%
engAssist_KeyP= engdf.sort_values(by=['teamId','playerId'])
engAssist_KeyP=engpreAssist.rename(columns={'From X':'X','From y':'Y'})
engA_KPextracted_rows = pd.DataFrame(columns=engAssist_KeyP.columns)
for index, row in engAssist_KeyP.iterrows():
    if row['assist'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=engAssist_KeyP.columns)
        # Append the row dataframe to the appended_df
        engA_KPextracted_rows = engA_KPextracted_rows.append(row_df, ignore_index=True)
engdfAssist_KeyP = pd.merge(engA_KPextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
engdfAssist_KeyP = pd.merge(engdfAssist_KeyP, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
engdfAssist_KeyP['player Name']=engdfAssist_KeyP['firstName']+" "+engdfAssist_KeyP['lastName']
engdfAssist_KeyP = pd.merge(engdfAssist_KeyP, Names[['code3','playerId']], on='playerId', how='inner')
engdfAssist_KeyP= engdfAssist_KeyP.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
engdfAssist_KeyP =engdfAssist_KeyP.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
engdfAssist_KeyP['assist'].replace(301, 'Assist', inplace=True) 
engdfAssist_KeyP['assist'].replace(302, 'Key Pass', inplace=True)
engdfAssist_KeyP = engdfAssist_KeyP.rename(columns={'assist':'Type'})
engdfAssist_KeyP = engdfAssist_KeyP.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Spain Teams

# %%
spainAssist_KeyP= spaindf.sort_values(by=['teamId','playerId'])
spainAssist_KeyP=spainAssist_KeyP.rename(columns={'From X':'X','From y':'Y'})
spainA_KPextracted_rows = pd.DataFrame(columns=spainAssist_KeyP.columns)
for index, row in spainAssist_KeyP.iterrows():
    if row['assist'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=spainAssist_KeyP.columns)
        # Append the row dataframe to the appended_df
        spainA_KPextracted_rows = spainA_KPextracted_rows.append(row_df, ignore_index=True)
spaindfAssist_KeyP = pd.merge(spainA_KPextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
spaindfAssist_KeyP = pd.merge(spaindfAssist_KeyP, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
spaindfAssist_KeyP['player Name']=spaindfAssist_KeyP['firstName']+" "+spaindfAssist_KeyP['lastName']
spaindfAssist_KeyP = pd.merge(spaindfAssist_KeyP, Names[['code3','playerId']], on='playerId', how='inner')
spaindfAssist_KeyP= spaindfAssist_KeyP.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
spaindfAssist_KeyP =spaindfAssist_KeyP.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
spaindfAssist_KeyP['assist'].replace(301, 'Assist', inplace=True) 
spaindfAssist_KeyP['assist'].replace(302, 'Key Pass', inplace=True)
spaindfAssist_KeyP = spaindfAssist_KeyP.rename(columns={'assist':'Type'})
spaindfAssist_KeyP = spaindfAssist_KeyP.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Italy Teams

# %%
italyAssist_KeyP= italydf.sort_values(by=['teamId','playerId'])
italyAssist_KeyP=italyAssist_KeyP.rename(columns={'From X':'X','From y':'Y'})
italyA_KPextracted_rows = pd.DataFrame(columns=italyAssist_KeyP.columns)
for index, row in italyAssist_KeyP.iterrows():
    if row['assist'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=italyAssist_KeyP.columns)
        # Append the row dataframe to the appended_df
        italyA_KPextracted_rows = italyA_KPextracted_rows.append(row_df, ignore_index=True)
italydfAssist_KeyP = pd.merge(italyA_KPextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
italydfAssist_KeyP = pd.merge(italydfAssist_KeyP, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
italydfAssist_KeyP['player Name']=italydfAssist_KeyP['firstName']+" "+italydfAssist_KeyP['lastName']
italydfAssist_KeyP = pd.merge(italydfAssist_KeyP, Names[['code3','playerId']], on='playerId', how='inner')
italydfAssist_KeyP= italydfAssist_KeyP.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
italydfAssist_KeyP =italydfAssist_KeyP.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
italydfAssist_KeyP['assist'].replace(301, 'Assist', inplace=True) 
italydfAssist_KeyP['assist'].replace(302, 'Key Pass', inplace=True)
italydfAssist_KeyP = italydfAssist_KeyP.rename(columns={'assist':'Type'})
italydfAssist_KeyP = italydfAssist_KeyP.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## France Teams

# %%
franceAssist_KeyP= francedf.sort_values(by=['teamId','playerId'])
franceAssist_KeyP=franceAssist_KeyP.rename(columns={'From X':'X','From y':'Y'})
franceA_KPextracted_rows = pd.DataFrame(columns=franceAssist_KeyP.columns)
for index, row in franceAssist_KeyP.iterrows():
    if row['assist'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=franceAssist_KeyP.columns)
        # Append the row dataframe to the appended_df
        franceA_KPextracted_rows = franceA_KPextracted_rows.append(row_df, ignore_index=True)
francedfAssist_KeyP = pd.merge(franceA_KPextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
francedfAssist_KeyP = pd.merge(francedfAssist_KeyP, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
francedfAssist_KeyP['player Name']=francedfAssist_KeyP['firstName']+" "+francedfAssist_KeyP['lastName']
francedfAssist_KeyP = pd.merge(francedfAssist_KeyP, Names[['code3','playerId']], on='playerId', how='inner')
francedfAssist_KeyP = francedfAssist_KeyP.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
francedfAssist_KeyP =francedfAssist_KeyP.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
francedfAssist_KeyP['assist'].replace(301, 'Assist', inplace=True) 
francedfAssist_KeyP['assist'].replace(302, 'Key Pass', inplace=True)
francedfAssist_KeyP = francedfAssist_KeyP.rename(columns={'assist':'Type'})
francedfAssist_KeyP = francedfAssist_KeyP.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Germany Teams

# %%
germanyAssist_KeyP= germanydf.sort_values(by=['teamId','playerId'])
germanyAssist_KeyP=germanyAssist_KeyP.rename(columns={'From X':'X','From y':'Y'})
germanyA_KPextracted_rows = pd.DataFrame(columns=germanyAssist_KeyP.columns)
for index, row in germanyAssist_KeyP.iterrows():
    if row['assist'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=germanyAssist_KeyP.columns)
        # Append the row dataframe to the appended_df
        germanyA_KPextracted_rows = germanyA_KPextracted_rows.append(row_df, ignore_index=True)
germanydfAssist_KeyP = pd.merge(germanyA_KPextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
germanydfAssist_KeyP = pd.merge(germanydfAssist_KeyP, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
germanydfAssist_KeyP['player Name']=germanydfAssist_KeyP['firstName']+" "+germanydfAssist_KeyP['lastName']
germanydfAssist_KeyP = pd.merge(germanydfAssist_KeyP, Names[['code3','playerId']], on='playerId', how='inner')
germanydfAssist_KeyP = germanydfAssist_KeyP.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
germanydfAssist_KeyP =germanydfAssist_KeyP.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','CounteAttack','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
germanydfAssist_KeyP['assist'].replace(301, 'Assist', inplace=True) 
germanydfAssist_KeyP['assist'].replace(302, 'Key Pass', inplace=True)
germanydfAssist_KeyP = germanydfAssist_KeyP.rename(columns={'assist':'Type'})
germanydfAssist_KeyP = germanydfAssist_KeyP.sort_values(by=['teamId','playerId'])

# %%
AllkP_A=[engdfAssist_KeyP,italydfAssist_KeyP,spaindfAssist_KeyP,francedfAssist_KeyP,germanydfAssist_KeyP]
AllAssist_KeyP=pd.concat(AllkP_A).reset_index().drop('index',axis=1)
AllAssist_KeyP.to_csv('Teams Assists-KeyPasses.csv',index=False)

# %% [markdown]
# # Teams Counter Attack Stats

# %% [markdown]
# ## England Teams

# %%
engCounter_A= engdf.sort_values(by=['teamId','playerId'])
engCounter_A=engCounter_A.rename(columns={'From X':'X','From y':'Y'})
engCounter_Aextracted_rows = pd.DataFrame(columns=engCounter_A.columns)
for index, row in engCounter_A.iterrows():
    if row['CounteAttack'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=engCounter_A.columns)
        # Append the row dataframe to the appended_df
        engCounter_Aextracted_rows = engCounter_Aextracted_rows.append(row_df, ignore_index=True)
engdfCounter_A = pd.merge(engCounter_Aextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
engdfCounter_A = pd.merge(engdfCounter_A, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
engdfCounter_A['player Name']=engdfCounter_A['firstName']+" "+engdfCounter_A['lastName']
engdfCounter_A = pd.merge(engdfCounter_A, Names[['code3','playerId']], on='playerId', how='inner')
engdfCounter_A = engdfCounter_A.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
engdfCounter_A =engdfCounter_A.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
engdfCounter_A['CounteAttack'].replace(1901, 'Counter Attack', inplace=True) 
engdfCounter_A = engdfCounter_A.rename(columns={'CounteAttack':'Type'})
engdfCounter_A = engdfCounter_A.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Spain Teams

# %%
spainCounter_A= spaindf.sort_values(by=['teamId','playerId'])
spainCounter_A=spainCounter_A.rename(columns={'From X':'X','From y':'Y'})
spainCounter_Aextracted_rows = pd.DataFrame(columns=spainCounter_A.columns)
for index, row in spainCounter_A.iterrows():
    if row['CounteAttack'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=spainCounter_A.columns)
        # Append the row dataframe to the appended_df
        spainCounter_Aextracted_rows = spainCounter_Aextracted_rows.append(row_df, ignore_index=True)
spaindfCounter_A = pd.merge(spainCounter_Aextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
spaindfCounter_A = pd.merge(spaindfCounter_A, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
spaindfCounter_A['player Name']=spaindfCounter_A['firstName']+" "+spaindfCounter_A['lastName']
spaindfCounter_A = pd.merge(spaindfCounter_A, Names[['code3','playerId']], on='playerId', how='inner')
spaindfCounter_A = spaindfCounter_A.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
spaindfCounter_A =spaindfCounter_A.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
spaindfCounter_A['CounteAttack'].replace(1901, 'Counter Attack', inplace=True) 
spaindfCounter_A = spaindfCounter_A.rename(columns={'CounteAttack':'Type'})
spaindfCounter_A = spaindfCounter_A.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Italy Teams

# %%
italyCounter_A= italydf.sort_values(by=['teamId','playerId'])
italyCounter_A=italyCounter_A.rename(columns={'From X':'X','From y':'Y'})
italyCounter_Aextracted_rows = pd.DataFrame(columns=italyCounter_A.columns)
for index, row in italyCounter_A.iterrows():
    if row['CounteAttack'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=italyCounter_A.columns)
        # Append the row dataframe to the appended_df
        italyCounter_Aextracted_rows = italyCounter_Aextracted_rows.append(row_df, ignore_index=True)
italydfCounter_A = pd.merge(italyCounter_Aextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
italydfCounter_A = pd.merge(italydfCounter_A, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
italydfCounter_A['player Name']=italydfCounter_A['firstName']+" "+italydfCounter_A['lastName']
italydfCounter_A = pd.merge(italydfCounter_A, Names[['code3','playerId']], on='playerId', how='inner')
italydfCounter_A = italydfCounter_A.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
italydfCounter_A =italydfCounter_A.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
italydfCounter_A['CounteAttack'].replace(1901, 'Counter Attack', inplace=True) 
italydfCounter_A = italydfCounter_A.rename(columns={'CounteAttack':'Type'})
italydfCounter_A = italydfCounter_A.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## France Teams

# %%
franceCounter_A= francedf.sort_values(by=['teamId','playerId'])
franceCounter_A=franceCounter_A.rename(columns={'From X':'X','From y':'Y'})
franceCounter_Aextracted_rows = pd.DataFrame(columns=franceCounter_A.columns)
for index, row in franceCounter_A.iterrows():
    if row['CounteAttack'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=franceCounter_A.columns)
        # Append the row dataframe to the appended_df
        franceCounter_Aextracted_rows = franceCounter_Aextracted_rows.append(row_df, ignore_index=True)
francedfCounter_A = pd.merge(franceCounter_Aextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
francedfCounter_A = pd.merge(francedfCounter_A, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
francedfCounter_A['player Name']=francedfCounter_A['firstName']+" "+francedfCounter_A['lastName']
francedfCounter_A = pd.merge(francedfCounter_A, Names[['code3','playerId']], on='playerId', how='inner')
francedfCounter_A = francedfCounter_A.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
francedfCounter_A =francedfCounter_A.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
francedfCounter_A['CounteAttack'].replace(1901, 'Counter Attack', inplace=True) 
francedfCounter_A = francedfCounter_A.rename(columns={'CounteAttack':'Type'})
francedfCounter_A = francedfCounter_A.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Germany Teams

# %%
germanyCounter_A= germanydf.sort_values(by=['teamId','playerId'])
germanyCounter_A=germanyCounter_A.rename(columns={'From X':'X','From y':'Y'})
germanyCounter_Aextracted_rows = pd.DataFrame(columns=germanyCounter_A.columns)
for index, row in germanyCounter_A.iterrows():
    if row['CounteAttack'] != 0:
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=germanyCounter_A.columns)
        # Append the row dataframe to the appended_df
        germanyCounter_Aextracted_rows = germanyCounter_Aextracted_rows.append(row_df, ignore_index=True)
germanydfCounter_A = pd.merge(germanyCounter_Aextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
germanydfCounter_A = pd.merge(germanydfCounter_A, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
germanydfCounter_A['player Name']=germanydfCounter_A['firstName']+" "+germanydfCounter_A['lastName']
germanydfCounter_A = pd.merge(germanydfCounter_A, Names[['code3','playerId']], on='playerId', how='inner')
germanydfCounter_A = germanydfCounter_A.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
germanydfCounter_A =germanydfCounter_A.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
germanydfCounter_A['CounteAttack'].replace(1901, 'Counter Attack', inplace=True) 
germanydfCounter_A = germanydfCounter_A.rename(columns={'CounteAttack':'Type'})
germanydfCounter_A = germanydfCounter_A.sort_values(by=['teamId','playerId'])

# %%
AllCounter_A=[engdfCounter_A,spaindfCounter_A,italydfCounter_A,francedfCounter_A,germanydfCounter_A]
AllTeamsCounter_A=pd.concat(AllCounter_A).reset_index().drop('index',axis=1)
AllTeamsCounter_A.to_csv('Teams Counter Attack.csv',index=False)

# %% [markdown]
# # Teams Accurate Shots

# %% [markdown]
# ## England Teams

# %%
engAcc_shot= engdf.copy()
engAcc_shot=engAcc_shot.rename(columns={'From X':'X','From y':'Y'})
engAcc_shotextracted_rows = pd.DataFrame(columns=engAcc_shot.columns)
for index, row in engAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=engAcc_shot.columns)
        # Append the row dataframe to the appended_df
        engAcc_shotextracted_rows = engAcc_shotextracted_rows.append(row_df, ignore_index=True)
engdfAcc_shot = pd.merge(engAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
engdfAcc_shot = pd.merge(engdfAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
engdfAcc_shot['player Name']=engdfAcc_shot['firstName']+" "+engdfAcc_shot['lastName']
engdfAcc_shot = pd.merge(engdfAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
engdfAcc_shot = engdfAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
engdfAcc_shot =engdfAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
engdfAcc_shot['goalPos'].replace(1201, "Goal low center", inplace=True)
engdfAcc_shot['goalPos'].replace(1202, 'Goal low right', inplace=True) 
engdfAcc_shot['goalPos'].replace(1203, "Goal center", inplace=True)
engdfAcc_shot['goalPos'].replace(1204, 'Goal center left', inplace=True) 
engdfAcc_shot['goalPos'].replace(1205, "Goal low left", inplace=True)
engdfAcc_shot['goalPos'].replace(1206, 'Goal center right', inplace=True) 
engdfAcc_shot['goalPos'].replace(1207, "Goal high center", inplace=True)
engdfAcc_shot['goalPos'].replace(1208, 'Goal high left', inplace=True) 
engdfAcc_shot['goalPos'].replace(1209, 'Goal high right', inplace=True)
engdfAcc_shot = engdfAcc_shot.rename(columns={'goalPos':'Goal Position'})
engdfAcc_shot = engdfAcc_shot.sort_values(by=['teamId','playerId'])

# %%
engdfAcc_shot
# Out:
#      Y coordinate X coordinate subEventName playerId  matchId eventName  \
# 196            47           82         Shot     3319  2499798      Shot
# 197            42           93         Shot     3319  2499800      Shot
# 198            32           91         Shot     3319  2499850      Shot
# 199            47           84         Shot     3319  2499860      Shot
# 200            45           86         Shot     3319  2499890      Shot
# ...           ...          ...          ...      ...      ...       ...
# 2815           56           80         Shot   343951  2500026      Shot
# 2816           39           88         Shot   343951  2500034      Shot
# 2817           60           89         Shot   343951  2500034      Shot
# 2818           53           91         Shot   343951  2500048      Shot
# 2819           46           88         Shot   343951  2500096      Shot
#
#      teamId matchPeriod     eventSec     Goal Position         Club Name  \
# ...

# %% [markdown]
# ## Spain Teams

# %%
spainAcc_shot= spaindf.copy()
spainAcc_shot=spainAcc_shot.rename(columns={'From X':'X','From y':'Y'})
spainAcc_shotextracted_rows = pd.DataFrame(columns=spainAcc_shot.columns)
for index, row in spainAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=spainAcc_shot.columns)
        # Append the row dataframe to the appended_df
        spainAcc_shotextracted_rows = spainAcc_shotextracted_rows.append(row_df, ignore_index=True)
spaindfAcc_shot = pd.merge(spainAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
spaindfAcc_shot = pd.merge(spaindfAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
spaindfAcc_shot['player Name']=spaindfAcc_shot['firstName']+" "+spaindfAcc_shot['lastName']
spaindfAcc_shot = pd.merge(spaindfAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
spaindfAcc_shot = spaindfAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
spaindfAcc_shot =spaindfAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
spaindfAcc_shot['goalPos'].replace(1201, "Goal low center", inplace=True)
spaindfAcc_shot['goalPos'].replace(1202, 'Goal low right', inplace=True) 
spaindfAcc_shot['goalPos'].replace(1203, "Goal center", inplace=True)
spaindfAcc_shot['goalPos'].replace(1204, 'Goal center left', inplace=True) 
spaindfAcc_shot['goalPos'].replace(1205, "Goal low left", inplace=True)
spaindfAcc_shot['goalPos'].replace(1206, 'Goal center right', inplace=True) 
spaindfAcc_shot['goalPos'].replace(1207, "Goal high center", inplace=True)
spaindfAcc_shot['goalPos'].replace(1208, 'Goal high left', inplace=True) 
spaindfAcc_shot['goalPos'].replace(1209, 'Goal high right', inplace=True)
spaindfAcc_shot = spaindfAcc_shot.rename(columns={'goalPos':'Goal Position'})
spaindfAcc_shot = spaindfAcc_shot.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Italy Teams

# %%
italyAcc_shot= italydf.copy()
italyAcc_shot=italyAcc_shot.rename(columns={'From X':'X','From y':'Y'})
italyAcc_shotextracted_rows = pd.DataFrame(columns=italyAcc_shot.columns)
for index, row in italyAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=italyAcc_shot.columns)
        # Append the row dataframe to the appended_df
        italyAcc_shotextracted_rows = italyAcc_shotextracted_rows.append(row_df, ignore_index=True)
italydfAcc_shot = pd.merge(italyAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
italydfAcc_shot = pd.merge(italydfAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
italydfAcc_shot['player Name']=italydfAcc_shot['firstName']+" "+italydfAcc_shot['lastName']
italydfAcc_shot = pd.merge(italydfAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
italydfAcc_shot = italydfAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
italydfAcc_shot =italydfAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
italydfAcc_shot['goalPos'].replace(1201, "Goal low center", inplace=True)
italydfAcc_shot['goalPos'].replace(1202, 'Goal low right', inplace=True) 
italydfAcc_shot['goalPos'].replace(1203, "Goal center", inplace=True)
italydfAcc_shot['goalPos'].replace(1204, 'Goal center left', inplace=True) 
italydfAcc_shot['goalPos'].replace(1205, "Goal low left", inplace=True)
italydfAcc_shot['goalPos'].replace(1206, 'Goal center right', inplace=True) 
italydfAcc_shot['goalPos'].replace(1207, "Goal high center", inplace=True)
italydfAcc_shot['goalPos'].replace(1208, 'Goal high left', inplace=True) 
italydfAcc_shot['goalPos'].replace(1209, 'Goal high right', inplace=True)
italydfAcc_shot = italydfAcc_shot.rename(columns={'goalPos':'Goal Position'})
italydfAcc_shot = italydfAcc_shot.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## France Teams

# %%
franceAcc_shot= francedf.copy()
franceAcc_shot=franceAcc_shot.rename(columns={'From X':'X','From y':'Y'})
franceAcc_shotextracted_rows = pd.DataFrame(columns=franceAcc_shot.columns)
for index, row in franceAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=franceAcc_shot.columns)
        # Append the row dataframe to the appended_df
        franceAcc_shotextracted_rows = franceAcc_shotextracted_rows.append(row_df, ignore_index=True)
francedfAcc_shot = pd.merge(franceAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
francedfAcc_shot = pd.merge(francedfAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
francedfAcc_shot['player Name']=francedfAcc_shot['firstName']+" "+francedfAcc_shot['lastName']
francedfAcc_shot = pd.merge(francedfAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
francedfAcc_shot = francedfAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
francedfAcc_shot =francedfAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
francedfAcc_shot['goalPos'].replace(1201, "Goal low center", inplace=True)
francedfAcc_shot['goalPos'].replace(1202, 'Goal low right', inplace=True) 
francedfAcc_shot['goalPos'].replace(1203, "Goal center", inplace=True)
francedfAcc_shot['goalPos'].replace(1204, 'Goal center left', inplace=True) 
francedfAcc_shot['goalPos'].replace(1205, "Goal low left", inplace=True)
francedfAcc_shot['goalPos'].replace(1206, 'Goal center right', inplace=True) 
francedfAcc_shot['goalPos'].replace(1207, "Goal high center", inplace=True)
francedfAcc_shot['goalPos'].replace(1208, 'Goal high left', inplace=True) 
francedfAcc_shot['goalPos'].replace(1209, 'Goal high right', inplace=True)
francedfAcc_shot = francedfAcc_shot.rename(columns={'goalPos':'Goal Position'})
francedfAcc_shot = francedfAcc_shot.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Germany Teams

# %%
germanyAcc_shot= germanydf.copy()
germanyAcc_shot=germanyAcc_shot.rename(columns={'From X':'X','From y':'Y'})
germanyAcc_shotextracted_rows = pd.DataFrame(columns=germanyAcc_shot.columns)
for index, row in germanyAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=germanyAcc_shot.columns)
        # Append the row dataframe to the appended_df
        germanyAcc_shotextracted_rows = germanyAcc_shotextracted_rows.append(row_df, ignore_index=True)
germanydfAcc_shot = pd.merge(germanyAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
germanydfAcc_shot = pd.merge(germanydfAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
germanydfAcc_shot['player Name']=germanydfAcc_shot['firstName']+" "+germanydfAcc_shot['lastName']
germanydfAcc_shot = pd.merge(germanydfAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
germanydfAcc_shot = germanydfAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
germanydfAcc_shot =germanydfAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
germanydfAcc_shot['goalPos'].replace(1201, "Goal low center", inplace=True)
germanydfAcc_shot['goalPos'].replace(1202, 'Goal low right', inplace=True) 
germanydfAcc_shot['goalPos'].replace(1203, "Goal center", inplace=True)
germanydfAcc_shot['goalPos'].replace(1204, 'Goal center left', inplace=True) 
germanydfAcc_shot['goalPos'].replace(1205, "Goal low left", inplace=True)
germanydfAcc_shot['goalPos'].replace(1206, 'Goal center right', inplace=True) 
germanydfAcc_shot['goalPos'].replace(1207, "Goal high center", inplace=True)
germanydfAcc_shot['goalPos'].replace(1208, 'Goal high left', inplace=True) 
germanydfAcc_shot['goalPos'].replace(1209, 'Goal high right', inplace=True)
germanydfAcc_shot = germanydfAcc_shot.rename(columns={'goalPos':'Goal Position'})
germanydfAcc_shot = germanydfAcc_shot.sort_values(by=['teamId','playerId'])

# %%
AllAcc_shot=[engdfAcc_shot,spaindfAcc_shot,italydfAcc_shot,francedfAcc_shot,germanydfAcc_shot]
AllTeamsAcc_shot=pd.concat(AllAcc_shot).reset_index().drop('index',axis=1)
AllTeamsAcc_shot.to_csv('Teams Accurate Shots.csv',index=False)

# %% [markdown]
# # Teams Not Accurate Shots

# %% [markdown]
# ## England Teams

# %%
engNotAcc_shot= engdf.copy()
engNotAcc_shot=engNotAcc_shot.rename(columns={'From X':'X','From y':'Y'})
engNotAcc_shotextracted_rows = pd.DataFrame(columns=engNotAcc_shot.columns)
for index, row in engAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=engNotAcc_shot.columns)
        # Append the row dataframe to the appended_df
        engNotAcc_shotextracted_rows = engNotAcc_shotextracted_rows.append(row_df, ignore_index=True)
engdfNotAcc_shot = pd.merge(engNotAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
engdfNotAcc_shot = pd.merge(engdfNotAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
engdfNotAcc_shot['player Name']=engdfNotAcc_shot['firstName']+" "+engdfNotAcc_shot['lastName']
engdfNotAcc_shot = pd.merge(engdfNotAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
engdfNotAcc_shot = engdfNotAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
engdfNotAcc_shot =engdfNotAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
engdfNotAcc_shot = engdfNotAcc_shot.sort_values(by=['teamId','playerId'])

# %%
engdfNotAcc_shot
# Out:
#      Y coordinate X coordinate subEventName playerId  matchId eventName  \
# 369            64           71         Shot     3319  2499719      Shot
# 370            47           87         Shot     3319  2499719      Shot
# 371            33           92         Shot     3319  2499719      Shot
# 372            51           82         Shot     3319  2499735      Shot
# 373            30           77         Shot     3319  2499735      Shot
# ...           ...          ...          ...      ...      ...       ...
# 4159           58           88         Shot   343951  2500026      Shot
# 4160           60           75         Shot   343951  2500048      Shot
# 4161           66           91         Shot   343951  2500048      Shot
# 4162           53           89         Shot   343951  2500056      Shot
# 4163           26           88         Shot   343951  2500096      Shot
#
#      teamId matchPeriod     eventSec         Club Name      player Name
# ...

# %% [markdown]
# ## Spain Teams

# %%
spainNotAcc_shot= spaindf.copy()
spainNotAcc_shot=spainNotAcc_shot.rename(columns={'From X':'X','From y':'Y'})
spainNotAcc_shotextracted_rows = pd.DataFrame(columns=spainNotAcc_shot.columns)
for index, row in spainNotAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=spainNotAcc_shot.columns)
        # Append the row dataframe to the appended_df
        spainNotAcc_shotextracted_rows = spainNotAcc_shotextracted_rows.append(row_df, ignore_index=True)
spaindfNotAcc_shot = pd.merge(spainNotAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
spaindfNotAcc_shot = pd.merge(spaindfNotAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
spaindfNotAcc_shot['player Name']=spaindfNotAcc_shot['firstName']+" "+spaindfNotAcc_shot['lastName']
spaindfNotAcc_shot = pd.merge(spaindfNotAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
spaindfNotAcc_shot = spaindfNotAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
spaindfNotAcc_shot =spaindfNotAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
spaindfNotAcc_shot = spaindfNotAcc_shot.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Italy Teams

# %%
italyNotAcc_shot= italydf.copy()
italyNotAcc_shot=italyNotAcc_shot.rename(columns={'From X':'X','From y':'Y'})
italyNotAcc_shotextracted_rows = pd.DataFrame(columns=italyNotAcc_shot.columns)
for index, row in italyNotAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=italyNotAcc_shot.columns)
        # Append the row dataframe to the appended_df
        italyNotAcc_shotextracted_rows = italyNotAcc_shotextracted_rows.append(row_df, ignore_index=True)
italydfNotAcc_shot = pd.merge(italyNotAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
italydfNotAcc_shot = pd.merge(italydfNotAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
italydfNotAcc_shot['player Name']=italydfNotAcc_shot['firstName']+" "+italydfNotAcc_shot['lastName']
italydfNotAcc_shot = pd.merge(italydfNotAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
italydfNotAcc_shot = italydfNotAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
italydfNotAcc_shot =italydfNotAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
italydfNotAcc_shot = italydfNotAcc_shot.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## France Teams

# %%
franceNotAcc_shot= francedf.copy()
franceNotAcc_shot=franceNotAcc_shot.rename(columns={'From X':'X','From y':'Y'})
franceNotAcc_shotextracted_rows = pd.DataFrame(columns=franceNotAcc_shot.columns)
for index, row in franceNotAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=franceNotAcc_shot.columns)
        # Append the row dataframe to the appended_df
        franceNotAcc_shotextracted_rows = franceNotAcc_shotextracted_rows.append(row_df, ignore_index=True)
francedfNotAcc_shot = pd.merge(franceNotAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
francedfNotAcc_shot = pd.merge(francedfNotAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
francedfNotAcc_shot['player Name']=francedfNotAcc_shot['firstName']+" "+francedfNotAcc_shot['lastName']
francedfNotAcc_shot = pd.merge(francedfNotAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
francedfNotAcc_shot = francedfNotAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
francedfNotAcc_shot =francedfNotAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
francedfNotAcc_shot = francedfNotAcc_shot.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Germany Teams

# %%
germanyNotAcc_shot= germanydf.copy()
germanyNotAcc_shot=germanyNotAcc_shot.rename(columns={'From X':'X','From y':'Y'})
germanyNotAcc_shotextracted_rows = pd.DataFrame(columns=germanyNotAcc_shot.columns)
for index, row in germanyNotAcc_shot.iterrows():
    if row['eventName'] == 'Shot' and row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=germanyNotAcc_shot.columns)
        # Append the row dataframe to the appended_df
        germanyNotAcc_shotextracted_rows = germanyNotAcc_shotextracted_rows.append(row_df, ignore_index=True)
germanydfNotAcc_shot = pd.merge(germanyNotAcc_shotextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
germanydfNotAcc_shot = pd.merge(germanydfNotAcc_shot, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
germanydfNotAcc_shot['player Name']=germanydfNotAcc_shot['firstName']+" "+germanydfNotAcc_shot['lastName']
germanydfNotAcc_shot = pd.merge(germanydfNotAcc_shot, Names[['code3','playerId']], on='playerId', how='inner')
germanydfNotAcc_shot = germanydfNotAcc_shot.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
germanydfNotAcc_shot =germanydfNotAcc_shot.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
germanydfNotAcc_shot = germanydfNotAcc_shot.sort_values(by=['teamId','playerId'])

# %%
AllNotAcc_shot=[engdfNotAcc_shot,spaindfNotAcc_shot,italydfNotAcc_shot,francedfNotAcc_shot,germanydfNotAcc_shot]
AllTeamsNotAcc_shot=pd.concat(AllNotAcc_shot).reset_index().drop('index',axis=1)
AllTeamsNotAcc_shot.to_csv('Teams Not Accurate Shots.csv',index=False)

# %% [markdown]
# # Teams Lost Ball\Possession

# %% [markdown]
# ## England Teams

# %%
engLost_poss= engdf.copy()
engLost_poss=engLost_poss.rename(columns={'From X':'X','From y':'Y'})
engLost_possextracted_rows = pd.DataFrame(columns=engLost_poss.columns)
engLost_poss=engLost_poss[engLost_poss['eventName']!='Shot']
engLost_poss=engLost_poss[engLost_poss['eventName']!='Save attempt']
engLost_poss=engLost_poss[engLost_poss['subEventName']!='Ground defending duel']
engLost_poss=engLost_poss[engLost_poss['subEventName']!='Penalty']
for index, row in engLost_poss.iterrows():
    if row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=engLost_poss.columns)
        # Append the row dataframe to the appended_df
        engLost_possextracted_rows = engLost_possextracted_rows.append(row_df, ignore_index=True)
engdfLost_poss = pd.merge(engLost_possextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
engdfLost_poss = pd.merge(engdfLost_poss, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
engdfLost_poss['player Name']=engdfLost_poss['firstName']+" "+engdfLost_poss['lastName']
engdfLost_poss = pd.merge(engdfLost_poss, Names[['code3','playerId']], on='playerId', how='inner')
engdfLost_poss = engdfLost_poss.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
engdfLost_poss =engdfLost_poss.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
engdfLost_poss = engdfLost_poss.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Spain Teams

# %%
spainLost_poss= spaindf.copy()
spainLost_poss=spainLost_poss.rename(columns={'From X':'X','From y':'Y'})
spainLost_possextracted_rows = pd.DataFrame(columns=spainLost_poss.columns)
spainLost_poss=spainLost_poss[spainLost_poss['eventName']!='Shot']
spainLost_poss=spainLost_poss[spainLost_poss['eventName']!='Save attempt']
spainLost_poss=spainLost_poss[spainLost_poss['subEventName']!='Ground defending duel']
spainLost_poss=spainLost_poss[spainLost_poss['subEventName']!='Penalty']
for index, row in spainLost_poss.iterrows():
    if row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=spainLost_poss.columns)
        # Append the row dataframe to the appended_df
        spainLost_possextracted_rows = spainLost_possextracted_rows.append(row_df, ignore_index=True)
spaindfLost_poss = pd.merge(spainLost_possextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
spaindfLost_poss = pd.merge(spaindfLost_poss, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
spaindfLost_poss['player Name']=spaindfLost_poss['firstName']+" "+spaindfLost_poss['lastName']
spaindfLost_poss = pd.merge(spaindfLost_poss, Names[['code3','playerId']], on='playerId', how='inner')
spaindfLost_poss = spaindfLost_poss.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
spaindfLost_poss =spaindfLost_poss.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
spaindfLost_poss = spaindfLost_poss.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Italy Teams

# %%
italyLost_poss= italydf.copy()
italyLost_poss=italyLost_poss.rename(columns={'From X':'X','From y':'Y'})
italyLost_possextracted_rows = pd.DataFrame(columns=italyLost_poss.columns)
italyLost_poss=italyLost_poss[italyLost_poss['eventName']!='Shot']
italyLost_poss=italyLost_poss[italyLost_poss['eventName']!='Save attempt']
italyLost_poss=italyLost_poss[italyLost_poss['subEventName']!='Ground defending duel']
italyLost_poss=italyLost_poss[italyLost_poss['subEventName']!='Penalty']
for index, row in italyLost_poss.iterrows():
    if row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=italyLost_poss.columns)
        # Append the row dataframe to the appended_df
        italyLost_possextracted_rows = italyLost_possextracted_rows.append(row_df, ignore_index=True)
italydfLost_poss = pd.merge(italyLost_possextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
italydfLost_poss = pd.merge(italydfLost_poss, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
italydfLost_poss['player Name']=italydfLost_poss['firstName']+" "+italydfLost_poss['lastName']
italydfLost_poss = pd.merge(italydfLost_poss, Names[['code3','playerId']], on='playerId', how='inner')
italydfLost_poss = italydfLost_poss.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
italydfLost_poss =italydfLost_poss.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
italydfLost_poss = italydfLost_poss.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## France Teams

# %%
franceLost_poss= francedf.copy()
franceLost_poss=franceLost_poss.rename(columns={'From X':'X','From y':'Y'})
franceLost_possextracted_rows = pd.DataFrame(columns=franceLost_poss.columns)
franceLost_poss=franceLost_poss[franceLost_poss['eventName']!='Shot']
franceLost_poss=franceLost_poss[franceLost_poss['eventName']!='Save attempt']
franceLost_poss=franceLost_poss[franceLost_poss['subEventName']!='Ground defending duel']
franceLost_poss=franceLost_poss[franceLost_poss['subEventName']!='Penalty']
for index, row in franceLost_poss.iterrows():
    if row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=franceLost_poss.columns)
        # Append the row dataframe to the appended_df
        franceLost_possextracted_rows = franceLost_possextracted_rows.append(row_df, ignore_index=True)
francedfLost_poss = pd.merge(franceLost_possextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
francedfLost_poss = pd.merge(francedfLost_poss, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
francedfLost_poss['player Name']=francedfLost_poss['firstName']+" "+francedfLost_poss['lastName']
francedfLost_poss = pd.merge(francedfLost_poss, Names[['code3','playerId']], on='playerId', how='inner')
francedfLost_poss = francedfLost_poss.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
francedfLost_poss =francedfLost_poss.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
francedfLost_poss = francedfLost_poss.sort_values(by=['teamId','playerId'])

# %% [markdown]
# ## Germany Teams

# %%
germanyLost_poss= germanydf.copy()
germanyLost_poss=germanyLost_poss.rename(columns={'From X':'X','From y':'Y'})
germanyLost_possextracted_rows = pd.DataFrame(columns=germanyLost_poss.columns)
germanyLost_poss=germanyLost_poss[germanyLost_poss['eventName']!='Shot']
germanyLost_poss=germanyLost_poss[germanyLost_poss['eventName']!='Save attempt']
germanyLost_poss=germanyLost_poss[germanyLost_poss['subEventName']!='Ground defending duel']
germanyLost_poss=germanyLost_poss[germanyLost_poss['subEventName']!='Penalty']
for index, row in germanyLost_poss.iterrows():
    if row['Accuracy'] == 'Not Accurate':
        # Extract the row as a dataframe with a single row
        row_df = pd.DataFrame([row], columns=germanyLost_poss.columns)
        # Append the row dataframe to the appended_df
        germanyLost_possextracted_rows = germanyLost_possextracted_rows.append(row_df, ignore_index=True)
germanydfLost_poss = pd.merge(germanyLost_possextracted_rows, Teams[['officialName', 'teamId']], on='teamId', how='inner')
germanydfLost_poss = pd.merge(germanydfLost_poss, Names[['firstName','lastName','playerId']], on='playerId', how='inner')
germanydfLost_poss['player Name']=germanydfLost_poss['firstName']+" "+germanydfLost_poss['lastName']
germanydfLost_poss = pd.merge(germanydfLost_poss, Names[['code3','playerId']], on='playerId', how='inner')
germanydfLost_poss = germanydfLost_poss.rename(columns={'code3': 'Position','X':'X coordinate','Y':'Y coordinate','officialName':'Club Name'})
germanydfLost_poss =germanydfLost_poss.drop(['id_0','subEventId','firstName','lastName','To y','To X','eventId','Accuracy','interception',
                                    'through','dribble','tackle','CounteAttack','goalPos','assist','To x - From x',
                                    'To y - From y','Angle','Position','pass Position','distance'],axis=1)
 
germanydfLost_poss = germanydfLost_poss.sort_values(by=['teamId','playerId'])

# %%
AllLost_poss=[engdfLost_poss,spaindfLost_poss,italydfLost_poss,francedfLost_poss,germanydfLost_poss]
AllTeamsLost_poss=pd.concat(AllLost_poss).reset_index().drop('index',axis=1)
AllTeamsLost_poss.to_csv('Teams Lost Ball-Possession.csv',index=False)
